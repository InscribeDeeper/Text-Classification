# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Package-import" data-toc-modified-id="Package-import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Package import</a></span></li><li><span><a href="#Data-Loading" data-toc-modified-id="Data-Loading-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Loading</a></span><ul class="toc-item"><li><span><a href="#parsing" data-toc-modified-id="parsing-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>parsing</a></span></li><li><span><a href="#combined" data-toc-modified-id="combined-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>combined</a></span><ul class="toc-item"><li><span><a href="#module-test" data-toc-modified-id="module-test-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>module test</a></span></li></ul></li><li><span><a href="#attribute-selection" data-toc-modified-id="attribute-selection-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>attribute selection</a></span></li></ul></li><li><span><a href="#Feature-engineering" data-toc-modified-id="Feature-engineering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Feature engineering</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Regex" data-toc-modified-id="Regex-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Regex</a></span></li></ul></li><li><span><a href="#Build-global-index" data-toc-modified-id="Build-global-index-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Build global index</a></span></li></ul></div>

# %% [markdown]
# ## Package import

# %%
import pandas as pd 
import numpy as np
import os
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
import mailparser
import re

# %% [markdown]
# ## Data Loading
# - from file into DataFrame

# %%
def load_data_folder(path):
    '''
    @param folders: the train or test directory
    @return: document list with [doc_path, doc, label, original_idx]
    '''
    folders = glob(path+'/**')  # explore all the folder under the directory

    docs = []
    for classes in folders:
        label = classes.split('\\')[-1]
        doc_paths = glob(classes+'\\**')
        
        for doc_path in doc_paths:
            original_idx = doc_path.split('\\')[-1]
            
            with open(doc_path, encoding='UTF-8') as f:
                text = f.read()
            docs.append([doc_path, text, label, original_idx])

    print(f'\nLoaded folder under {path}: \n')
    for folder in folders:
        print(folder)
        
    return docs


corpus_train_docs = load_data_folder(path='../data/train')
corpus_test_docs = load_data_folder(path='../data/test')
# Out:
# Loaded folder under ../data/train:
#
# ../data/train\alt.atheism
# ../data/train\comp.graphics
# ../data/train\comp.os.ms-windows.misc
# ../data/train\comp.sys.ibm.pc.hardware
# ../data/train\comp.sys.mac.hardware
# ../data/train\comp.windows.x
# ../data/train\misc.forsale
# ../data/train\rec.autos
# ../data/train\rec.motorcycles
# ../data/train\rec.sport.baseball
# ../data/train\rec.sport.hockey
# ../data/train\sci.crypt
# ../data/train\sci.electronics
# ../data/train\sci.med
# ../data/train\sci.space
# ../data/train\soc.religion.christian
# ../data/train\talk.politics.guns
# ../data/train\talk.politics.mideast
# ../data/train\talk.politics.misc
# ../data/train\talk.religion.misc
#
# Loaded folder under ../data/test:
#
# ../data/test\alt.atheism
# ../data/test\comp.graphics
# ../data/test\comp.os.ms-windows.misc
# ../data/test\comp.sys.ibm.pc.hardware
# ../data/test\comp.sys.mac.hardware
# ../data/test\comp.windows.x
# ../data/test\misc.forsale
# ../data/test\rec.autos
# ../data/test\rec.motorcycles
# ../data/test\rec.sport.baseball
# ../data/test\rec.sport.hockey
# ../data/test\sci.crypt
# ../data/test\sci.electronics
# ../data/test\sci.med
# ../data/test\sci.space
# ../data/test\soc.religion.christian
# ../data/test\talk.politics.guns
# ../data/test\talk.politics.mideast
# ../data/test\talk.politics.misc
# ../data/test\talk.religion.misc

# %% [markdown]
# ### parsing

# %%
corpus_train = pd.DataFrame(corpus_train_docs, columns=['doc_path', 'text', 'label', 'original_idx'])
corpus_train = corpus_train.reset_index().rename(columns={'index':'global_index'})

corpus_test = pd.DataFrame(corpus_test_docs, columns=['doc_path', 'text', 'label', 'original_idx'])
corpus_test = corpus_test.reset_index().rename(columns={'index':'global_index'})

print("original_idx duplicate count:", corpus_train.shape[0] - corpus_train.original_idx.drop_duplicates().shape[0], ' on ', corpus_train.shape[0])
print("original_idx duplicate count:", corpus_test.shape[0] - corpus_test.original_idx.drop_duplicates().shape[0], ' on ', corpus_test.shape[0])
# Out:
# original_idx duplicate count: 1060  on  11083
# original_idx duplicate count: 770  on  7761

# %%
def typo_parser(x):
    '''
    1. replace irrelevant symbol "|"
    2. remove extra space "  "
    3. replace extra \n "\n\n" into "\n"
    4. replace '> *>' into '>>' for further analysis
    
    @param string: email body string
    @return: cleaned email body string, extracted emails
    '''
    
    x = re.sub('\|', "", x)
    x = re.sub(' {2,}', " ", x)
    x = re.sub(' ?\n{1,} ?', '\n', x)
    x = re.sub('> *>', '>>', x)
    return x

# %%
def email_address_parser(string):
    '''
    extract and remove email from the body
    @param string: email body string
    @return: cleaned email body string, extracted emails
    '''
    emails = None
    emails = re.findall(" ?[\S]+@[\S]+ ?", string)
    string = re.sub(" ?[\S]+@[\S]+ ?", " ", string)
    return string, emails

# %%
def bytedata_parser(string, threshold=25):
    '''
    Since 99% of english words length ranged from [1,20], we set the threshold with 25.
    If length of span larger than threshold, then we will not treat it as a word. 
    sep can only use space
    '''
    bytedata = None
    clean_string = " ".join([word for word in re.split(" ", string) if len(word)<=threshold])
    bytedata = [word for word in re.split(" ", string) if len(word)>threshold]
    return clean_string, bytedata

# %%
def structure_parser(string):
    '''
    @param parser: email string
    @return: structural information for email header, body, others
    '''
    error_message = None
    header = {}
    body = ''
    others = []
    try:
        mail = mailparser.parse_from_string(string)
        if mail.has_defects:  # [first line error]
            remove_first_line_string = "\n".join(string.split('\n')[1:])
            mail = mailparser.parse_from_string(remove_first_line_string)
            # print('remove_first_line_string update for ')
        header, body = mail.headers, mail.body
        others = [mail.date, mail.delivered_to, mail.to_domains, error_message]

    except Exception as error:
        error_message = error
    return header, body, others



def reference_parser(string, match_type=2):
    '''
    Consider reply with referencing previous email, we need to separate them to make prediction separately.
    @param 
        string: email body string
        match_type: 0 with return only main body, 1 with return main body + previous one reference, 2 with more reference
    @return: 
        reply, previous_one, previous_two in the email
    
    
    @ test with the following code
    string = ' \n\n\n\n    >>>zero email \n\n >>first email\n >second email\n reply email \n'
    reply, previous_one, previous_two = reference_parser(string, match_type=2)
    print("## reply\n", repr(reply))
    print("## previous_one\n", repr(previous_one))
    print("## previous_two\n", repr(previous_two))
    '''
    
    previous_one, previous_two, reply = None, None, None

    # extract reply with out containing >
    reply = " ".join([s for s in string.split('\n') if '>' not in s]).strip()
    
    # add '\n' before string to matchign [^>]{1}
    if match_type>0:
        previous_one = " ".join(re.findall('[^>]{1}>{1}([^>]{1}[\S ]*)\n', '\n' + string)).strip() # matching >
    if match_type>1:
        previous_two = " ".join(re.findall('[^>]{1}>{2}([^>]{1}[\S ]*)\n' , '\n' + string)).strip() # matching >>
    
    # previous_two_more_pt = '[^>]{1}>{2,}([^>]{1}[\S ]*)\n' # matching >> or >>> more
    return reply, previous_one, previous_two


def structural_email(data):
    '''
    this is a parser pipeline, parser order matters.
    1. string => structure email to separate => header, body, others
    2. body => remove typo and some irrelevant words => body
    3. body => parse and remove email from body => body_no_email
    4. body_no_email => parse and remove binary data like BMP or picture from body => body_no_binary_no_email
    5. body_no_binary_no_email => separate email reference and reply => reply, previous_one, previous_two
    
    @param data: data text dataframe series including all the training set or test set
    @return: structural information
    '''
    print("Preprocessing for unstructure email...")
    header_info = []
    body_info = []
    others_info = []
    for string in tqdm(data):
        header, body, others = structure_parser(string)
        body = typo_parser(body)
        body_no_email, emails = email_address_parser(body)
        body_no_binary_no_email, bytedata = bytedata_parser(body_no_email, threshold=25)
        reply, previous_one, previous_two = reference_parser(body_no_binary_no_email, match_type=2)

        header_info.append(header)
        body_info.append([reply, previous_one, previous_two])
        others_info.append(others+[emails]+[bytedata])

    a1 = pd.DataFrame.from_dict(header_info)
    a2 = pd.DataFrame(body_info, columns=['reply', 'reference_one', 'reference_two'])
    a3 = pd.DataFrame(others_info, columns=['date', 'delivered_to', 'to_domains', 'error_message', 'contained_emails', 'long_string'])
    structure_email = pd.concat([a1, a2, a3], axis=1)
    return structure_email

# %% [markdown]
# ### combined

# %%
structural_train = structural_email(corpus_train['text'])
structural_test = structural_email(corpus_test['text'])
# Out:
#   1%|▍                                                                             | 58/11083 [00:00<00:19, 579.75it/s]
# Preprocessing for unstructure email...
#  53%|████████████████████████████████████████▎                                   | 5886/11083 [00:07<00:06, 816.76it/s]Email content 'x-usenet-faq' not handled
# Email content 'x-usenet-faq' not handled
# Email content 'x-usenet-faq' not handled
# 100%|███████████████████████████████████████████████████████████████████████████| 11083/11083 [00:14<00:00, 746.15it/s]
#   2%|█▍                                                                            | 145/7761 [00:00<00:10, 717.62it/s]
# Preprocessing for unstructure email...
# 100%|█████████████████████████████████████████████████████████████████████████████| 7761/7761 [00:10<00:00, 738.43it/s]

# %%
structural_train['reference_one'].sample(5).tolist()
# Out:
# ["... \n>> >Are all truths also absolutes? Is all of scripture truths (and therefore absolutes)? \n>> The answer to both questions is yes. Perhaps we have different definitions of absolute then.  To me, situations, etc.  True in every instance possible.  Do you agree \n>> Similarly, all truth is absolute.  Indeed, a non-absolute truth is a Evangelicals are clearly not taking this particular part of scripture Can you reconcile this? \n>I don't claim that there are *no* absolutes.  I think there are very \n>> >There is hardly consensus, even in evangelical Christianity (not to mention the rest of Christianity) regarding Biblical interpretation.",
#  'I do not have finger!!! So is there any other way of accessing this service',
#  "Hi.I'm a Turkish guy who had tried atheism,satenism and buddism at some instant  write here.From my point of view,you atheists are people who has dropped to a  if you had looked a little bit upward you would see the blue skies.You'dsee t  ager.now,let's generate some entropy in means of theology and thermodynamics.W  spark which was generated for the formation of the universe.Has it formed by i rk?Please think a bit.Think and return to the only reality of the universe:ISLA",
#  '',
#  'In article  (Lee Lady) writes: Einstein and the average post-doc physicist is the quality of genius who would be a great scientist but whose great thoughts']

# %%
structural_train['reference_two']
# Out:
# 0
# 1
# 2        Well, John has a quite different, not necessar...
# 3
# 4
#                                ...
# 11078
# 11079
# 11080
# 11081
# 11082    |> Perhaps you should read it and stop advanci...
# Name: reference_two, Length: 11083, dtype: object

# %%
structural_train
# Out:
#                                                     From  \
# 0                           mathew <mathew@mantis.co.uk>
# 1                           mathew <mathew@mantis.co.uk>
# 2         I3150101@dbstu1.rz.tu-bs.de (Benedikt Rosenau)
# 3                           mathew <mathew@mantis.co.uk>
# 4                       strom@Watson.Ibm.Com (Rob Strom)
# ...                                                  ...
# 11078      psyrobtw@ubvmsd.cc.buffalo.edu (Robert Weiss)
# 11079            sandvik@newton.apple.com (Kent Sandvik)
# 11080            sandvik@newton.apple.com (Kent Sandvik)
# 11081               cutter@gloster.via.mind.org (cutter)
# 11082  rfox@charlie.usd.edu (Rich Fox, Univ of South ...
#
#                                                  Subject  \
# 0                     Alt.Atheism FAQ: Atheist Resources
# 1               Alt.Atheism FAQ: Introduction to Atheism
# 2                                      Re: Gospel Dating
# 3      Re: university violating separation of church/...
# 4      Re: [soc.motss, et al.] "Princeton axes matchi...
# ...                                                  ...
# 11078       18 Apr 93   God's Promise in Philippians 4:9
# 11079       Re: 14 Apr 93   God's Promise in 1 John 1: 7
# 11080          Re: Disillusioned Protestant Finds Christ
# 11081  Re: Biblical Backing of Koresh's 3-02 Tape (Ci...
# 11082                                   Re: Albert Sabin
#
#                                                  Summary  \
# 0      Books, addresses, music -- anything related to...
# 1      Please read this file before posting to alt.at...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11078                                                NaN
# 11079                                                NaN
# 11080                                                NaN
# 11081                                                NaN
# 11082                                                NaN
#
#                                                 Keywords  \
# 0      FAQ, atheism, books, music, fiction, addresses...
# 1                                           FAQ, atheism
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11078                                                NaN
# 11079                                                NaN
# 11080                                                NaN
# 11081                                                NaN
# 11082                                                NaN
#
#                              Expires Distribution  \
# 0      Thu, 29 Apr 1993 11:57:19 GMT        world
# 1       Thu, 6 May 1993 12:22:45 GMT        world
# 2                                NaN          NaN
# 3                                NaN          NaN
# 4                                NaN          usa
# ...                              ...          ...
# 11078                            NaN          NaN
# 11079                            NaN          NaN
# 11080                            NaN          NaN
# 11081                            NaN        world
# 11082                            NaN          NaN
#
#                                             Organization  \
# 0                     Mantis Consultants, Cambridge. UK.
# 1                     Mantis Consultants, Cambridge. UK.
# 2             Technical University Braunschweig, Germany
# 3                     Mantis Consultants, Cambridge. UK.
# 4                                           IBM Research
# ...                                                  ...
# 11078                              University at Buffalo
# 11079                          Cookamunga Tourist Bureau
# 11080                          Cookamunga Tourist Bureau
# 11081                           Gordian Knot, Gloster,GA
# 11082  The University of South Dakota Computer Scienc...
#
#                           Supersedes Lines   X-Newsreader  ... Oanization  \
# 0      <19930301143317@mantis.co.uk>   290            NaN  ...        NaN
# 1      <19930308134439@mantis.co.uk>   646            NaN  ...        NaN
# 2                                NaN    93            NaN  ...        NaN
# 3                                NaN    29  rusnews v1.01  ...        NaN
# 4                                NaN    15            NaN  ...        NaN
# ...                              ...   ...            ...  ...        ...
# 11078                            NaN     8            NaN  ...        NaN
# 11079                            NaN    14            NaN  ...        NaN
# 11080                            NaN    23            NaN  ...        NaN
# 11081                            NaN    22            NaN  ...        NaN
# 11082                            NaN    91            NaN  ...        NaN
#
#                                                    reply  \
# 0      Archive-name: resources Last-modified: 11 Dece...
# 1      Archive-name: 5 April 1993 Version: 1.2 -----B...
# 2      In article (Charley Wingate) writes:   The arg...
# 3      (...until kings become philosophers or philoso...
# 4      In article  (Bob McGwier) writes: Can somebody...
# ...                                                  ...
# 11078  Those things, \twhich ye have both learned, an...
# 11079  In article  (A.Lizard) wrote: Please, please d...
# 11080  In article  (Jim Burrill) wrote: Jim, please, ...
# 11081  () writes: And I think we ought to hold Christ...
# 11082  In article  (System PRIVILEGED Account) writes...
#
#                                            reference_one  \
# 0
# 1
# 2      >This is a new argument to me.  Could you elab...
# 3      Recently, RAs have been ordered (and none have...
# 4      [1] HOWEVER, I hate economic terrorism and pol...
# ...                                                  ...
# 11078
# 11079  Judging from postings I've read all over Usene...
# 11080  If Jesus never taught the concept of the Trini...
# 11081  In article  (stephen For those who think David...
# 11082  >In article  (Rich Fox, Univ of South Dakota) ...
#
#                                            reference_two  date delivered_to  \
# 0                                                         None           []
# 1                                                         None           []
# 2      Well, John has a quite different, not necessar...  None           []
# 3                                                         None           []
# 4                                                         None           []
# ...                                                  ...   ...          ...
# 11078                                                     None           []
# 11079                                                     None           []
# 11080                                                     None           []
# 11081                                                     None           []
# 11082  |> Perhaps you should read it and stop advanci...  None           []
#
#               to_domains error_message  \
# 0                     []          None
# 1                     []          None
# 2                     []          None
# 3                     []          None
# 4                     []          None
# ...                  ...           ...
# 11078                 []          None
# 11079                 []          None
# 11080                 []          None
# 11081                 []          None
# 11082  [charlie.usd.edu]          None
#
#                                         contained_emails  \
# 0      [ <figmo@netcom.com>. ,  archive-server@mantis...
# 1       [ <mathew@mantis.co.uk>,  pgpinfo@mantis.co.uk.]
# 2           [ <65974@mimsy.umd.edu>, mangoe@cs.umd.edu ]
# 3                                  [dmn@kepler.unh.edu ]
# 4      [ <N4HY.93Apr5120934@harder.ccr-p.ida.org>, , ...
# ...                                                  ...
# 11078                                                 []
# 11079  [ <RN652B5w165w@tweekco.uucp>, , alizard@tweek...
# 11080  [ <C5KxDD.K4J@boi.hp.com>, , jburrill@boi.hp.c...
# 11081  [netd@susie.sbc.com ,  <20APR199301460499@utar...
# 11082  [ <1993Apr15.012537.26867@nntpd2.cxo.dec.com>,...
#
#                                              long_string
# 0      [atheism/resources\nAlt-atheism-archive-name:,...
# 1      [atheism/introduction\nAlt-atheism-archive-nam...
# 2                       [discovered.\n>\n>>Interesting,]
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 11078                                                 []
# 11079                                                 []
# 11080                                                 []
# 11081  [Gladiators.\n\n\n----------------------------...
# 11082                     [anthropological\nperspective]
#
# [11083 rows x 111 columns]

# %%
train
# Out:
#                     label                                               body  \
# 0             alt.atheism  Archive-name: atheism/resources\nAlt-atheism-a...
# 1             alt.atheism  Archive-name: atheism/introduction\nAlt-atheis...
# 2             alt.atheism  In article <65974@mimsy.umd.edu>\nmangoe@cs.um...
# 3             alt.atheism  dmn@kepler.unh.edu (...until kings become phil...
# 4             alt.atheism  In article <N4HY.93Apr5120934@harder.ccr-p.ida...
# ...                   ...                                                ...
# 11078  talk.religion.misc  \n\tThose things,\n\twhich ye have both learne...
# 11079  talk.religion.misc  In article <RN652B5w165w@tweekco.uucp>, alizar...
# 11080  talk.religion.misc  In article <C5KxDD.K4J@boi.hp.com>, jburrill@b...
# 11081  talk.religion.misc  netd@susie.sbc.com () writes:\n\n> In article ...
# 11082  talk.religion.misc  In article <1993Apr15.012537.26867@nntpd2.cxo....
#
#        global_index                                doc_path  \
# 0                 0         ../data/train\alt.atheism\49960
# 1                 1         ../data/train\alt.atheism\51060
# 2                 2         ../data/train\alt.atheism\51119
# 3                 3         ../data/train\alt.atheism\51120
# 4                 4         ../data/train\alt.atheism\51121
# ...             ...                                     ...
# 11078         11078  ../data/train\talk.religion.misc\84444
# 11079         11079  ../data/train\talk.religion.misc\84445
# 11080         11080  ../data/train\talk.religion.misc\84446
# 11081         11081  ../data/train\talk.religion.misc\84507
# 11082         11082  ../data/train\talk.religion.misc\84558
#
#                                                  Subject  \
# 0                     Alt.Atheism FAQ: Atheist Resources
# 1               Alt.Atheism FAQ: Introduction to Atheism
# 2                                      Re: Gospel Dating
# 3      Re: university violating separation of church/...
# 4      Re: [soc.motss, et al.] "Princeton axes matchi...
# ...                                                  ...
# 11078       18 Apr 93   God's Promise in Philippians 4:9
# 11079       Re: 14 Apr 93   God's Promise in 1 John 1: 7
# 11080          Re: Disillusioned Protestant Finds Christ
# 11081  Re: Biblical Backing of Koresh's 3-02 Tape (Ci...
# 11082                                   Re: Albert Sabin
#
#                                                     From Lines  \
# 0                           mathew <mathew@mantis.co.uk>   290
# 1                           mathew <mathew@mantis.co.uk>   646
# 2         I3150101@dbstu1.rz.tu-bs.de (Benedikt Rosenau)    93
# 3                           mathew <mathew@mantis.co.uk>    29
# 4                       strom@Watson.Ibm.Com (Rob Strom)    15
# ...                                                  ...   ...
# 11078      psyrobtw@ubvmsd.cc.buffalo.edu (Robert Weiss)     8
# 11079            sandvik@newton.apple.com (Kent Sandvik)    14
# 11080            sandvik@newton.apple.com (Kent Sandvik)    23
# 11081               cutter@gloster.via.mind.org (cutter)    22
# 11082  rfox@charlie.usd.edu (Rich Fox, Univ of South ...    91
#
#                                             Organization  \
# 0                     Mantis Consultants, Cambridge. UK.
# 1                     Mantis Consultants, Cambridge. UK.
# 2             Technical University Braunschweig, Germany
# 3                     Mantis Consultants, Cambridge. UK.
# 4                                           IBM Research
# ...                                                  ...
# 11078                              University at Buffalo
# 11079                          Cookamunga Tourist Bureau
# 11080                          Cookamunga Tourist Bureau
# 11081                           Gordian Knot, Gloster,GA
# 11082  The University of South Dakota Computer Scienc...
#
#                                                     text
# 0      From: mathew <mathew@mantis.co.uk>\nSubject: A...
# 1      From: mathew <mathew@mantis.co.uk>\nSubject: A...
# 2      From: I3150101@dbstu1.rz.tu-bs.de (Benedikt Ro...
# 3      From: mathew <mathew@mantis.co.uk>\nSubject: R...
# 4      From: strom@Watson.Ibm.Com (Rob Strom)\nSubjec...
# ...                                                  ...
# 11078  From: psyrobtw@ubvmsd.cc.buffalo.edu (Robert W...
# 11079  From: sandvik@newton.apple.com (Kent Sandvik)\...
# 11080  From: sandvik@newton.apple.com (Kent Sandvik)\...
# 11081  From: cutter@gloster.via.mind.org (cutter)\nSu...
# 11082  Subject: Re: Albert Sabin\nFrom: rfox@charlie....
#
# [11083 rows x 9 columns]

# %%
train = pd.concat([corpus_train, structural_train], axis=1)
test = pd.concat([corpus_test, structural_test], axis=1)

# %% [markdown]
# #### module test

# %%
def checking_text(idx, write_in_local=True):
    x = train[train['global_index'] == idx]
    string = x['text'].iloc[0]
    body = x['body'].iloc[0]
    x_path = x['doc_path'].iloc[0]
    x_label = x['label'].iloc[0]
    
    if write_in_local:
        with open('E:/wyang_github/Text-Classification/text.txt', 'w', encoding='utf-8') as f:
            f.write(x_label+'\n\n')
            f.write(x_path+'\n\n')
            f.write(string)
    return string, body, x_path, x_label


# idx = 22
idx = 11082

string, body, x_path, x_label = checking_text(idx)
# header, body, others = structure_parser(string)

body_no_email, emails = email_address_parser(body)
print("\nrepr(body):   \n", repr(body))
print("\nrepr(emails):   \n", repr(emails))
print("\nrepr(body_no_email):   \n", repr(body_no_email))

body_no_binary_no_email, bytedata = bytedata_parser(body_no_email, threshold=25)
print("\nrepr(bytedata):   \n", repr(bytedata))
print("\nrepr(body_no_binary_no_email):   \n", repr(body_no_binary_no_email))

reply, previous_one, previous_two = reference_parser(body_no_binary_no_email, match_type=2)

print("\nrepr(reply):   \n", repr(reply))
print("\nrepr(previous_one):   \n", repr(previous_one))
print("\nrepr(previous_two):   \n", repr(previous_two))
# Out:
# repr(body):
#  'In article <1993Apr15.012537.26867@nntpd2.cxo.dec.com>, sharpe@nmesis.enet.dec.com (System PRIVILEGED Account) writes:\n>\n>In article <C5FtJt.885@sunfish.usd.edu>, rfox@charlie.usd.edu (Rich Fox, Univ of South Dakota) writes:\n>|>\n>|>In article <1993Apr10.213547.17644@rambo.atlanta.dg.com>, wpr@atlanta.dg.com (Bill Rawlins) writes:\n>|>\n>|>[earlier dialogue deleted]\n>|>\n>|>>|> Perhaps you should read it and stop advancing the Bible as evidence relating \n>|>>|> to questions of science.  \n>|>\n>|>[it = _Did Jesus exist?_ by G. A. Wells]\n>|>\n>|>>     There is a great fallacy in your statement. The question of origins is\n>|>>     based on more than science alone.  \n>|>\n>|>Nope, no fallacy.  Yep, science is best in determining how; religions handle\n>|>why and who.\n>|>\n>\n>Rich, I am curious as to why you and others award custody of the baby to\n>theists and religion?\n\nI hope I didn\'t award custody, Rich.  I purposely used "handle" in order to \navoid doing so - i.e., that happens to be what religions do (of course there are\naberrations like "scientific" creationism).  I used "best" in part to indicate \nthat science currently has a time of it with why and who, so these domains are\nmostly ignored.  I also attempted to be brief, which no doubt confused the\nmatter.  As an aside, for science I should have written "how and when".  Nobody\nseems to argue over what.\n\n>Are they [theists, theologians] any better equiped to investigate the "who and \n>why" than magicians, astrologers, housewives [not being sexists], athiests or \n>agnostics.\n\nSeems to me that the answer would vary from individual to individual.  I\'m not\ntrying to be evasive on this, but from a societal perspective, religion works.\nOn the other hand, sometimes it is abused and misused, and many suffer, which\nyou know.  But the net result seems positive, this from the anthropological\nperspective on human affairs.  You might call me a neo-Fruedian insofar as I \nthink the masses can\'t get along without religion.  Not that generally they are \nincapable; they just don\'t, and for myriad reasons, but the main one seems to \nbe the promise of immortality.  Very seductive, that immortality.  Therefore \nit seems that theologians are better equipped than the others you mention for \ndispensing answers to "who and why".  I suggest that this holds regardless of \nthe "truth" in their answers to who and why simply because people believe.  \nIn the end, spiritual beliefs are just as "real" as scientific facts and \nexplanation (CAUTION TO SOME: DO NOT TAKE THIS OUT OF CONTEXT).  \n\n>Do you suggest that the "who and why" will forever be closed to scientific \n>investigation?\n\nNo.  In fact, I don\'t think it is closed now, at least for some individuals. \nIsn\'t there a group of theoretical physicists who argue that matter was \ncreated from nothing in a Big Bang singularity?  This approach might \npresuppose an absence of who and why, except that it seems it could be argued \nthat something had to be responsible for nothing?  Maybe that something doesn\'t\nhave to be supernatural, maybe just mechanistic.  But that\'s a tough one for\npeople today to grasp.  In any case, theory without empirical data is not \nexplanation, but then your question does not require data.  In other words, \nI agree that theorizing (within scientific parameters) is just as scientific \nas explaining.  So the answer is, who and why are not closed to scientists, but \nI sense that science in these realms is currently very inadequate.  Data will \nbe necessary for improvement, and that seems a long way off, if ever.  Pretty \nconvoluted here; I hope I\'ve made sense.  \n\n>It seems to me that 200 or so years ago, the question of the origin of life on\n>earth was not considered open to scientific enquiry.\n\nI agree generally.  But I prefer to put it this way - the *questions* of how, \nwhen, who and why were not open to inquiry.  During the Enlightenment, \nreason was reponsible ...
#
# repr(emails):
#  [' <1993Apr15.012537.26867@nntpd2.cxo.dec.com>, ', 'sharpe@nmesis.enet.dec.com ', ' <C5FtJt.885@sunfish.usd.edu>, ', 'rfox@charlie.usd.edu ', ' <1993Apr10.213547.17644@rambo.atlanta.dg.com>, ', 'wpr@atlanta.dg.com ']
#
# repr(body_no_email):
#  'In article  (System PRIVILEGED Account) writes:\n>\n>In article  (Rich Fox, Univ of South Dakota) writes:\n>|>\n>|>In article  (Bill Rawlins) writes:\n>|>\n>|>[earlier dialogue deleted]\n>|>\n>|>>|> Perhaps you should read it and stop advancing the Bible as evidence relating \n>|>>|> to questions of science.  \n>|>\n>|>[it = _Did Jesus exist?_ by G. A. Wells]\n>|>\n>|>>     There is a great fallacy in your statement. The question of origins is\n>|>>     based on more than science alone.  \n>|>\n>|>Nope, no fallacy.  Yep, science is best in determining how; religions handle\n>|>why and who.\n>|>\n>\n>Rich, I am curious as to why you and others award custody of the baby to\n>theists and religion?\n\nI hope I didn\'t award custody, Rich.  I purposely used "handle" in order to \navoid doing so - i.e., that happens to be what religions do (of course there are\naberrations like "scientific" creationism).  I used "best" in part to indicate \nthat science currently has a time of it with why and who, so these domains are\nmostly ignored.  I also attempted to be brief, which no doubt confused the\nmatter.  As an aside, for science I should have written "how and when".  Nobody\nseems to argue over what.\n\n>Are they [theists, theologians] any better equiped to investigate the "who and \n>why" than magicians, astrologers, housewives [not being sexists], athiests or \n>agnostics.\n\nSeems to me that the answer would vary from individual to individual.  I\'m not\ntrying to be evasive on this, but from a societal perspective, religion works.\nOn the other hand, sometimes it is abused and misused, and many suffer, which\nyou know.  But the net result seems positive, this from the anthropological\nperspective on human affairs.  You might call me a neo-Fruedian insofar as I \nthink the masses can\'t get along without religion.  Not that generally they are \nincapable; they just don\'t, and for myriad reasons, but the main one seems to \nbe the promise of immortality.  Very seductive, that immortality.  Therefore \nit seems that theologians are better equipped than the others you mention for \ndispensing answers to "who and why".  I suggest that this holds regardless of \nthe "truth" in their answers to who and why simply because people believe.  \nIn the end, spiritual beliefs are just as "real" as scientific facts and \nexplanation (CAUTION TO SOME: DO NOT TAKE THIS OUT OF CONTEXT).  \n\n>Do you suggest that the "who and why" will forever be closed to scientific \n>investigation?\n\nNo.  In fact, I don\'t think it is closed now, at least for some individuals. \nIsn\'t there a group of theoretical physicists who argue that matter was \ncreated from nothing in a Big Bang singularity?  This approach might \npresuppose an absence of who and why, except that it seems it could be argued \nthat something had to be responsible for nothing?  Maybe that something doesn\'t\nhave to be supernatural, maybe just mechanistic.  But that\'s a tough one for\npeople today to grasp.  In any case, theory without empirical data is not \nexplanation, but then your question does not require data.  In other words, \nI agree that theorizing (within scientific parameters) is just as scientific \nas explaining.  So the answer is, who and why are not closed to scientists, but \nI sense that science in these realms is currently very inadequate.  Data will \nbe necessary for improvement, and that seems a long way off, if ever.  Pretty \nconvoluted here; I hope I\'ve made sense.  \n\n>It seems to me that 200 or so years ago, the question of the origin of life on\n>earth was not considered open to scientific enquiry.\n\nI agree generally.  But I prefer to put it this way - the *questions* of how, \nwhen, who and why were not open to inquiry.  During the Enlightenment, \nreason was reponsible for questioning the theological answers to how and when, \nand not, for the most part, who and why.  Science was thus born out of the \nnaturalists\' curiosity, eventually carting away  ...
#
# repr(bytedata):
#  ['anthropological\nperspective']
#
# repr(body_no_binary_no_email):
#  'In article  (System PRIVILEGED Account) writes:\n>\n>In article  (Rich Fox, Univ of South Dakota) writes:\n>|>\n>|>In article  (Bill Rawlins) writes:\n>|>\n>|>[earlier dialogue deleted]\n>|>\n>|>>|> Perhaps you should read it and stop advancing the Bible as evidence relating \n>|>>|> to questions of science.  \n>|>\n>|>[it = _Did Jesus exist?_ by G. A. Wells]\n>|>\n>|>>     There is a great fallacy in your statement. The question of origins is\n>|>>     based on more than science alone.  \n>|>\n>|>Nope, no fallacy.  Yep, science is best in determining how; religions handle\n>|>why and who.\n>|>\n>\n>Rich, I am curious as to why you and others award custody of the baby to\n>theists and religion?\n\nI hope I didn\'t award custody, Rich.  I purposely used "handle" in order to \navoid doing so - i.e., that happens to be what religions do (of course there are\naberrations like "scientific" creationism).  I used "best" in part to indicate \nthat science currently has a time of it with why and who, so these domains are\nmostly ignored.  I also attempted to be brief, which no doubt confused the\nmatter.  As an aside, for science I should have written "how and when".  Nobody\nseems to argue over what.\n\n>Are they [theists, theologians] any better equiped to investigate the "who and \n>why" than magicians, astrologers, housewives [not being sexists], athiests or \n>agnostics.\n\nSeems to me that the answer would vary from individual to individual.  I\'m not\ntrying to be evasive on this, but from a societal perspective, religion works.\nOn the other hand, sometimes it is abused and misused, and many suffer, which\nyou know.  But the net result seems positive, this from the on human affairs.  You might call me a neo-Fruedian insofar as I \nthink the masses can\'t get along without religion.  Not that generally they are \nincapable; they just don\'t, and for myriad reasons, but the main one seems to \nbe the promise of immortality.  Very seductive, that immortality.  Therefore \nit seems that theologians are better equipped than the others you mention for \ndispensing answers to "who and why".  I suggest that this holds regardless of \nthe "truth" in their answers to who and why simply because people believe.  \nIn the end, spiritual beliefs are just as "real" as scientific facts and \nexplanation (CAUTION TO SOME: DO NOT TAKE THIS OUT OF CONTEXT).  \n\n>Do you suggest that the "who and why" will forever be closed to scientific \n>investigation?\n\nNo.  In fact, I don\'t think it is closed now, at least for some individuals. \nIsn\'t there a group of theoretical physicists who argue that matter was \ncreated from nothing in a Big Bang singularity?  This approach might \npresuppose an absence of who and why, except that it seems it could be argued \nthat something had to be responsible for nothing?  Maybe that something doesn\'t\nhave to be supernatural, maybe just mechanistic.  But that\'s a tough one for\npeople today to grasp.  In any case, theory without empirical data is not \nexplanation, but then your question does not require data.  In other words, \nI agree that theorizing (within scientific parameters) is just as scientific \nas explaining.  So the answer is, who and why are not closed to scientists, but \nI sense that science in these realms is currently very inadequate.  Data will \nbe necessary for improvement, and that seems a long way off, if ever.  Pretty \nconvoluted here; I hope I\'ve made sense.  \n\n>It seems to me that 200 or so years ago, the question of the origin of life on\n>earth was not considered open to scientific enquiry.\n\nI agree generally.  But I prefer to put it this way - the *questions* of how, \nwhen, who and why were not open to inquiry.  During the Enlightenment, \nreason was reponsible for questioning the theological answers to how and when, \nand not, for the most part, who and why.  Science was thus born out of the \nnaturalists\' curiosity, eventually carting away the how and when while largel ...
#
# repr(reply):
#  'In article  (System PRIVILEGED Account) writes: I hope I didn\'t award custody, Rich.  I purposely used "handle" in order to avoid doing so - i.e., that happens to be what religions do (of course there are aberrations like "scientific" creationism).  I used "best" in part to indicate that science currently has a time of it with why and who, so these domains are mostly ignored.  I also attempted to be brief, which no doubt confused the matter.  As an aside, for science I should have written "how and when".  Nobody seems to argue over what. Seems to me that the answer would vary from individual to individual.  I\'m not trying to be evasive on this, but from a societal perspective, religion works. On the other hand, sometimes it is abused and misused, and many suffer, which you know.  But the net result seems positive, this from the on human affairs.  You might call me a neo-Fruedian insofar as I think the masses can\'t get along without religion.  Not that generally they are incapable; they just don\'t, and for myriad reasons, but the main one seems to be the promise of immortality.  Very seductive, that immortality.  Therefore it seems that theologians are better equipped than the others you mention for dispensing answers to "who and why".  I suggest that this holds regardless of the "truth" in their answers to who and why simply because people believe.  In the end, spiritual beliefs are just as "real" as scientific facts and explanation (CAUTION TO SOME: DO NOT TAKE THIS OUT OF CONTEXT).  No.  In fact, I don\'t think it is closed now, at least for some individuals. Isn\'t there a group of theoretical physicists who argue that matter was created from nothing in a Big Bang singularity?  This approach might presuppose an absence of who and why, except that it seems it could be argued that something had to be responsible for nothing?  Maybe that something doesn\'t have to be supernatural, maybe just mechanistic.  But that\'s a tough one for people today to grasp.  In any case, theory without empirical data is not explanation, but then your question does not require data.  In other words, I agree that theorizing (within scientific parameters) is just as scientific as explaining.  So the answer is, who and why are not closed to scientists, but I sense that science in these realms is currently very inadequate.  Data will be necessary for improvement, and that seems a long way off, if ever.  Pretty convoluted here; I hope I\'ve made sense.  I agree generally.  But I prefer to put it this way - the *questions* of how, when, who and why were not open to inquiry.  During the Enlightenment, reason was reponsible for questioning the theological answers to how and when, and not, for the most part, who and why.  Science was thus born out of the naturalists\' curiosity, eventually carting away the how and when while largely leaving behind the who and why.  The ignorant, the selfish, the intolerant, and the arrogant, of course, still claim authority in all four domains. Much obliged.  Funny how facts tend to muddle things, isn\'t it?  Well, I am sure there are plenty of "scientific" creationist "rebuttals" out there somewhere, even if they have to be created from nothing. [just for the record, again, AMH = anatomically modern humans] Best regards :-), Rich Fox, Anthro, Usouthdakota'
#
# repr(previous_one):
#  '>In article  (Rich Fox, Univ of South Dakota) writes: \n>|>In article  (Bill Rawlins) writes: \n>|>[earlier dialogue deleted] \n>|>>|> Perhaps you should read it and stop advancing the Bible as evidence relating  to questions of science.  \n>|>[it = _Did Jesus exist?_ by G. A. Wells] \n>|>>     There is a great fallacy in your statement. The question of origins is |> Nope, no fallacy.  Yep, science is best in determining how; religions handle why and who. \n> theists and religion? Are they [theists, theologians] any better equiped to investigate the "who and agnostics. Do you suggest that the "who and why" will forever be closed to scientific It seems to me that 200 or so years ago, the question of the origin of life on |>Rich Fox, Anthro, Usouthdakota your original post :-)'
#
# repr(previous_two):
#  '|> Perhaps you should read it and stop advancing the Bible as evidence relating |> to questions of science.       There is a great fallacy in your statement. The question of origins is      based on more than science alone.'

# %%
def reference_parser(string, match_type=2):
    '''
    Consider reply with referencing previous email, we need to separate them to make prediction separately.
    @param 
        string: email body string
        match_type: 0 with return only main body, 1 with return main body + previous one reference, 2 with more reference
    @return: 
        reply, previous_one, previous_two in the email
    
    
    @ test with the following code
    string = ' \n\n\n\n    >>>zero email \n\n >>first email\n >second email\n reply email \n'
    reply, previous_one, previous_two = reference_parser(string, match_type=2)
    print("## reply\n", repr(reply))
    print("## previous_one\n", repr(previous_one))
    print("## previous_two\n", repr(previous_two))
    '''
    # replace \n\n as \n if we dont need to separate paragraph to analysis
    # add \n before string for >> matching.  
    previous_one, previous_two, reply = None, None, None
    string = re.sub(' ?\n{1,} ?', '\n', '\n' + string) 
    
    # extract reply with out containing >
    reply = " ".join([s for s in string.split('\n') if '>' not in s]).strip()
    
    if match_type>0:
        previous_one = " ".join(re.findall('[^>]{1}>{1}([^>]{1}[\S ]*)\n', string)).strip() # matching >
    if match_type>1:
        previous_two = " ".join(re.findall('[^>]{1}>{2}([^>]{1}[\S ]*)\n' , string)).strip() # matching >>
    
    # previous_two_more_pt = '[^>]{1}>{2,}([^>]{1}[\S ]*)\n' # matching >> or >>> more
    return reply, previous_one, previous_two

# %%
string = body_no_binary_no_email
# string = body
string = re.sub(' ?\n{1,} ?', '\n', '\n' + string) 

# extract reply with out containing >
reply = " ".join([s for s in string.split('\n') if '>' not in s]).strip()

# %%
string
# Out:
# '\nIn article  (Bob McGwier) writes:  |> [1] HOWEVER, I hate economic terrorism and political correctness |> worse than I hate this policy.     |> [2] A more effective approach is to stop donating |> to ANY organizating that directly or indirectly supports gay rights issues |> until they end the boycott on funding of scouts.    Can somebody reconcile the apparent contradiction between [1] and [2]?  --  Rob Strom, (914) 784-7641 IBM Research, 30 Saw Mill River Road, P.O. Box 704, Yorktown Heights, NY  10598 '

# %%
string.split('\n')
# Out:
# ['',
#  'In article  (Bob McGwier) writes:  |> [1] HOWEVER, I hate economic terrorism and political correctness |> worse than I hate this policy.     |> [2] A more effective approach is to stop donating |> to ANY organizating that directly or indirectly supports gay rights issues |> until they end the boycott on funding of scouts.    Can somebody reconcile the apparent contradiction between [1] and [2]?  --  Rob Strom, (914) 784-7641 IBM Research, 30 Saw Mill River Road, P.O. Box 704, Yorktown Heights, NY  10598 ']

# %%
reply
# Out:
# 'Can somebody reconcile the apparent contradiction between [1] and [2]? -- Rob Strom, strom@watson.ibm.com, (914) 784-7641 IBM Research, 30 Saw Mill River Road, P.O. Box 704, Yorktown Heights, NY  10598'

# %% [markdown]
# ### attribute selection

# %%
t = train.isnull().sum().sort_values()
not_used_cols = t[t > train.shape[0]*0.1].index.tolist() 
print("not_used_cols: \n", not_used_cols)

select_cols = ['label', 'body', 'global_index', 'doc_path',
               'Subject', 'From', 'Lines', 'Organization', 'text']
print('may use cols: \n', select_cols)
# Out:
# not_used_cols:
#  ['Distribution', 'Nntp-Posting-Host', 'NNTP-Posting-Host', 'Reply-To', 'Keywords', 'Article-I.D.', 'X-Newsreader', 'Summary', 'Originator', 'In-Reply-To', 'News-Software', 'Expires', 'In-reply-to', 'To', 'X-Disclaimer', 'Disclaimer', 'X-Mailer', 'X-Useragent', 'X-Xxdate', 'Supersedes', 'X-UserAgent', 'X-XXDate', 'Nf-From', 'Nf-ID', 'X-News-Reader', 'Original-Sender', 'X-Added', 'X-Posted-From', 'X-XXMessage-ID', 'X-Xxmessage-Id', 'Content-Type', 'Cc', 'Mime-Version', 'X-Last-Updated', 'Moderator', 'Content-Transfer-Encoding', 'X-To', 'X-Gated-By', 'X-Received', 'X-Sender', 'Return-Path', 'Nntp-Posting-User', 'X-Auth-User', 'X-X-From', 'X-Md4-Signature', 'X-Maildoor', 'MIME-Version', 'Return-Receipt-To', 'X-AltNet-ID', 'X-Cc', 'X-NewsSoftware', 'Comments', 'Posting-Front-End', 'Bcc', 'X-Bytes', 'X-Header', 'X-Software', 'Organisation', 'X-Newssoftware', 'X-News-Software', 'X-Mail-Reader', 'Apparently-To', 'X-Reader', 'X-Copyright', 'Follow-Ups', 'X-Fax', 'X-Phone', 'IMPORTANT-INFO', 'OD-Comment-To', 'X-Gateway', 'X-Alt.reply-Address', 'X-Standard-Disclaimer', 'X-Address', 'Followups-to', 'X-Newsposter', 'X-Comment-To', 'X-FTN-To', 'Oanization', 'Mmdf-Warning', 'Original-To', 'Oganization', 'Nntp-Software', 'Nntp-Posting-Host-[nntpd-23809]', 'X-Date', 'Nntp-Posting-Host-[nntpd-8755]', 'Nntp-Posting-Host-[nntpd-19510]', 'Nntp-Posting-Host-[nntpd-29970]', 'Content-Length', 'ReplyTo', 'X-Advert', 'Status', 'Nntp-Posting-Host-[nntpd-681]', 'Weather', 'Moon-Phase', 'Received-Date', 'X-Face', 'Posted-Date', 'Orginization', 'date', 'error_message']
# may use cols:
#  ['label', 'body', 'global_index', 'doc_path', 'Subject', 'From', 'Lines', 'Organization', 'text']

# %%
train = train[select_cols].dropna(subset=['body'])
test = test[select_cols]

# %%
train.head()
# Out:
#          label                                               body  \
# 0  alt.atheism  Archive-name: atheism/resources\nAlt-atheism-a...
# 1  alt.atheism  Archive-name: atheism/introduction\nAlt-atheis...
# 2  alt.atheism  In article <65974@mimsy.umd.edu>\nmangoe@cs.um...
# 3  alt.atheism  dmn@kepler.unh.edu (...until kings become phil...
# 4  alt.atheism  In article <N4HY.93Apr5120934@harder.ccr-p.ida...
#
#    global_index                         doc_path  \
# 0             0  ../data/train\alt.atheism\49960
# 1             1  ../data/train\alt.atheism\51060
# 2             2  ../data/train\alt.atheism\51119
# 3             3  ../data/train\alt.atheism\51120
# 4             4  ../data/train\alt.atheism\51121
#
#                                              Subject  \
# 0                 Alt.Atheism FAQ: Atheist Resources
# 1           Alt.Atheism FAQ: Introduction to Atheism
# 2                                  Re: Gospel Dating
# 3  Re: university violating separation of church/...
# 4  Re: [soc.motss, et al.] "Princeton axes matchi...
#
#                                              From Lines  \
# 0                    mathew <mathew@mantis.co.uk>   290
# 1                    mathew <mathew@mantis.co.uk>   646
# 2  I3150101@dbstu1.rz.tu-bs.de (Benedikt Rosenau)    93
# 3                    mathew <mathew@mantis.co.uk>    29
# 4                strom@Watson.Ibm.Com (Rob Strom)    15
#
#                                  Organization  \
# 0          Mantis Consultants, Cambridge. UK.
# 1          Mantis Consultants, Cambridge. UK.
# 2  Technical University Braunschweig, Germany
# 3          Mantis Consultants, Cambridge. UK.
# 4                                IBM Research
#
#                                                 text
# 0  From: mathew <mathew@mantis.co.uk>\nSubject: A...
# 1  From: mathew <mathew@mantis.co.uk>\nSubject: A...
# 2  From: I3150101@dbstu1.rz.tu-bs.de (Benedikt Ro...
# 3  From: mathew <mathew@mantis.co.uk>\nSubject: R...
# 4  From: strom@Watson.Ibm.Com (Rob Strom)\nSubjec...

# %%
t = train[train['body'].apply(lambda x: 'In article' in x)]
# t.groupby('label').size()

# %%
t
# Out:
#                     label                                               body  \
# 2             alt.atheism  In article <65974@mimsy.umd.edu>\nmangoe@cs.um...
# 4             alt.atheism  In article <N4HY.93Apr5120934@harder.ccr-p.ida...
# 5             alt.atheism  In article <1993Apr5.091139.823@batman.bmd.trw...
# 7             alt.atheism  In article <114127@bu.edu>\njaeger@buphy.bu.ed...
# 16            alt.atheism  In article <2942881697.0.p00168@psilink.com> p...
# ...                   ...                                                ...
# 11077  talk.religion.misc  Okay, I'll bite. I should probably leave this ...
# 11079  talk.religion.misc  In article <RN652B5w165w@tweekco.uucp>, alizar...
# 11080  talk.religion.misc  In article <C5KxDD.K4J@boi.hp.com>, jburrill@b...
# 11081  talk.religion.misc  netd@susie.sbc.com () writes:\n\n> In article ...
# 11082  talk.religion.misc  In article <1993Apr15.012537.26867@nntpd2.cxo....
#
#        global_index                                doc_path  \
# 2                 2         ../data/train\alt.atheism\51119
# 4                 4         ../data/train\alt.atheism\51121
# 5                 5         ../data/train\alt.atheism\51122
# 7                 7         ../data/train\alt.atheism\51124
# 16               16         ../data/train\alt.atheism\51134
# ...             ...                                     ...
# 11077         11077  ../data/train\talk.religion.misc\84443
# 11079         11079  ../data/train\talk.religion.misc\84445
# 11080         11080  ../data/train\talk.religion.misc\84446
# 11081         11081  ../data/train\talk.religion.misc\84507
# 11082         11082  ../data/train\talk.religion.misc\84558
#
#                                                  Subject  \
# 2                                      Re: Gospel Dating
# 4      Re: [soc.motss, et al.] "Princeton axes matchi...
# 5               Re: A visit from the Jehovah's Witnesses
# 7                            Re: An Anecdote about Islam
# 16     Re: Don't more innocents die without the death...
# ...                                                  ...
# 11077                                  Re: Flaming Nazis
# 11079       Re: 14 Apr 93   God's Promise in 1 John 1: 7
# 11080          Re: Disillusioned Protestant Finds Christ
# 11081  Re: Biblical Backing of Koresh's 3-02 Tape (Ci...
# 11082                                   Re: Albert Sabin
#
#                                                     From Lines  \
# 2         I3150101@dbstu1.rz.tu-bs.de (Benedikt Rosenau)    93
# 4                       strom@Watson.Ibm.Com (Rob Strom)    15
# 5         I3150101@dbstu1.rz.tu-bs.de (Benedikt Rosenau)   114
# 7         I3150101@dbstu1.rz.tu-bs.de (Benedikt Rosenau)    28
# 16            bobbe@vice.ICO.TEK.COM (Robert Beauchaine)    26
# ...                                                  ...   ...
# 11077  deane@binah.cc.brandeis.edu (David Matthew Deane)   106
# 11079            sandvik@newton.apple.com (Kent Sandvik)    14
# 11080            sandvik@newton.apple.com (Kent Sandvik)    23
# 11081               cutter@gloster.via.mind.org (cutter)    22
# 11082  rfox@charlie.usd.edu (Rich Fox, Univ of South ...    91
#
#                                             Organization
# 2             Technical University Braunschweig, Germany
# 4                                           IBM Research
# 5             Technical University Braunschweig, Germany
# 7             Technical University Braunschweig, Germany
# 16                      Tektronix, Inc., Beaverton,  OR.
# ...                                                  ...
# 11077                                Brandeis University
# 11079                          Cookamunga Tourist Bureau
# 11080                          Cookamunga Tourist Bureau
# 11081                           Gordian Knot, Gloster,GA
# 11082  The University of South Dakota Computer Scienc...
#
# [4442 rows x 8 columns]

# %%
print(string)
# Out:
# From: dbd@urartu.sdpa.org (David Davidian)
# Subject: FORGED POSTING -- FORGED POSTING -- FORGED POSTING
# Summary: usually generated by those who can't live with themselves!
# Organization: S.D.P.A. Center for Regional Studies
# Lines: 37
#
#
# THE FOLLOWING POSTING WAS FORGED IN MY NAME! PLEASE IGNORE SUCH POSTINGS!
#
# [FORGED] Newsgroups:soc.culture.turkish,talk.politics.mideast,talk.politics.
# [FORGED] soviet,soc.culture.greek
# [FORGED] From: dbd@urartu.sdpa.org (David Davidian)
# [FORGED] News-Software: VAX/VMS VNEWS 1.41
# [FORGED] Organization: University of Tennessee Computing Center
# [FORGED] Date: Fri, 16 Apr 1993 21:36:00 GMT
# [FORGED] Lines: 293
# [FORGED]
# [FORGED] Dear friends,
# [FORGED]
# [FORGED] I am a graduate student in Education at the University of Tennessee.
# [FORGED]
#   .
#   .
#   .
# [FORGED]
# [FORGED]
# [FORGED]                         __QUESTIONNAIRE__
# [FORGED]                  Teaching Music for deaf children.
# [FORGED]
# [FORGED] NAME ________________________________
# [FORGED] ADDRESS/ E-MAIL _____________________
# [FORGED] EMPLOYING INSTITUTION _______________
# [FORGED] YEARS OF EXPERIENCE_________ GRADE LEVEL(S)____
# [FORGED] EDUCATIONAL BACKGROUND:BACHELOR__ MASTERS__ DOCTORATE__
# [FORGED] PROFESSIONAL FIELD:SPECIAL EDUC.__  MUSIC EDUC.__ OTHER*__
#
# THE ABOVE POSTING WAS FORGED IN MY NAME! PLEASE IGNORE SUCH POSTINGS!
#
# --
# David Davidian dbd@urartu.sdpa.org   | "How do we explain Turkish troops on
# S.D.P.A. Center for Regional Studies |  the Armenian border, when we can't
# P.O. Box 382761                      |  even explain 1915?"
# Cambridge, MA 02238                  |              Turkish MP, March 1992

# %% [markdown]
# ## Feature engineering

# %%
train[['body', 'doc_path', 'label']].sample(5).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_62ce4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >body</th>
#       <th class="col_heading level0 col1" >doc_path</th>
#       <th class="col_heading level0 col2" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62ce4_level0_row0" class="row_heading level0 row0" >7409</th>
#       <td id="T_62ce4_row0_col0" class="data row0 col0" >In article <19613@pitt.UUCP>, geb@cs.pitt.edu (Gordon Banks) writes:
# > In article <1993Apr7.221357.12533@lamont.ldgo.columbia.edu> brenner@ldgo.columbia.edu (carl brenner) writes:
# > >> see the ulterior motive here.  It is easy for me to see it the
# > >> those physicians who call everything lyme and treat everything.
# > >> There is a lot of money involved.
# > >
# > >	You keep bringing this up. But I don't understand what's in it
# > >financially for the physician to go ahead and treat. Unless the physician
# > >has an investment in (or is involved in some kickback scheme with) the
# > >home infusion company, where is the financial gain for the doctor?
# >
# > Well, let me put it this way, based on my own experience.  A
# > general practitioner with no training in infectious diseases,
# > by establishing links to the "Lyme community", treating patients
# > who come to him wondering about lyme or having decided they
# > have lyme as if they did, saying that diseases such as MS
# > are probably spirochetal, if not Lyme, giving talks at meetings
# > of users groups, validating the feelings of even delusional
# > patients, etc.  This GP can go from being a run-of-the-mill
# > $100K/yr GP to someone with lots of patients in the hospital
# > and getting expensive infusions that need monitoring in his
# > office, and making lots of bread.  Also getting the adulation
# > of many who believe his is their only hope (if not of cure,
# > then of control) and seeing his name in publications put out
# > by support groups, etc.  This is a definite temptation.
#
# 	Harumph. Getting published in these newsletters is hardly something
# to aspire to. :-)
# 	I can't really argue with your logic, though I think you may be
# extrapolating a bit recklessly from what appears to be a sample size of
# one. Even if what you say about this local Pittsburgh guy is true, it is
# not logical or fair to conclude that this is true of all doctors who
# treat Lyme disease.
# 	By your logic, I could conclude that all of the physicians who
# consult for insurance companies and make money by denying benefits to
# Lyme patients are doing it for the money, rather than because they believe
# they are encouraging good medicine. I have no idea how sincere these guys
# are, but their motives are as suspect as the physicians you excoriate for
# what you believe to be indiscriminate treatment.
# 	I would really feel more comfortable discussing the medical issues
# in Lyme, rather than speculating as to the motives of the various parties
# involved.
#
# > ----------------------------------------------------------------------------
# > Gordon Banks  N3JXP      | "Skepticism is the chastity of the intellect, and
# > geb@cadre.dsl.pitt.edu   |  it is shameful to surrender it too soon."
# > ----------------------------------------------------------------------------
#
# Carl Brenner
#
# </td>
#       <td id="T_62ce4_row0_col1" class="data row0 col1" >../data/train\sci.med\58904</td>
#       <td id="T_62ce4_row0_col2" class="data row0 col2" >sci.med</td>
#     </tr>
#     <tr>
#       <th id="T_62ce4_level0_row1" class="row_heading level0 row1" >8975</th>
#       <td id="T_62ce4_row1_col0" class="data row1 col0" >I've been thinking about the idea that was raised (by Michael Covington,
# I think) that words mean what we think they mean, regardless of
# etymology.  I've been reflecting on what certain words meant in my
# childhood and tracing how this shaped some of my attitudes.
#
# I grew up in a home where Christ was a bad word.  People who were very
# angry said it.  The word Christian meant someone who was not a Jew.  It
# carried connotations of otherness, of threat, of enemy.  It took some
# time to figure out that there was a connection between `Christ' and
# `Christian'.  When I accepted Jesus, I expected to be disowned.  To
# become a Christian meant to join the enemy.  I knew others would
# consider me a traitor.  At some level, I agreed, but was still prepared
# to pay this price.  Like Esau, I sold my birthright.  However, I made a
# better bargain.  He only got some stew, but I got the incomparable
# riches of knowing Christ.
#
# As it turned out, my parents did not disown me.  I found out later that
# they were hoping it was a phase that I would grow out of.  By the time
# they had decided it wasn't a phase, they were sort of used to it.  They
# didn't disown me but they didn't completely accept the situation either.
# For example, they didn't come to my wedding because it was in a church.
# When I visited my grandmother in the hospital a few days before her
# death, she said to me, "As far as I'm concerned, you still are a Jew."
# What she meant was that she loved me and forgave me.  But I am not a
# Jew.  I am a Christian.  (I'll concede, one that likes chicken soup with
# matzoh balls.:-))
#
# I do not keep kosher.  I do not celebrate the Sabbath on Saturday.  My
# sons are not circumcised.  But these things are true of some people who
# do consider themselves Jews.  It is not these rules that make people
# Jews; it is the heritage from the past.  I gave up the past.
#
# This is why I find it hard to relate to Messianic Jews.  Their
# experience is unlike mine.  They still consider themselves Jews while
# following Jesus.  Some would even say that I *must* do so, too.
#
# I am at a stage of my life now where I would like to have a heritage.
# It was not something I valued very much when I gave it.  But I did have
# a sense that I was giving it for God.  It may have been a small
# sacrifice.  It may have been an unnecessary sacrifice.  But I gave it
# and do not want to ask for it back.
#
# And while I don't have the heritage I was born with, I do have another.
# I am an outcast from the house of Israel, but I am a member of the
# Church.  One of the things I like about being a Catholic Christian is
# that it is rich in tradition.  It gives me a feeling of, once again,
# being rooted in the past.
#
# This is probably one of the reasons why I don't like it when people mess
# around with Christian traditions (for example, changing the name of
# Easter).  These traditions fill an important emotional need of mine.
#
# I suppose the point of all this is that people shouldn't assume that all
# believers of Jewish background are the same.  For some `Jewish
# Christian' is a good name, for others it is an oxymoron.
#
# Jayne Kulikauskas/jayen@mmalt.guild.org
# </td>
#       <td id="T_62ce4_row1_col1" class="data row1 col1" >../data/train\soc.religion.christian\20925</td>
#       <td id="T_62ce4_row1_col2" class="data row1 col2" >soc.religion.christian</td>
#     </tr>
#     <tr>
#       <th id="T_62ce4_level0_row2" class="row_heading level0 row2" >10057</th>
#       <td id="T_62ce4_row2_col0" class="data row2 col0" >Mr. Freeman:
#
# Please find something more constructive to do with your time rather
# than engaging in fantasy..... Not that I have a particular affinty
# to Arafat or anything.
#
# John
#
#
#
# "Marlow ceased, and sat apart, indistinct and silent, in the pose of a
#  meditating Buddha. Nobody moved for a time...The offing was barred by
#  a black bank of clouds, and the tranquil waterway leading to the utter-
#  most ends of the earth flowed sombre under an overcast sky - seemed to
# </td>
#       <td id="T_62ce4_row2_col1" class="data row2 col1" >../data/train\talk.politics.mideast\76251</td>
#       <td id="T_62ce4_row2_col2" class="data row2 col2" >talk.politics.mideast</td>
#     </tr>
#     <tr>
#       <th id="T_62ce4_level0_row3" class="row_heading level0 row3" >1287</th>
#       <td id="T_62ce4_row3_col0" class="data row3 col0" >
# In article <1993Apr17.023017.17301@gmuvax2.gmu.edu> rwang@gmuvax2.gmu.edu writes:
#
#  >
#  > Hi,

# %% [markdown]
# ## EDA

# %%
train['char_length'] = train['text'].apply(lambda x:len(x))

# c = (train['char_length'].sort_values())
# sent_cdf = c.cumsum()
# sent_pdf = c # / c.sum()
# sent_pdf.plot(kind='hist', bins=100)
# plt.xlabel("char_length")  # 需要先sort, 才能说是index of chars.
# plt.ylabel("char_cum_counts_perc")
# plt.title("MAX_DOC_LEN CDF")
# plt.show()

# %%
train.sort_values(by='char_length')
# Out:
#        global_index                                    doc_path  \
# 494             494           ../data/train\comp.graphics\37928
# 2402           2402   ../data/train\comp.sys.mac.hardware\51522
# 4039           4039              ../data/train\rec.autos\101589
# 2421           2421   ../data/train\comp.sys.mac.hardware\51541
# 3595           3595            ../data/train\misc.forsale\75911
# ...             ...                                         ...
# 10176         10176   ../data/train\talk.politics.mideast\76392
# 1362           1362  ../data/train\comp.os.ms-windows.misc\9704
# 2826           2826          ../data/train\comp.windows.x\66322
# 9625           9625      ../data/train\talk.politics.guns\54684
# 6739           6739         ../data/train\sci.electronics\53569
#
#                                                     text  \
# 494    From: hl7204@eehp22 (H L)\nSubject: Re: Graphi...
# 2402   From: kwgst+@pitt.edu (Mr. Someone)\nSubject: ...
# 4039   From: swdwan@napier.uwaterloo.ca (Donald Wan)\...
# 2421   From: news@news.claremont.edu (The News System...
# 3595   From: ibeshir@nyx.cs.du.edu (Ibrahim)\nSubject...
# ...                                                  ...
# 10176  From: dbd@urartu.sdpa.org (David Davidian)\nSu...
# 1362   From: james@dlss2 (James Cummings)\nSubject: R...
# 2826   From: ware@cis.ohio-state.edu (Peter Ware)\nSu...
# 9625   From: mjp@watson.ibm.com (Michael Phelps)\nSub...
# 6739   From: jeh@cmkrnl.com\nSubject: Electrical wiri...
#
#                          label original_idx  char_length
# 494              comp.graphics        37928          125
# 2402     comp.sys.mac.hardware        51522          125
# 4039                 rec.autos       101589          131
# 2421     comp.sys.mac.hardware        51541          139
# 3595              misc.forsale        75911          142
# ...                        ...          ...          ...
# 10176    talk.politics.mideast        76392        62187
# 1362   comp.os.ms-windows.misc         9704        63095
# 2826            comp.windows.x        66322        66459
# 9625        talk.politics.guns        54684        71400
# 6739           sci.electronics        53569        72637
#
# [11083 rows x 6 columns]

# %%
# Out:
#                                                     From  \
# 0                           mathew <mathew@mantis.co.uk>
# 1                           mathew <mathew@mantis.co.uk>
# 2         I3150101@dbstu1.rz.tu-bs.de (Benedikt Rosenau)
# 3                           mathew <mathew@mantis.co.uk>
# 4                       strom@Watson.Ibm.Com (Rob Strom)
# ...                                                  ...
# 11078      psyrobtw@ubvmsd.cc.buffalo.edu (Robert Weiss)
# 11079            sandvik@newton.apple.com (Kent Sandvik)
# 11080            sandvik@newton.apple.com (Kent Sandvik)
# 11081               cutter@gloster.via.mind.org (cutter)
# 11082  rfox@charlie.usd.edu (Rich Fox, Univ of South ...
#
#                                                  Subject  \
# 0                     Alt.Atheism FAQ: Atheist Resources
# 1               Alt.Atheism FAQ: Introduction to Atheism
# 2                                      Re: Gospel Dating
# 3      Re: university violating separation of church/...
# 4      Re: [soc.motss, et al.] "Princeton axes matchi...
# ...                                                  ...
# 11078       18 Apr 93   God's Promise in Philippians 4:9
# 11079       Re: 14 Apr 93   God's Promise in 1 John 1: 7
# 11080          Re: Disillusioned Protestant Finds Christ
# 11081  Re: Biblical Backing of Koresh's 3-02 Tape (Ci...
# 11082                                   Re: Albert Sabin
#
#                                                  Summary  \
# 0      Books, addresses, music -- anything related to...
# 1      Please read this file before posting to alt.at...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11078                                                NaN
# 11079                                                NaN
# 11080                                                NaN
# 11081                                                NaN
# 11082                                                NaN
#
#                                                 Keywords  \
# 0      FAQ, atheism, books, music, fiction, addresses...
# 1                                           FAQ, atheism
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11078                                                NaN
# 11079                                                NaN
# 11080                                                NaN
# 11081                                                NaN
# 11082                                                NaN
#
#                              Expires Distribution  \
# 0      Thu, 29 Apr 1993 11:57:19 GMT        world
# 1       Thu, 6 May 1993 12:22:45 GMT        world
# 2                                NaN          NaN
# 3                                NaN          NaN
# 4                                NaN          usa
# ...                              ...          ...
# 11078                            NaN          NaN
# 11079                            NaN          NaN
# 11080                            NaN          NaN
# 11081                            NaN        world
# 11082                            NaN          NaN
#
#                                             Organization  \
# 0                     Mantis Consultants, Cambridge. UK.
# 1                     Mantis Consultants, Cambridge. UK.
# 2             Technical University Braunschweig, Germany
# 3                     Mantis Consultants, Cambridge. UK.
# 4                                           IBM Research
# ...                                                  ...
# 11078                              University at Buffalo
# 11079                          Cookamunga Tourist Bureau
# 11080                          Cookamunga Tourist Bureau
# 11081                           Gordian Knot, Gloster,GA
# 11082  The University of South Dakota Computer Scienc...
#
#                           Supersedes Lines   X-Newsreader  ... Followups-to  \
# 0      <19930301143317@mantis.co.uk>   290            NaN  ...          NaN
# 1      <19930308134439@mantis.co.uk>   646            NaN  ...          NaN
# 2                                NaN    93            NaN  ...          NaN
# 3                                NaN    29  rusnews v1.01  ...          NaN
# 4                                NaN    15            NaN  ...          NaN
# ...                              ...   ...            ...  ...          ...
# 11078                            NaN     8            NaN  ...          NaN
# 11079                            NaN    14            NaN  ...          NaN
# 11080                            NaN    23            NaN  ...          NaN
# 11081                            NaN    22            NaN  ...          NaN
# 11082                            NaN    91            NaN  ...          NaN
#
#       X-Newsposter X-Header X-Cc Oanization  \
# 0              NaN      NaN  NaN        NaN
# 1              NaN      NaN  NaN        NaN
# 2              NaN      NaN  NaN        NaN
# 3              NaN      NaN  NaN        NaN
# 4              NaN      NaN  NaN        NaN
# ...            ...      ...  ...        ...
# 11078          NaN      NaN  NaN        NaN
# 11079          NaN      NaN  NaN        NaN
# 11080          NaN      NaN  NaN        NaN
# 11081          NaN      NaN  NaN        NaN
# 11082          NaN      NaN  NaN        NaN
#
#                                                     body  date delivered_to  \
# 0      Archive-name: atheism/resources\nAlt-atheism-a...  None           []
# 1      Archive-name: atheism/introduction\nAlt-atheis...  None           []
# 2      In article <65974@mimsy.umd.edu>\nmangoe@cs.um...  None           []
# 3      dmn@kepler.unh.edu (...until kings become phil...  None           []
# 4      In article <N4HY.93Apr5120934@harder.ccr-p.ida...  None           []
# ...                                                  ...   ...          ...
# 11078  \n\tThose things,\n\twhich ye have both learne...  None           []
# 11079  In article <RN652B5w165w@tweekco.uucp>, alizar...  None           []
# 11080  In article <C5KxDD.K4J@boi.hp.com>, jburrill@b...  None           []
# 11081  netd@susie.sbc.com () writes:\n\n> In article ...  None           []
# 11082  In article <1993Apr15.012537.26867@nntpd2.cxo....  None           []
#
#               to_domains error_message
# 0                     []          None
# 1                     []          None
# 2                     []          None
# 3                     []          None
# 4                     []          None
# ...                  ...           ...
# 11078                 []          None
# 11079                 []          None
# 11080                 []          None
# 11081                 []          None
# 11082  [charlie.usd.edu]          None
#
# [11083 rows x 107 columns]

# %% [markdown]
# ### Regex
# - From
# - Subject
#     - 如果 bmp 在这里面的话, 直接跳过 先不处理
# - Summary
# - Keywords
# - Expires
# - Distribution
# - Organization
# - Supersedes
# - Lines
#
# - Archive-name
# - Alt-atheism-archive-name
# - Last-modified
# - Version
#
# 内容里面最长的词有多长, 如果太长了 超过100, 则认为是有乱码. 直接跳过?

# %%
写正则表达式
-

# %%
string = t['text'][9]
string.split('\n')
# Out:
# ['From: keith@cco.caltech.edu (Keith Allan Schneider)',
#  'Subject: Re: >>>>>>Pompous ass',
#  'Organization: California Institute of Technology, Pasadena',
#  'Lines: 9',
#  'NNTP-Posting-Host: punisher.caltech.edu',
#  '',
#  'kmr4@po.CWRU.edu (Keith M. Ryan) writes:',
#  '',
#  '>>Then why do people keep asking the same questions over and over?',
#  '>Because you rarely ever answer them.',
#  '',
#  "Nope, I've answered each question posed, and most were answered multiple",
#  'times.',
#  '',
#  'keith',
#  '']

# %%
# Out:
# 0        From: mathew <mathew@mantis.co.uk>\nSubject: A...
# 1        From: mathew <mathew@mantis.co.uk>\nSubject: A...
# 2        From: I3150101@dbstu1.rz.tu-bs.de (Benedikt Ro...
# 3        From: mathew <mathew@mantis.co.uk>\nSubject: R...
# 4        From: strom@Watson.Ibm.Com (Rob Strom)\nSubjec...
#                                ...
# 11078    From: psyrobtw@ubvmsd.cc.buffalo.edu (Robert W...
# 11079    From: sandvik@newton.apple.com (Kent Sandvik)\...
# 11080    From: sandvik@newton.apple.com (Kent Sandvik)\...
# 11081    From: cutter@gloster.via.mind.org (cutter)\nSu...
# 11082    Subject: Re: Albert Sabin\nFrom: rfox@charlie....
# Name: text, Length: 11083, dtype: object

# %%
def info_extractor():

# %% [markdown]
# ## Build global index
# - for future information retrieve

# %%
# def parser():
data
# Out:
# ['../data/train\\talk.religion.misc\\82757',
#  '../data/train\\talk.religion.misc\\82758',
#  '../data/train\\talk.religion.misc\\82759',
#  '../data/train\\talk.religion.misc\\82760',
#  '../data/train\\talk.religion.misc\\82763',
#  '../data/train\\talk.religion.misc\\82766',
#  '../data/train\\talk.religion.misc\\82767',
#  '../data/train\\talk.religion.misc\\82771',
#  '../data/train\\talk.religion.misc\\82772',
#  '../data/train\\talk.religion.misc\\82774',
#  '../data/train\\talk.religion.misc\\82775',
#  '../data/train\\talk.religion.misc\\82776',
#  '../data/train\\talk.religion.misc\\82777',
#  '../data/train\\talk.religion.misc\\82778',
#  '../data/train\\talk.religion.misc\\82779',
#  '../data/train\\talk.religion.misc\\82781',
#  '../data/train\\talk.religion.misc\\82782',
#  '../data/train\\talk.religion.misc\\82783',
#  '../data/train\\talk.religion.misc\\82784',
#  '../data/train\\talk.religion.misc\\82785',
#  '../data/train\\talk.religion.misc\\82786',
#  '../data/train\\talk.religion.misc\\82787',
#  '../data/train\\talk.religion.misc\\82788',
#  '../data/train\\talk.religion.misc\\82792',
#  '../data/train\\talk.religion.misc\\82793',
#  '../data/train\\talk.religion.misc\\82794',
#  '../data/train\\talk.religion.misc\\82795',
#  '../data/train\\talk.religion.misc\\82796',
#  '../data/train\\talk.religion.misc\\82797',
#  '../data/train\\talk.religion.misc\\82798',
#  '../data/train\\talk.religion.misc\\82799',
#  '../data/train\\talk.religion.misc\\82800',
#  '../data/train\\talk.religion.misc\\82801',
#  '../data/train\\talk.religion.misc\\82802',
#  '../data/train\\talk.religion.misc\\82804',
#  '../data/train\\talk.religion.misc\\82806',
#  '../data/train\\talk.religion.misc\\82807',
#  '../data/train\\talk.religion.misc\\82808',
#  '../data/train\\talk.religion.misc\\82810',
#  '../data/train\\talk.religion.misc\\82812',
#  '../data/train\\talk.religion.misc\\82813',
#  '../data/train\\talk.religion.misc\\82814',
#  '../data/train\\talk.religion.misc\\82815',
#  '../data/train\\talk.religion.misc\\82816',
#  '../data/train\\talk.religion.misc\\82818',
#  '../data/train\\talk.religion.misc\\82819',
#  '../data/train\\talk.religion.misc\\83437',
#  '../data/train\\talk.religion.misc\\83438',
#  '../data/train\\talk.religion.misc\\83439',
#  '../data/train\\talk.religion.misc\\83440',
#  '../data/train\\talk.religion.misc\\83441',
#  '../data/train\\talk.religion.misc\\83442',
#  '../data/train\\talk.religion.misc\\83444',
#  '../data/train\\talk.religion.misc\\83445',
#  '../data/train\\talk.religion.misc\\83447',
#  '../data/train\\talk.religion.misc\\83449',
#  '../data/train\\talk.religion.misc\\83450',
#  '../data/train\\talk.religion.misc\\83451',
#  '../data/train\\talk.religion.misc\\83453',
#  '../data/train\\talk.religion.misc\\83454',
#  '../data/train\\talk.religion.misc\\83455',
#  '../data/train\\talk.religion.misc\\83456',
#  '../data/train\\talk.religion.misc\\83457',
#  '../data/train\\talk.religion.misc\\83460',
#  '../data/train\\talk.religion.misc\\83461',
#  '../data/train\\talk.religion.misc\\83463',
#  '../data/train\\talk.religion.misc\\83467',
#  '../data/train\\talk.religion.misc\\83468',
#  '../data/train\\talk.religion.misc\\83469',
#  '../data/train\\talk.religion.misc\\83470',
#  '../data/train\\talk.religion.misc\\83471',
#  '../data/train\\talk.religion.misc\\83472',
#  '../data/train\\talk.religion.misc\\83473',
#  '../data/train\\talk.religion.misc\\83476',
#  '../data/train\\talk.religion.misc\\83477',
#  '../data/train\\talk.religion.misc\\83478',
#  '../data/train\\talk.religion.misc\\83479',
#  '../data/train\\talk.religion.misc\\83481',
#  '../data/train\\talk.religion.misc\\83482',
#  '../data/train\\talk.religion.misc\\83483',
#  '../data/train\\talk.religion.misc\\83484',
#  '../data/train\\talk.religion.misc\\83485',
#  '../data/train\\talk.religion.misc\\83486',
#  '../data/train\\talk.religion.misc\\83487',
#  '../data/train\\talk.religion.misc\\83488',
#  '../data/train\\talk.religion.misc\\83490',
#  '../data/train\\talk.religion.misc\\83491',
#  '../data/train\\talk.religion.misc\\83492',
#  '../data/train\\talk.religion.misc\\83494',
#  '../data/train\\talk.religion.misc\\83495',
#  '../data/train\\talk.religion.misc\\83496',
#  '../data/train\\talk.religion.misc\\83497',
#  '../data/train\\talk.religion.misc\\83498',
#  '../data/train\\talk.religion.misc\\83499',
#  '../data/train\\talk.religion.misc\\83500',
#  '../data/train\\talk.religion.misc\\83501',
#  '../data/train\\talk.religion.misc\\83503',
#  '../data/train\\talk.religion.misc\\83504',
#  '../data/train\\talk.religion.misc\\83505',
#  '../data/train\\talk.religion.misc\\83506',
#  '../data/train\\talk.religion.misc\\83507',
#  '../data/train\\talk.religion.misc\\83508',
#  '../data/train\\talk.religion.misc\\83509',
#  '../data/train\\talk.religion.misc\\83510',
#  '../data/train\\talk.religion.misc\\83511',
#  '../data/train\\talk.religion.misc\\83512',
#  '../data/train\\talk.religion.misc\\83513',
#  '../data/train\\talk.religion.misc\\83514',
#  '../data/train\\talk.religion.misc\\83515',
#  '../data/train\\talk.religion.misc\\83516',
#  '../data/train\\talk.religion.misc\\83517',
#  '../data/train\\talk.religion.misc\\83518',
#  '../data/train\\talk.religion.misc\\83519',
#  '../data/train\\talk.religion.misc\\83520',
#  '../data/train\\talk.religion.misc\\83522',
#  '../data/train\\talk.religion.misc\\83523',
#  '../data/train\\talk.religion.misc\\83524',
#  '../data/train\\talk.religion.misc\\83525',
#  '../data/train\\talk.religion.misc\\83526',
#  '../data/train\\talk.religion.misc\\83527',
#  '../data/train\\talk.religion.misc\\83528',
#  '../data/train\\talk.religion.misc\\83529',
#  '../data/train\\talk.religion.misc\\83535',
#  '../data/train\\talk.religion.misc\\83544',
#  '../data/train\\talk.religion.misc\\83547',
#  '../data/train\\talk.religion.misc\\83558',
#  '../data/train\\talk.religion.misc\\83561',
#  '../data/train\\talk.religion.misc\\83562',
#  '../data/train\\talk.religion.misc\\83568',
#  '../data/train\\talk.religion.misc\\83572',
#  '../data/train\\talk.religion.misc\\83581',
#  '../data/train\\talk.religion.misc\\83582',
#  '../data/train\\talk.religion.misc\\83585',
#  '../data/train\\talk.religion.misc\\83586',
#  '../data/train\\talk.religion.misc\\83587',
#  '../data/train\\talk.religion.misc\\83591',
#  '../data/train\\talk.religion.misc\\83592',
#  '../data/train\\talk.religion.misc\\83593',
#  '../data/train\\talk.religion.misc\\83594',
#  '../data/train\\talk.religion.misc\\83601',
#  '../data/train\\talk.religion.misc\\83602',
#  '../data/train\\talk.religion.misc\\83608',
#  '../data/train\\talk.religion.misc\\83609',
#  '../data/train\\talk.religion.misc\\83610',
#  '../data/train\\talk.religion.misc\\83614',
#  '../data/train\\talk.religion.misc\\83617',
#  '../data/train\\talk.religion.misc\\83620',
#  '../data/train\\talk.religion.misc\\83621',
#  '../data/train\\talk.religion.misc\\83622',
#  '../data/train\\talk.religion.misc\\83623',
#  '../data/train\\talk.religion.misc\\83624',
#  '../data/train\\talk.religion.misc\\83627',
#  '../data/train\\talk.religion.misc\\83629',
#  '../data/train\\talk.religion.misc\\83630',
#  '../data/train\\talk.religion.misc\\83642',
#  '../data/train\\talk.religion.misc\\83643',
#  '../data/train\\talk.religion.misc\\83646',
#  '../data/train\\talk.religion.misc\\83650',
#  '../data/train\\talk.religion.misc\\83651',
#  '../data/train\\talk.religion.misc\\83658',
#  '../data/train\\talk.religion.misc\\83659',
#  '../data/train\\talk.religion.misc\\83660',
#  '../data/train\\talk.religion.misc\\83661',
#  '../data/train\\talk.religion.misc\\83662',
#  '../data/train\\talk.religion.misc\\83668',
#  '../data/train\\talk.religion.misc\\83669',
#  '../data/train\\talk.religion.misc\\83670',
#  '../data/train\\talk.religion.misc\\83671',
#  '../data/train\\talk.religion.misc\\83672',
#  '../data/train\\talk.religion.misc\\83673',
#  '../data/train\\talk.religion.misc\\83674',
#  '../data/train\\talk.religion.misc\\83677',
#  '../data/train\\talk.religion.misc\\83680',
#  '../data/train\\talk.religion.misc\\83681',
#  '../data/train\\talk.religion.misc\\83686',
#  '../data/train\\talk.religion.misc\\83687',
#  '../data/train\\talk.religion.misc\\83688',
#  '../data/train\\talk.religion.misc\\83689',
#  '../data/train\\talk.religion.misc\\83690',
#  '../data/train\\talk.religion.misc\\83691',
#  '../data/train\\talk.religion.misc\\83701',
#  '../data/train\\talk.religion.misc\\83704',
#  '../data/train\\talk.religion.misc\\83705',
#  '../data/train\\talk.religion.misc\\83706',
#  '../data/train\\talk.religion.misc\\83708',
#  '../data/train\\talk.religion.misc\\83711',
#  '../data/train\\talk.religion.misc\\83713',
#  '../data/train\\talk.religion.misc\\83714',
#  '../data/train\\talk.religion.misc\\83719',
#  '../data/train\\talk.religion.misc\\83722',
#  '../data/train\\talk.religion.misc\\83725',
#  '../data/train\\talk.religion.misc\\83727',
#  '../data/train\\talk.religion.misc\\83728',
#  '../data/train\\talk.religion.misc\\83729',
#  '../data/train\\talk.religion.misc\\83732',
#  '../data/train\\talk.religion.misc\\83736',
#  '../data/train\\talk.religion.misc\\83738',
#  '../data/train\\talk.religion.misc\\83740',
#  '../data/train\\talk.religion.misc\\83741',
#  '../data/train\\talk.religion.misc\\83744',
#  '../data/train\\talk.religion.misc\\83745',
#  '../data/train\\talk.religion.misc\\83776',
#  '../data/train\\talk.religion.misc\\83777',
#  '../data/train\\talk.religion.misc\\83781',
#  '../data/train\\talk.religion.misc\\83783',
#  '../data/train\\talk.religion.misc\\83786',
#  '../data/train\\talk.religion.misc\\83788',
#  '../data/train\\talk.religion.misc\\83789',
#  '../data/train\\talk.religion.misc\\83790',
#  '../data/train\\talk.religion.misc\\83795',
#  '../data/train\\talk.religion.misc\\83798',
#  '../data/train\\talk.religion.misc\\83799',
#  '../data/train\\talk.religion.misc\\83800',
#  '../data/train\\talk.religion.misc\\83801',
#  '../data/train\\talk.religion.misc\\83803',
#  '../data/train\\talk.religion.misc\\83805',
#  '../data/train\\talk.religion.misc\\83807',
#  '../data/train\\talk.religion.misc\\83808',
#  '../data/train\\talk.religion.misc\\83811',
#  '../data/train\\talk.religion.misc\\83812',
#  '../data/train\\talk.religion.misc\\83816',
#  '../data/train\\talk.religion.misc\\83817',
#  '../data/train\\talk.religion.misc\\83818',
#  '../data/train\\talk.religion.misc\\83823',
#  '../data/train\\talk.religion.misc\\83827',
#  '../data/train\\talk.religion.misc\\83828',
#  '../data/train\\talk.religion.misc\\83829',
#  '../data/train\\talk.religion.misc\\83830',
#  '../data/train\\talk.religion.misc\\83835',
#  '../data/train\\talk.religion.misc\\83841',
#  '../data/train\\talk.religion.misc\\83842',
#  '../data/train\\talk.religion.misc\\83843',
#  '../data/train\\talk.religion.misc\\83844',
#  '../data/train\\talk.religion.misc\\83845',
#  '../data/train\\talk.religion.misc\\83846',
#  '../data/train\\talk.religion.misc\\83847',
#  '../data/train\\talk.religion.misc\\83848',
#  '../data/train\\talk.religion.misc\\83849',
#  '../data/train\\talk.religion.misc\\83852',
#  '../data/train\\talk.religion.misc\\83855',
#  '../data/train\\talk.religion.misc\\83856',
#  '../data/train\\talk.religion.misc\\83860',
#  '../data/train\\talk.religion.misc\\83863',
#  '../data/train\\talk.religion.misc\\83867',
#  '../data/train\\talk.religion.misc\\83880',
#  '../data/train\\talk.religion.misc\\83882',
#  '../data/train\\talk.religion.misc\\83884',
#  '../data/train\\talk.religion.misc\\83885',
#  '../data/train\\talk.religion.misc\\83891',
#  '../data/train\\talk.religion.misc\\83892',
#  '../data/train\\talk.religion.misc\\83895',
#  '../data/train\\talk.religion.misc\\83897',
#  '../data/train\\talk.religion.misc\\83899',
#  '../data/train\\talk.religion.misc\\83900',
#  '../data/train\\talk.religion.misc\\83901',
#  '../data/train\\talk.religion.misc\\83902',
#  '../data/train\\talk.religion.misc\\83929',
#  '../data/train\\talk.religion.misc\\83932',
#  '../data/train\\talk.religion.misc\\83934',
#  '../data/train\\talk.religion.misc\\83936',
#  '../data/train\\talk.religion.misc\\83957',
#  '../data/train\\talk.religion.misc\\83974',
#  '../data/train\\talk.religion.misc\\83975',
#  '../data/train\\talk.religion.misc\\83985',
#  '../data/train\\talk.religion.misc\\83986',
#  '../data/train\\talk.religion.misc\\83994',
#  '../data/train\\talk.religion.misc\\83995',
#  '../data/train\\talk.religion.misc\\83998',
#  '../data/train\\talk.religion.misc\\83999',
#  '../data/train\\talk.religion.misc\\84004',
#  '../data/train\\talk.religion.misc\\84006',
#  '../data/train\\talk.religion.misc\\84008',
#  '../data/train\\talk.religion.misc\\84009',
#  '../data/train\\talk.religion.misc\\84011',
#  '../data/train\\talk.religion.misc\\84014',
#  '../data/train\\talk.religion.misc\\84021',
#  '../data/train\\talk.religion.misc\\84023',
#  '../data/train\\talk.religion.misc\\84025',
#  '../data/train\\talk.religion.misc\\84033',
#  '../data/train\\talk.religion.misc\\84042',
#  '../data/train\\talk.religion.misc\\84043',
#  '../data/train\\talk.religion.misc\\84047',
#  '../data/train\\talk.religion.misc\\84048',
#  '../data/train\\talk.religion.misc\\84052',
#  '../data/train\\talk.religion.misc\\84054',
#  '../data/train\\talk.religion.misc\\84055',
#  '../data/train\\talk.religion.misc\\84056',
#  '../data/train\\talk.religion.misc\\84067',
#  '../data/train\\talk.religion.misc\\84070',
#  '../data/train\\talk.religion.misc\\84071',
#  '../data/train\\talk.religion.misc\\84072',
#  '../data/train\\talk.religion.misc\\84073',
#  '../data/train\\talk.religion.misc\\84074',
#  '../data/train\\talk.religion.misc\\84076',
#  '../data/train\\talk.religion.misc\\84081',
#  '../data/train\\talk.religion.misc\\84086',
#  '../data/train\\talk.religion.misc\\84087',
#  '../data/train\\talk.religion.misc\\84101',
#  '../data/train\\talk.religion.misc\\84105',
#  '../data/train\\talk.religion.misc\\84106',
#  '../data/train\\talk.religion.misc\\84113',
#  '../data/train\\talk.religion.misc\\84120',
#  '../data/train\\talk.religion.misc\\84122',
#  '../data/train\\talk.religion.misc\\84123',
#  '../data/train\\talk.religion.misc\\84124',
#  '../data/train\\talk.religion.misc\\84125',
#  '../data/train\\talk.religion.misc\\84130',
#  '../data/train\\talk.religion.misc\\84131',
#  '../data/train\\talk.religion.misc\\84132',
#  '../data/train\\talk.religion.misc\\84134',
#  '../data/train\\talk.religion.misc\\84142',
#  '../data/train\\talk.religion.misc\\84143',
#  '../data/train\\talk.religion.misc\\84144',
#  '../data/train\\talk.religion.misc\\84146',
#  '../data/train\\talk.religion.misc\\84147',
#  '../data/train\\talk.religion.misc\\84148',
#  '../data/train\\talk.religion.misc\\84149',
#  '../data/train\\talk.religion.misc\\84150',
#  '../data/train\\talk.religion.misc\\84151',
#  '../data/train\\talk.religion.misc\\84152',
#  '../data/train\\talk.religion.misc\\84153',
#  '../data/train\\talk.religion.misc\\84157',
#  '../data/train\\talk.religion.misc\\84158',
#  '../data/train\\talk.religion.misc\\84164',
#  '../data/train\\talk.religion.misc\\84165',
#  '../data/train\\talk.religion.misc\\84170',
#  '../data/train\\talk.religion.misc\\84174',
#  '../data/train\\talk.religion.misc\\84175',
#  '../data/train\\talk.religion.misc\\84183',
#  '../data/train\\talk.religion.misc\\84184',
#  '../data/train\\talk.religion.misc\\84185',
#  '../data/train\\talk.religion.misc\\84186',
#  '../data/train\\talk.religion.misc\\84187',
#  '../data/train\\talk.religion.misc\\84188',
#  '../data/train\\talk.religion.misc\\84190',
#  '../data/train\\talk.religion.misc\\84195',
#  '../data/train\\talk.religion.misc\\84196',
#  '../data/train\\talk.religion.misc\\84197',
#  '../data/train\\talk.religion.misc\\84198',
#  '../data/train\\talk.religion.misc\\84199',
#  '../data/train\\talk.religion.misc\\84200',
#  '../data/train\\talk.religion.misc\\84201',
#  '../data/train\\talk.religion.misc\\84202',
#  '../data/train\\talk.religion.misc\\84203',
#  '../data/train\\talk.religion.misc\\84226',
#  '../data/train\\talk.religion.misc\\84227',
#  '../data/train\\talk.religion.misc\\84229',
#  '../data/train\\talk.religion.misc\\84230',
#  '../data/train\\talk.religion.misc\\84255',
#  '../data/train\\talk.religion.misc\\84256',
#  '../data/train\\talk.religion.misc\\84257',
#  '../data/train\\talk.religion.misc\\84263',
#  '../data/train\\talk.religion.misc\\84268',
#  '../data/train\\talk.religion.misc\\84308',
#  '../data/train\\talk.religion.misc\\84309',
#  '../data/train\\talk.religion.misc\\84323',
#  '../data/train\\talk.religion.misc\\84324',
#  '../data/train\\talk.religion.misc\\84325',
#  '../data/train\\talk.religion.misc\\84326',
#  '../data/train\\talk.religion.misc\\84327',
#  '../data/train\\talk.religion.misc\\84328',
#  '../data/train\\talk.religion.misc\\84336',
#  '../data/train\\talk.religion.misc\\84357',
#  '../data/train\\talk.religion.misc\\84358',
#  '../data/train\\talk.religion.misc\\84360',
#  '../data/train\\talk.religion.misc\\84396',
#  '../data/train\\talk.religion.misc\\84397',
#  '../data/train\\talk.religion.misc\\84398',
#  '../data/train\\talk.religion.misc\\84399',
#  '../data/train\\talk.religion.misc\\84422',
#  '../data/train\\talk.religion.misc\\84431',
#  '../data/train\\talk.religion.misc\\84443',
#  '../data/train\\talk.religion.misc\\84444',
#  '../data/train\\talk.religion.misc\\84445',
#  '../data/train\\talk.religion.misc\\84446',
#  '../data/train\\talk.religion.misc\\84507',
#  '../data/train\\talk.religion.misc\\84558']

# %%
pd.data
# Out:
# ['../data/train\\talk.religion.misc\\82757',
#  '../data/train\\talk.religion.misc\\82758',
#  '../data/train\\talk.religion.misc\\82759',
#  '../data/train\\talk.religion.misc\\82760',
#  '../data/train\\talk.religion.misc\\82763',
#  '../data/train\\talk.religion.misc\\82766',
#  '../data/train\\talk.religion.misc\\82767',
#  '../data/train\\talk.religion.misc\\82771',
#  '../data/train\\talk.religion.misc\\82772',
#  '../data/train\\talk.religion.misc\\82774',
#  '../data/train\\talk.religion.misc\\82775',
#  '../data/train\\talk.religion.misc\\82776',
#  '../data/train\\talk.religion.misc\\82777',
#  '../data/train\\talk.religion.misc\\82778',
#  '../data/train\\talk.religion.misc\\82779',
#  '../data/train\\talk.religion.misc\\82781',
#  '../data/train\\talk.religion.misc\\82782',
#  '../data/train\\talk.religion.misc\\82783',
#  '../data/train\\talk.religion.misc\\82784',
#  '../data/train\\talk.religion.misc\\82785',
#  '../data/train\\talk.religion.misc\\82786',
#  '../data/train\\talk.religion.misc\\82787',
#  '../data/train\\talk.religion.misc\\82788',
#  '../data/train\\talk.religion.misc\\82792',
#  '../data/train\\talk.religion.misc\\82793',
#  '../data/train\\talk.religion.misc\\82794',
#  '../data/train\\talk.religion.misc\\82795',
#  '../data/train\\talk.religion.misc\\82796',
#  '../data/train\\talk.religion.misc\\82797',
#  '../data/train\\talk.religion.misc\\82798',
#  '../data/train\\talk.religion.misc\\82799',
#  '../data/train\\talk.religion.misc\\82800',
#  '../data/train\\talk.religion.misc\\82801',
#  '../data/train\\talk.religion.misc\\82802',
#  '../data/train\\talk.religion.misc\\82804',
#  '../data/train\\talk.religion.misc\\82806',
#  '../data/train\\talk.religion.misc\\82807',
#  '../data/train\\talk.religion.misc\\82808',
#  '../data/train\\talk.religion.misc\\82810',
#  '../data/train\\talk.religion.misc\\82812',
#  '../data/train\\talk.religion.misc\\82813',
#  '../data/train\\talk.religion.misc\\82814',
#  '../data/train\\talk.religion.misc\\82815',
#  '../data/train\\talk.religion.misc\\82816',
#  '../data/train\\talk.religion.misc\\82818',
#  '../data/train\\talk.religion.misc\\82819',
#  '../data/train\\talk.religion.misc\\83437',
#  '../data/train\\talk.religion.misc\\83438',
#  '../data/train\\talk.religion.misc\\83439',
#  '../data/train\\talk.religion.misc\\83440',
#  '../data/train\\talk.religion.misc\\83441',
#  '../data/train\\talk.religion.misc\\83442',
#  '../data/train\\talk.religion.misc\\83444',
#  '../data/train\\talk.religion.misc\\83445',
#  '../data/train\\talk.religion.misc\\83447',
#  '../data/train\\talk.religion.misc\\83449',
#  '../data/train\\talk.religion.misc\\83450',
#  '../data/train\\talk.religion.misc\\83451',
#  '../data/train\\talk.religion.misc\\83453',
#  '../data/train\\talk.religion.misc\\83454',
#  '../data/train\\talk.religion.misc\\83455',
#  '../data/train\\talk.religion.misc\\83456',
#  '../data/train\\talk.religion.misc\\83457',
#  '../data/train\\talk.religion.misc\\83460',
#  '../data/train\\talk.religion.misc\\83461',
#  '../data/train\\talk.religion.misc\\83463',
#  '../data/train\\talk.religion.misc\\83467',
#  '../data/train\\talk.religion.misc\\83468',
#  '../data/train\\talk.religion.misc\\83469',
#  '../data/train\\talk.religion.misc\\83470',
#  '../data/train\\talk.religion.misc\\83471',
#  '../data/train\\talk.religion.misc\\83472',
#  '../data/train\\talk.religion.misc\\83473',
#  '../data/train\\talk.religion.misc\\83476',
#  '../data/train\\talk.religion.misc\\83477',
#  '../data/train\\talk.religion.misc\\83478',
#  '../data/train\\talk.religion.misc\\83479',
#  '../data/train\\talk.religion.misc\\83481',
#  '../data/train\\talk.religion.misc\\83482',
#  '../data/train\\talk.religion.misc\\83483',
#  '../data/train\\talk.religion.misc\\83484',
#  '../data/train\\talk.religion.misc\\83485',
#  '../data/train\\talk.religion.misc\\83486',
#  '../data/train\\talk.religion.misc\\83487',
#  '../data/train\\talk.religion.misc\\83488',
#  '../data/train\\talk.religion.misc\\83490',
#  '../data/train\\talk.religion.misc\\83491',
#  '../data/train\\talk.religion.misc\\83492',
#  '../data/train\\talk.religion.misc\\83494',
#  '../data/train\\talk.religion.misc\\83495',
#  '../data/train\\talk.religion.misc\\83496',
#  '../data/train\\talk.religion.misc\\83497',
#  '../data/train\\talk.religion.misc\\83498',
#  '../data/train\\talk.religion.misc\\83499',
#  '../data/train\\talk.religion.misc\\83500',
#  '../data/train\\talk.religion.misc\\83501',
#  '../data/train\\talk.religion.misc\\83503',
#  '../data/train\\talk.religion.misc\\83504',
#  '../data/train\\talk.religion.misc\\83505',
#  '../data/train\\talk.religion.misc\\83506',
#  '../data/train\\talk.religion.misc\\83507',
#  '../data/train\\talk.religion.misc\\83508',
#  '../data/train\\talk.religion.misc\\83509',
#  '../data/train\\talk.religion.misc\\83510',
#  '../data/train\\talk.religion.misc\\83511',
#  '../data/train\\talk.religion.misc\\83512',
#  '../data/train\\talk.religion.misc\\83513',
#  '../data/train\\talk.religion.misc\\83514',
#  '../data/train\\talk.religion.misc\\83515',
#  '../data/train\\talk.religion.misc\\83516',
#  '../data/train\\talk.religion.misc\\83517',
#  '../data/train\\talk.religion.misc\\83518',
#  '../data/train\\talk.religion.misc\\83519',
#  '../data/train\\talk.religion.misc\\83520',
#  '../data/train\\talk.religion.misc\\83522',
#  '../data/train\\talk.religion.misc\\83523',
#  '../data/train\\talk.religion.misc\\83524',
#  '../data/train\\talk.religion.misc\\83525',
#  '../data/train\\talk.religion.misc\\83526',
#  '../data/train\\talk.religion.misc\\83527',
#  '../data/train\\talk.religion.misc\\83528',
#  '../data/train\\talk.religion.misc\\83529',
#  '../data/train\\talk.religion.misc\\83535',
#  '../data/train\\talk.religion.misc\\83544',
#  '../data/train\\talk.religion.misc\\83547',
#  '../data/train\\talk.religion.misc\\83558',
#  '../data/train\\talk.religion.misc\\83561',
#  '../data/train\\talk.religion.misc\\83562',
#  '../data/train\\talk.religion.misc\\83568',
#  '../data/train\\talk.religion.misc\\83572',
#  '../data/train\\talk.religion.misc\\83581',
#  '../data/train\\talk.religion.misc\\83582',
#  '../data/train\\talk.religion.misc\\83585',
#  '../data/train\\talk.religion.misc\\83586',
#  '../data/train\\talk.religion.misc\\83587',
#  '../data/train\\talk.religion.misc\\83591',
#  '../data/train\\talk.religion.misc\\83592',
#  '../data/train\\talk.religion.misc\\83593',
#  '../data/train\\talk.religion.misc\\83594',
#  '../data/train\\talk.religion.misc\\83601',
#  '../data/train\\talk.religion.misc\\83602',
#  '../data/train\\talk.religion.misc\\83608',
#  '../data/train\\talk.religion.misc\\83609',
#  '../data/train\\talk.religion.misc\\83610',
#  '../data/train\\talk.religion.misc\\83614',
#  '../data/train\\talk.religion.misc\\83617',
#  '../data/train\\talk.religion.misc\\83620',
#  '../data/train\\talk.religion.misc\\83621',
#  '../data/train\\talk.religion.misc\\83622',
#  '../data/train\\talk.religion.misc\\83623',
#  '../data/train\\talk.religion.misc\\83624',
#  '../data/train\\talk.religion.misc\\83627',
#  '../data/train\\talk.religion.misc\\83629',
#  '../data/train\\talk.religion.misc\\83630',
#  '../data/train\\talk.religion.misc\\83642',
#  '../data/train\\talk.religion.misc\\83643',
#  '../data/train\\talk.religion.misc\\83646',
#  '../data/train\\talk.religion.misc\\83650',
#  '../data/train\\talk.religion.misc\\83651',
#  '../data/train\\talk.religion.misc\\83658',
#  '../data/train\\talk.religion.misc\\83659',
#  '../data/train\\talk.religion.misc\\83660',
#  '../data/train\\talk.religion.misc\\83661',
#  '../data/train\\talk.religion.misc\\83662',
#  '../data/train\\talk.religion.misc\\83668',
#  '../data/train\\talk.religion.misc\\83669',
#  '../data/train\\talk.religion.misc\\83670',
#  '../data/train\\talk.religion.misc\\83671',
#  '../data/train\\talk.religion.misc\\83672',
#  '../data/train\\talk.religion.misc\\83673',
#  '../data/train\\talk.religion.misc\\83674',
#  '../data/train\\talk.religion.misc\\83677',
#  '../data/train\\talk.religion.misc\\83680',
#  '../data/train\\talk.religion.misc\\83681',
#  '../data/train\\talk.religion.misc\\83686',
#  '../data/train\\talk.religion.misc\\83687',
#  '../data/train\\talk.religion.misc\\83688',
#  '../data/train\\talk.religion.misc\\83689',
#  '../data/train\\talk.religion.misc\\83690',
#  '../data/train\\talk.religion.misc\\83691',
#  '../data/train\\talk.religion.misc\\83701',
#  '../data/train\\talk.religion.misc\\83704',
#  '../data/train\\talk.religion.misc\\83705',
#  '../data/train\\talk.religion.misc\\83706',
#  '../data/train\\talk.religion.misc\\83708',
#  '../data/train\\talk.religion.misc\\83711',
#  '../data/train\\talk.religion.misc\\83713',
#  '../data/train\\talk.religion.misc\\83714',
#  '../data/train\\talk.religion.misc\\83719',
#  '../data/train\\talk.religion.misc\\83722',
#  '../data/train\\talk.religion.misc\\83725',
#  '../data/train\\talk.religion.misc\\83727',
#  '../data/train\\talk.religion.misc\\83728',
#  '../data/train\\talk.religion.misc\\83729',
#  '../data/train\\talk.religion.misc\\83732',
#  '../data/train\\talk.religion.misc\\83736',
#  '../data/train\\talk.religion.misc\\83738',
#  '../data/train\\talk.religion.misc\\83740',
#  '../data/train\\talk.religion.misc\\83741',
#  '../data/train\\talk.religion.misc\\83744',
#  '../data/train\\talk.religion.misc\\83745',
#  '../data/train\\talk.religion.misc\\83776',
#  '../data/train\\talk.religion.misc\\83777',
#  '../data/train\\talk.religion.misc\\83781',
#  '../data/train\\talk.religion.misc\\83783',
#  '../data/train\\talk.religion.misc\\83786',
#  '../data/train\\talk.religion.misc\\83788',
#  '../data/train\\talk.religion.misc\\83789',
#  '../data/train\\talk.religion.misc\\83790',
#  '../data/train\\talk.religion.misc\\83795',
#  '../data/train\\talk.religion.misc\\83798',
#  '../data/train\\talk.religion.misc\\83799',
#  '../data/train\\talk.religion.misc\\83800',
#  '../data/train\\talk.religion.misc\\83801',
#  '../data/train\\talk.religion.misc\\83803',
#  '../data/train\\talk.religion.misc\\83805',
#  '../data/train\\talk.religion.misc\\83807',
#  '../data/train\\talk.religion.misc\\83808',
#  '../data/train\\talk.religion.misc\\83811',
#  '../data/train\\talk.religion.misc\\83812',
#  '../data/train\\talk.religion.misc\\83816',
#  '../data/train\\talk.religion.misc\\83817',
#  '../data/train\\talk.religion.misc\\83818',
#  '../data/train\\talk.religion.misc\\83823',
#  '../data/train\\talk.religion.misc\\83827',
#  '../data/train\\talk.religion.misc\\83828',
#  '../data/train\\talk.religion.misc\\83829',
#  '../data/train\\talk.religion.misc\\83830',
#  '../data/train\\talk.religion.misc\\83835',
#  '../data/train\\talk.religion.misc\\83841',
#  '../data/train\\talk.religion.misc\\83842',
#  '../data/train\\talk.religion.misc\\83843',
#  '../data/train\\talk.religion.misc\\83844',
#  '../data/train\\talk.religion.misc\\83845',
#  '../data/train\\talk.religion.misc\\83846',
#  '../data/train\\talk.religion.misc\\83847',
#  '../data/train\\talk.religion.misc\\83848',
#  '../data/train\\talk.religion.misc\\83849',
#  '../data/train\\talk.religion.misc\\83852',
#  '../data/train\\talk.religion.misc\\83855',
#  '../data/train\\talk.religion.misc\\83856',
#  '../data/train\\talk.religion.misc\\83860',
#  '../data/train\\talk.religion.misc\\83863',
#  '../data/train\\talk.religion.misc\\83867',
#  '../data/train\\talk.religion.misc\\83880',
#  '../data/train\\talk.religion.misc\\83882',
#  '../data/train\\talk.religion.misc\\83884',
#  '../data/train\\talk.religion.misc\\83885',
#  '../data/train\\talk.religion.misc\\83891',
#  '../data/train\\talk.religion.misc\\83892',
#  '../data/train\\talk.religion.misc\\83895',
#  '../data/train\\talk.religion.misc\\83897',
#  '../data/train\\talk.religion.misc\\83899',
#  '../data/train\\talk.religion.misc\\83900',
#  '../data/train\\talk.religion.misc\\83901',
#  '../data/train\\talk.religion.misc\\83902',
#  '../data/train\\talk.religion.misc\\83929',
#  '../data/train\\talk.religion.misc\\83932',
#  '../data/train\\talk.religion.misc\\83934',
#  '../data/train\\talk.religion.misc\\83936',
#  '../data/train\\talk.religion.misc\\83957',
#  '../data/train\\talk.religion.misc\\83974',
#  '../data/train\\talk.religion.misc\\83975',
#  '../data/train\\talk.religion.misc\\83985',
#  '../data/train\\talk.religion.misc\\83986',
#  '../data/train\\talk.religion.misc\\83994',
#  '../data/train\\talk.religion.misc\\83995',
#  '../data/train\\talk.religion.misc\\83998',
#  '../data/train\\talk.religion.misc\\83999',
#  '../data/train\\talk.religion.misc\\84004',
#  '../data/train\\talk.religion.misc\\84006',
#  '../data/train\\talk.religion.misc\\84008',
#  '../data/train\\talk.religion.misc\\84009',
#  '../data/train\\talk.religion.misc\\84011',
#  '../data/train\\talk.religion.misc\\84014',
#  '../data/train\\talk.religion.misc\\84021',
#  '../data/train\\talk.religion.misc\\84023',
#  '../data/train\\talk.religion.misc\\84025',
#  '../data/train\\talk.religion.misc\\84033',
#  '../data/train\\talk.religion.misc\\84042',
#  '../data/train\\talk.religion.misc\\84043',
#  '../data/train\\talk.religion.misc\\84047',
#  '../data/train\\talk.religion.misc\\84048',
#  '../data/train\\talk.religion.misc\\84052',
#  '../data/train\\talk.religion.misc\\84054',
#  '../data/train\\talk.religion.misc\\84055',
#  '../data/train\\talk.religion.misc\\84056',
#  '../data/train\\talk.religion.misc\\84067',
#  '../data/train\\talk.religion.misc\\84070',
#  '../data/train\\talk.religion.misc\\84071',
#  '../data/train\\talk.religion.misc\\84072',
#  '../data/train\\talk.religion.misc\\84073',
#  '../data/train\\talk.religion.misc\\84074',
#  '../data/train\\talk.religion.misc\\84076',
#  '../data/train\\talk.religion.misc\\84081',
#  '../data/train\\talk.religion.misc\\84086',
#  '../data/train\\talk.religion.misc\\84087',
#  '../data/train\\talk.religion.misc\\84101',
#  '../data/train\\talk.religion.misc\\84105',
#  '../data/train\\talk.religion.misc\\84106',
#  '../data/train\\talk.religion.misc\\84113',
#  '../data/train\\talk.religion.misc\\84120',
#  '../data/train\\talk.religion.misc\\84122',
#  '../data/train\\talk.religion.misc\\84123',
#  '../data/train\\talk.religion.misc\\84124',
#  '../data/train\\talk.religion.misc\\84125',
#  '../data/train\\talk.religion.misc\\84130',
#  '../data/train\\talk.religion.misc\\84131',
#  '../data/train\\talk.religion.misc\\84132',
#  '../data/train\\talk.religion.misc\\84134',
#  '../data/train\\talk.religion.misc\\84142',
#  '../data/train\\talk.religion.misc\\84143',
#  '../data/train\\talk.religion.misc\\84144',
#  '../data/train\\talk.religion.misc\\84146',
#  '../data/train\\talk.religion.misc\\84147',
#  '../data/train\\talk.religion.misc\\84148',
#  '../data/train\\talk.religion.misc\\84149',
#  '../data/train\\talk.religion.misc\\84150',
#  '../data/train\\talk.religion.misc\\84151',
#  '../data/train\\talk.religion.misc\\84152',
#  '../data/train\\talk.religion.misc\\84153',
#  '../data/train\\talk.religion.misc\\84157',
#  '../data/train\\talk.religion.misc\\84158',
#  '../data/train\\talk.religion.misc\\84164',
#  '../data/train\\talk.religion.misc\\84165',
#  '../data/train\\talk.religion.misc\\84170',
#  '../data/train\\talk.religion.misc\\84174',
#  '../data/train\\talk.religion.misc\\84175',
#  '../data/train\\talk.religion.misc\\84183',
#  '../data/train\\talk.religion.misc\\84184',
#  '../data/train\\talk.religion.misc\\84185',
#  '../data/train\\talk.religion.misc\\84186',
#  '../data/train\\talk.religion.misc\\84187',
#  '../data/train\\talk.religion.misc\\84188',
#  '../data/train\\talk.religion.misc\\84190',
#  '../data/train\\talk.religion.misc\\84195',
#  '../data/train\\talk.religion.misc\\84196',
#  '../data/train\\talk.religion.misc\\84197',
#  '../data/train\\talk.religion.misc\\84198',
#  '../data/train\\talk.religion.misc\\84199',
#  '../data/train\\talk.religion.misc\\84200',
#  '../data/train\\talk.religion.misc\\84201',
#  '../data/train\\talk.religion.misc\\84202',
#  '../data/train\\talk.religion.misc\\84203',
#  '../data/train\\talk.religion.misc\\84226',
#  '../data/train\\talk.religion.misc\\84227',
#  '../data/train\\talk.religion.misc\\84229',
#  '../data/train\\talk.religion.misc\\84230',
#  '../data/train\\talk.religion.misc\\84255',
#  '../data/train\\talk.religion.misc\\84256',
#  '../data/train\\talk.religion.misc\\84257',
#  '../data/train\\talk.religion.misc\\84263',
#  '../data/train\\talk.religion.misc\\84268',
#  '../data/train\\talk.religion.misc\\84308',
#  '../data/train\\talk.religion.misc\\84309',
#  '../data/train\\talk.religion.misc\\84323',
#  '../data/train\\talk.religion.misc\\84324',
#  '../data/train\\talk.religion.misc\\84325',
#  '../data/train\\talk.religion.misc\\84326',
#  '../data/train\\talk.religion.misc\\84327',
#  '../data/train\\talk.religion.misc\\84328',
#  '../data/train\\talk.religion.misc\\84336',
#  '../data/train\\talk.religion.misc\\84357',
#  '../data/train\\talk.religion.misc\\84358',
#  '../data/train\\talk.religion.misc\\84360',
#  '../data/train\\talk.religion.misc\\84396',
#  '../data/train\\talk.religion.misc\\84397',
#  '../data/train\\talk.religion.misc\\84398',
#  '../data/train\\talk.religion.misc\\84399',
#  '../data/train\\talk.religion.misc\\84422',
#  '../data/train\\talk.religion.misc\\84431',
#  '../data/train\\talk.religion.misc\\84443',
#  '../data/train\\talk.religion.misc\\84444',
#  '../data/train\\talk.religion.misc\\84445',
#  '../data/train\\talk.religion.misc\\84446',
#  '../data/train\\talk.religion.misc\\84507',
#  '../data/train\\talk.religion.misc\\84558']
