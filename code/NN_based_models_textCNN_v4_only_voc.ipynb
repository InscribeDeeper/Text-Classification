# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TextCNN" data-toc-modified-id="TextCNN-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TextCNN</a></span><ul class="toc-item"><li><span><a href="#notes:" data-toc-modified-id="notes:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>notes:</a></span></li></ul></li><li><span><a href="#LSTM" data-toc-modified-id="LSTM-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>LSTM</a></span></li></ul></div>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Text-Classification/code")
# !pip install pyLDAvis
# !pip install gensim
# !pip install pandas==1.3.0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.4)
# Requirement already satisfied: pandas==1.3.0 in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.0) (1.15.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import numpy as np 
from sklearn import metrics
from classification_utils import *
from clustering_utils import *
from eda_utils import *
from nn_utils_keras import *
from feature_engineering_utils import *

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

####################################
### string normalized
####################################
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
train, test = load_data()
train, upsampling_info = upsampling_train(train)

train_text, train_label = train_augmentation(train, select_comb=[ ['reply', 'reference_one'], ['Subject', 'reference_one', 'reference_two']])
# train_text, train_label = train_augmentation(train, select_comb=None)
test_text, test_label = test['text'], test['label']

test_text = test_text.apply(lambda x: extract_stem_voc(x))
train_text = train_text.apply(lambda x: extract_stem_voc(x))
# Out:
# may use cols:
#  ['global_index', 'doc_path', 'label', 'reply', 'reference_one', 'reference_two', 'tag_reply', 'tag_reference_one', 'tag_reference_two', 'Subject', 'From', 'Lines', 'Organization', 'contained_emails', 'long_string', 'text', 'error_message']
# combination 1 train:  ['reply', 'reference_one']
# combination 2 train:  ['Subject', 'reference_one', 'reference_two']

# %%
####################################
### label mapper
####################################
labels = sorted(train_label.unique())
label_mapper = dict(zip(labels, range(len(labels))))
train_label = train_label.map(label_mapper)
test_label = test_label.map(label_mapper)
y_train = train_label
y_test = test_label

print(train_text.shape)
print(test_text.shape)
print(train_label.shape)
print(test_label.shape)
print(labels)
# Out:
# (23626,)
# (7761,)
# (23626,)
# (7761,)
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']

# %%
####################################
### hyper params 
####################################
filters = '"#$%&()*+,-/:;<=>@[\\]^_`{|}~\t\n0123465789!.?\''
MAX_NB_WORDS_ratio = 0.98
MAX_DOC_LEN_ratio = 0.999
MAX_NB_WORDS = eda_MAX_NB_WORDS(train_text, ratio=MAX_NB_WORDS_ratio, char_level=False, filters=filters)
MAX_DOC_LEN = eda_MAX_DOC_LEN(train_text, ratio=MAX_DOC_LEN_ratio, char_level=False, filters=filters)
# Out:
# Cut index with 98.0 % of corpus:  3064
#
#     index  word   count
# 0      11   the  167552
# 1      19    to   83073
# 2      13    of   73182
# 3      48   and   65681
# 4      17    is   48926
# 5      43  that   47346
# 6      93    in   43902
# 7      69    it   35136
# 8       2   you   32380
# 9      22   for   31601
# 10     20    be   25027
# 11     34  have   22662
# 12     57   are   22248
# 13    122    on   21873
# 14     44   not   20938
# 15     31  with   19834
# 16     95    as   17287
# 17    214    wa   15582
# 18     66  they   15539
# 19    403   but   15473
# Cut index with 99.9 % of corpus:  3756

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Embedding, Dense, Conv1D, MaxPooling1D, Dropout, Activation, Input, Flatten, Concatenate, Lambda
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow import keras
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

# %% [markdown]
# # TextCNN

# %% [markdown]
# ## notes:

# %%
####################################
### train val test split
####################################
X_train_val, y_train_val, X_test, y_test = train_text, train_label, test_text, test_label
X_train, x_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, stratify=y_train_val)

####################################
### preprocessor for NN input
####################################
processor = text_preprocessor(MAX_DOC_LEN, MAX_NB_WORDS, train_text, filters='"#$%&()*+,-/:;<=>@[\\]^_`{|}~\t\n')
X_train = processor.generate_seq(X_train)
x_val = processor.generate_seq(x_val)
X_test = processor.generate_seq(X_test)
# y_train = to_categorical(y_train)
# y_val = to_categorical(y_val)
# y_test = to_categorical(y_test)


print('Shape of x_tr: ' + str(X_train.shape))
print('Shape of y_tr: ' + str(y_train.shape))
print('Shape of x_val: ' + str(x_val.shape))
print('Shape of y_val: ' + str(y_val.shape))
print('Shape of X_test: ' + str(X_test.shape))
print('Shape of y_test: ' + str(y_test.shape))


info = pd.concat([y_train.value_counts(), y_val.value_counts(), y_val.value_counts()/y_train.value_counts(), y_train.value_counts()/y_train.size\
                 , y_test.value_counts(), y_test.value_counts()/y_test.size], axis=1)
info.index = labels
info.columns = ['tr_size', 'val_size', 'val_ratio', 'tr_prop', 'test_size', 'test_prop']
info
# Out:
# Shape of x_tr: (18900, 3756)
# Shape of y_tr: (18900,)
# Shape of x_val: (4726, 3756)
# Shape of y_val: (4726,)
# Shape of X_test: (7761, 3756)
# Shape of y_test: (7761,)
#                           tr_size  val_size  ...  test_size  test_prop
# alt.atheism                   886       222  ...        319   0.041103
# comp.graphics                 934       234  ...        389   0.050122
# comp.os.ms-windows.misc       946       236  ...        394   0.050767
# comp.sys.ibm.pc.hardware      944       236  ...        392   0.050509
# comp.sys.mac.hardware         925       231  ...        385   0.049607
# comp.windows.x                949       237  ...        395   0.050896
# misc.forsale                  936       234  ...        390   0.050251
# rec.autos                     949       237  ...        395   0.050896
# rec.motorcycles               957       239  ...        398   0.051282
# rec.sport.baseball            955       239  ...        397   0.051153
# rec.sport.hockey              886       222  ...        827   0.106558
# sci.crypt                     952       238  ...        396   0.051024
# sci.electronics               946       236  ...        393   0.050638
# sci.med                      1267       317  ...        198   0.025512
# sci.space                     949       237  ...        394   0.050767
# soc.religion.christian        958       240  ...        398   0.051282
# talk.politics.guns            886       222  ...        364   0.046901
# talk.politics.mideast         902       226  ...        376   0.048447
# talk.politics.misc            886       222  ...        310   0.039943
# talk.religion.misc            887       221  ...        251   0.032341
#
# [20 rows x 6 columns]

# %%
# define Model for classification

def model_Create(FS, NF, EMB, MDL, MNW, PWV=None, optimizer='RMSprop', trainable_switch=True):
    cnn_box = cnn_model_l2(FILTER_SIZES=FS, MAX_NB_WORDS=MNW, MAX_DOC_LEN=MDL, EMBEDDING_DIM=EMB,
                        NUM_FILTERS=NF, PRETRAINED_WORD_VECTOR=PWV, trainable_switch=trainable_switch)
    # Hyperparameters: MAX_DOC_LEN
    q1_input = Input(shape=(MDL,), name='q1_input')
    encode_input1 = cnn_box(q1_input)
    # half_features = int(len(FS)*NF/2)*10
    x = Dense(384, activation='relu', name='half_features')(encode_input1)
    x = Dropout(rate=0.3, name='dropout1')(x)
#     x = Dense(256, activation='relu', name='dense1')(x)
#     x = Dropout(rate=0.3, name='dropou2')(x)
    x = Dense(128, activation='relu', name='dense2')(x)
    x = Dropout(rate=0.3, name='dropout3')(x)
    x = Dense(64, activation='relu', name='dense3')(x)
    x = Dropout(rate=0.3, name='dropout4')(x)
    pred = Dense(len(labels), activation='softmax', name='Prediction')(x)
    model = Model(inputs=q1_input, outputs=pred)
    model.compile(optimizer=optimizer,
                  loss=keras.losses.SparseCategoricalCrossentropy(),
                  metrics=[keras.metrics.SparseCategoricalAccuracy()])
    return model


EMBEDDING_DIM = 200
# W2V =  processor.w2v_pretrain(EMBEDDING_DIM, min_count=2, seed=1, cbow_mean=1,negative=5, window=20, workers=7) # pretrain w2v by gensim
# W2V = processor.load_glove_w2v(EMBEDDING_DIM) # download glove
W2V = None
trainable_switch = True

# %%
# Set hyper parameters
FILTER_SIZES = [2, 4,6,8]
# FILTER_SIZES = [2,3,4]
NUM_FILTERS = 64

# OPT = optimizers.Adam(learning_rate=0.005)
OPT = optimizers.RMSprop(learning_rate=0.0005) # 'RMSprop'
PWV = W2V
model = model_Create(FS=FILTER_SIZES, NF=NUM_FILTERS, EMB=EMBEDDING_DIM,
                     MDL=MAX_DOC_LEN, MNW=MAX_NB_WORDS+1, PWV=PWV, 
                     optimizer=OPT, trainable_switch=trainable_switch)

# %%
# visual_textCNN(model)

# %%
BATCH_SIZE = 32 # 先在小的batch上train, 容易找到全局最优部分, 然后再到 大 batch 上train, 快速收敛到局部最优
NUM_EPOCHES = 50  # 20步以上
patience = 30

file_name = 'test'
BestModel_Name = file_name + 'Best_GS_3'
BEST_MODEL_FILEPATH = BestModel_Name
# model.load_weights(BestModel_Name) # 这样就能接着上次train

earlyStopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=patience, verbose=1, mode='max') # patience: number of epochs with no improvement on monitor : val_loss
checkpoint = ModelCheckpoint(BEST_MODEL_FILEPATH, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
# history = model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
history = model.fit(X_train, y_train, validation_data=(x_val, y_val), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
model.load_weights(BestModel_Name)
# Out:
# Epoch 1/50
# 591/591 [==============================] - ETA: 0s - loss: 2.8191 - sparse_categorical_accuracy: 0.0850
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.15404, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 49s 79ms/step - loss: 2.8191 - sparse_categorical_accuracy: 0.0850 - val_loss: 2.4849 - val_sparse_categorical_accuracy: 0.1540
# Epoch 2/50
# 590/591 [============================>.] - ETA: 0s - loss: 2.3831 - sparse_categorical_accuracy: 0.1673
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.15404 to 0.24418, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 2.3832 - sparse_categorical_accuracy: 0.1674 - val_loss: 2.0896 - val_sparse_categorical_accuracy: 0.2442
# Epoch 3/50
# 590/591 [============================>.] - ETA: 0s - loss: 1.9483 - sparse_categorical_accuracy: 0.2900
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.24418 to 0.39632, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 46s 78ms/step - loss: 1.9478 - sparse_categorical_accuracy: 0.2901 - val_loss: 1.7221 - val_sparse_categorical_accuracy: 0.3963
# Epoch 4/50
# 591/591 [==============================] - ETA: 0s - loss: 1.5474 - sparse_categorical_accuracy: 0.4353
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.39632 to 0.55544, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 1.5474 - sparse_categorical_accuracy: 0.4353 - val_loss: 1.3844 - val_sparse_categorical_accuracy: 0.5554
# Epoch 5/50
# 590/591 [============================>.] - ETA: 0s - loss: 1.1995 - sparse_categorical_accuracy: 0.5948
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.55544 to 0.65743, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 1.1995 - sparse_categorical_accuracy: 0.5948 - val_loss: 1.1679 - val_sparse_categorical_accuracy: 0.6574
# Epoch 6/50
# 591/591 [==============================] - ETA: 0s - loss: 0.9292 - sparse_categorical_accuracy: 0.6989
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.65743 to 0.67922, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 46s 78ms/step - loss: 0.9292 - sparse_categorical_accuracy: 0.6989 - val_loss: 1.1597 - val_sparse_categorical_accuracy: 0.6792
# Epoch 7/50
# 591/591 [==============================] - ETA: 0s - loss: 0.7456 - sparse_categorical_accuracy: 0.7673
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.67922
# 591/591 [==============================] - 42s 72ms/step - loss: 0.7456 - sparse_categorical_accuracy: 0.7673 - val_loss: 1.3425 - val_sparse_categorical_accuracy: 0.6443
# Epoch 8/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.6273 - sparse_categorical_accuracy: 0.8066
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.67922 to 0.70821, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 45s 77ms/step - loss: 0.6272 - sparse_categorical_accuracy: 0.8066 - val_loss: 1.1926 - val_sparse_categorical_accuracy: 0.7082
# Epoch 9/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.5261 - sparse_categorical_accuracy: 0.8436
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.70821 to 0.71667, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 46s 78ms/step - loss: 0.5263 - sparse_categorical_accuracy: 0.8435 - val_loss: 1.2540 - val_sparse_categorical_accuracy: 0.7167
# Epoch 10/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.4631 - sparse_categorical_accuracy: 0.8646
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.71667 to 0.72471, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 46s 79ms/step - loss: 0.4629 - sparse_categorical_accuracy: 0.8648 - val_loss: 1.3270 - val_sparse_categorical_accuracy: 0.7247
# Epoch 11/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.4163 - sparse_categorical_accuracy: 0.8812
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.72471
# 591/591 [==============================] - 42s 72ms/step - loss: 0.4160 - sparse_categorical_accuracy: 0.8813 - val_loss: 1.4095 - val_sparse_categorical_accuracy: 0.7247
# Epoch 12/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.3734 - sparse_categorical_accuracy: 0.8960
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.72471 to 0.73339, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 0.3732 - sparse_categorical_accuracy: 0.8961 - val_loss: 1.5300 - val_sparse_categorical_accuracy: 0.7334
# Epoch 13/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.3475 - sparse_categorical_accuracy: 0.9039
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.73339
# 591/591 [==============================] - 42s 72ms/step - loss: 0.3477 - sparse_categorical_accuracy: 0.9039 - val_loss: 1.6649 - val_sparse_categorical_accuracy: 0.7289
# Epoch 14/50
# 591/591 [==============================] - ETA: 0s - loss: 0.3196 - sparse_categorical_accuracy: 0.9104
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.73339 to 0.73402, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 46s 79ms/step - loss: 0.3196 - sparse_categorical_accuracy: 0.9104 - val_loss: 1.5997 - val_sparse_categorical_accuracy: 0.7340
# Epoch 15/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.3166 - sparse_categorical_accuracy: 0.9129
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.73402 to 0.74228, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 80ms/step - loss: 0.3163 - sparse_categorical_accuracy: 0.9130 - val_loss: 1.6846 - val_sparse_categorical_accuracy: 0.7423
# Epoch 16/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2992 - sparse_categorical_accuracy: 0.9223
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.74228 to 0.74249, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 0.2993 - sparse_categorical_accuracy: 0.9223 - val_loss: 1.9885 - val_sparse_categorical_accuracy: 0.7425
# Epoch 17/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2919 - sparse_categorical_accuracy: 0.9224
# Epoch 00017: val_sparse_categorical_accuracy improved from 0.74249 to 0.75074, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 80ms/step - loss: 0.2918 - sparse_categorical_accuracy: 0.9224 - val_loss: 1.6470 - val_sparse_categorical_accuracy: 0.7507
# Epoch 18/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2701 - sparse_categorical_accuracy: 0.9288
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.75074
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2701 - sparse_categorical_accuracy: 0.9288 - val_loss: 1.7219 - val_sparse_categorical_accuracy: 0.7467
# Epoch 19/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2649 - sparse_categorical_accuracy: 0.9290
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.75074
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2649 - sparse_categorical_accuracy: 0.9290 - val_loss: 1.8692 - val_sparse_categorical_accuracy: 0.7505
# Epoch 20/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2560 - sparse_categorical_accuracy: 0.9331
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.75074
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2559 - sparse_categorical_accuracy: 0.9331 - val_loss: 2.0706 - val_sparse_categorical_accuracy: 0.7442
# Epoch 21/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2493 - sparse_categorical_accuracy: 0.9362
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.75074
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2493 - sparse_categorical_accuracy: 0.9362 - val_loss: 1.9807 - val_sparse_categorical_accuracy: 0.7433
# Epoch 22/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2559 - sparse_categorical_accuracy: 0.9356
# Epoch 00022: val_sparse_categorical_accuracy improved from 0.75074 to 0.75307, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 0.2557 - sparse_categorical_accuracy: 0.9357 - val_loss: 1.6878 - val_sparse_categorical_accuracy: 0.7531
# Epoch 23/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2427 - sparse_categorical_accuracy: 0.9374
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2428 - sparse_categorical_accuracy: 0.9374 - val_loss: 1.9426 - val_sparse_categorical_accuracy: 0.7450
# Epoch 24/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2391 - sparse_categorical_accuracy: 0.9370
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2398 - sparse_categorical_accuracy: 0.9368 - val_loss: 1.7787 - val_sparse_categorical_accuracy: 0.7486
# Epoch 25/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2351 - sparse_categorical_accuracy: 0.9403
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2351 - sparse_categorical_accuracy: 0.9403 - val_loss: 1.9202 - val_sparse_categorical_accuracy: 0.7490
# Epoch 26/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2359 - sparse_categorical_accuracy: 0.9404
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2359 - sparse_categorical_accuracy: 0.9404 - val_loss: 1.8481 - val_sparse_categorical_accuracy: 0.7459
# Epoch 27/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2327 - sparse_categorical_accuracy: 0.9412
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2325 - sparse_categorical_accuracy: 0.9412 - val_loss: 2.2237 - val_sparse_categorical_accuracy: 0.7399
# Epoch 28/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2395 - sparse_categorical_accuracy: 0.9415
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2395 - sparse_categorical_accuracy: 0.9415 - val_loss: 2.4683 - val_sparse_categorical_accuracy: 0.7402
# Epoch 29/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2286 - sparse_categorical_accuracy: 0.9425
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2286 - sparse_categorical_accuracy: 0.9425 - val_loss: 2.6292 - val_sparse_categorical_accuracy: 0.7478
# Epoch 30/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2370 - sparse_categorical_accuracy: 0.9428
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2368 - sparse_categorical_accuracy: 0.9428 - val_loss: 1.9913 - val_sparse_categorical_accuracy: 0.7514
# Epoch 31/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2280 - sparse_categorical_accuracy: 0.9423
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.75307
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2280 - sparse_categorical_accuracy: 0.9423 - val_loss: 2.1674 - val_sparse_categorical_accuracy: 0.7465
# Epoch 32/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2285 - sparse_categorical_accuracy: 0.9428
# Epoch 00032: val_sparse_categorical_accuracy improved from 0.75307 to 0.75497, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 0.2285 - sparse_categorical_accuracy: 0.9428 - val_loss: 2.1344 - val_sparse_categorical_accuracy: 0.7550
# Epoch 33/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2463 - sparse_categorical_accuracy: 0.9427
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.75497
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2463 - sparse_categorical_accuracy: 0.9427 - val_loss: 2.4013 - val_sparse_categorical_accuracy: 0.7416
# Epoch 34/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2402 - sparse_categorical_accuracy: 0.9456
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.75497
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2405 - sparse_categorical_accuracy: 0.9454 - val_loss: 2.4689 - val_sparse_categorical_accuracy: 0.7338
# Epoch 35/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2434 - sparse_categorical_accuracy: 0.9420
# Epoch 00035: val_sparse_categorical_accuracy improved from 0.75497 to 0.75751, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 591/591 [==============================] - 47s 79ms/step - loss: 0.2434 - sparse_categorical_accuracy: 0.9420 - val_loss: 2.1327 - val_sparse_categorical_accuracy: 0.7575
# Epoch 36/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2297 - sparse_categorical_accuracy: 0.9451
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 73ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9450 - val_loss: 2.3230 - val_sparse_categorical_accuracy: 0.7374
# Epoch 37/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2336 - sparse_categorical_accuracy: 0.9442
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2336 - sparse_categorical_accuracy: 0.9442 - val_loss: 2.5940 - val_sparse_categorical_accuracy: 0.7469
# Epoch 38/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2396 - sparse_categorical_accuracy: 0.9461
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2399 - sparse_categorical_accuracy: 0.9461 - val_loss: 2.5736 - val_sparse_categorical_accuracy: 0.7516
# Epoch 39/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2336 - sparse_categorical_accuracy: 0.9457
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2336 - sparse_categorical_accuracy: 0.9457 - val_loss: 2.3300 - val_sparse_categorical_accuracy: 0.7493
# Epoch 40/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2484 - sparse_categorical_accuracy: 0.9436
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2484 - sparse_categorical_accuracy: 0.9436 - val_loss: 2.4421 - val_sparse_categorical_accuracy: 0.7419
# Epoch 41/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2315 - sparse_categorical_accuracy: 0.9442
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2312 - sparse_categorical_accuracy: 0.9443 - val_loss: 3.0416 - val_sparse_categorical_accuracy: 0.7482
# Epoch 42/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2463 - sparse_categorical_accuracy: 0.9444
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2463 - sparse_categorical_accuracy: 0.9444 - val_loss: 3.1767 - val_sparse_categorical_accuracy: 0.7374
# Epoch 43/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2557 - sparse_categorical_accuracy: 0.9434
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2596 - sparse_categorical_accuracy: 0.9434 - val_loss: 3.1816 - val_sparse_categorical_accuracy: 0.7129
# Epoch 44/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2392 - sparse_categorical_accuracy: 0.9439
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2391 - sparse_categorical_accuracy: 0.9439 - val_loss: 2.5997 - val_sparse_categorical_accuracy: 0.7497
# Epoch 45/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2380 - sparse_categorical_accuracy: 0.9440
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2379 - sparse_categorical_accuracy: 0.9440 - val_loss: 3.1948 - val_sparse_categorical_accuracy: 0.7406
# Epoch 46/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2435 - sparse_categorical_accuracy: 0.9443
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9444 - val_loss: 3.1182 - val_sparse_categorical_accuracy: 0.7416
# Epoch 47/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2651 - sparse_categorical_accuracy: 0.9436
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 73ms/step - loss: 0.2651 - sparse_categorical_accuracy: 0.9436 - val_loss: 3.2995 - val_sparse_categorical_accuracy: 0.7438
# Epoch 48/50
# 591/591 [==============================] - ETA: 0s - loss: 0.2632 - sparse_categorical_accuracy: 0.9431
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 73ms/step - loss: 0.2632 - sparse_categorical_accuracy: 0.9431 - val_loss: 3.2701 - val_sparse_categorical_accuracy: 0.7378
# Epoch 49/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2473 - sparse_categorical_accuracy: 0.9451
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 73ms/step - loss: 0.2473 - sparse_categorical_accuracy: 0.9450 - val_loss: 2.8668 - val_sparse_categorical_accuracy: 0.7446
# Epoch 50/50
# 590/591 [============================>.] - ETA: 0s - loss: 0.2689 - sparse_categorical_accuracy: 0.9433
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.75751
# 591/591 [==============================] - 43s 72ms/step - loss: 0.2686 - sparse_categorical_accuracy: 0.9434 - val_loss: 3.4102 - val_sparse_categorical_accuracy: 0.7484

# %%
#### classification Report
history_plot(history)
y_pred = model.predict(X_test)
# print(classification_report(y_test, np.argmax(y_pred, axis=1)))
print(classification_report(test_label, np.argmax(y_pred, axis=1), target_names=labels))
scores = model.evaluate(X_test, y_test, verbose=2)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print( "\n\n\n")
# Out:
# ========================================================================
# loss val_loss
# ========================================================================
# sparse_categorical_accuracy val_sparse_categorical_accuracy
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.51      0.33      0.40       319
#            comp.graphics       0.46      0.44      0.45       389
#  comp.os.ms-windows.misc       0.59      0.48      0.53       394
# comp.sys.ibm.pc.hardware       0.55      0.43      0.48       392
#    comp.sys.mac.hardware       0.57      0.48      0.52       385
#           comp.windows.x       0.49      0.54      0.52       395
#             misc.forsale       0.55      0.66      0.60       390
#                rec.autos       0.72      0.61      0.66       395
#          rec.motorcycles       0.72      0.80      0.76       398
#       rec.sport.baseball       0.61      0.74      0.67       397
#         rec.sport.hockey       0.93      0.72      0.81       827
#                sci.crypt       0.83      0.79      0.81       396
#          sci.electronics       0.50      0.40      0.44       393
#                  sci.med       0.38      0.75      0.51       198
#                sci.space       0.70      0.79      0.74       394
#   soc.religion.christian       0.54      0.61      0.57       398
#       talk.politics.guns       0.62      0.64      0.63       364
#    talk.politics.mideast       0.44      0.73      0.55       376
#       talk.politics.misc       0.47      0.43      0.45       310
#       talk.religion.misc       0.38      0.26      0.31       251
#
#                 accuracy                           0.59      7761
#                macro avg       0.58      0.58      0.57      7761
#             weighted avg       0.61      0.59      0.59      7761
#
# 243/243 - 4s - loss: 5.8294 - sparse_categorical_accuracy: 0.5941 - 4s/epoch - 15ms/step
# sparse_categorical_accuracy: 59.41%

# %% [markdown]
# # LSTM

# %%
# from tensorflow.keras.layers import SpatialDropout1D, GlobalMaxPooling1D, GlobalMaxPooling2D

# def model_Create(FS, NF, EMB, MDL, MNW, PWV = None, optimizer='RMSprop', trainable_switch=True):
#     model = Sequential()
#     model.add(Embedding(input_dim=MNW, output_dim=EMB, embeddings_initializer='uniform', mask_zero=True, input_length=MDL))
#     model.add(Flatten())   
# #     model.add(GlobalMaxPooling2D()) # downsampling
# #     model.add(SpatialDropout1D(0.2))    
#     model.add(Dense(1024, activation='relu'))   
#     model.add(Dense(512, activation='relu'))   
#     model.add(Dense(128, activation='relu'))   
#     model.add(Dense(64, activation='relu'))   
#     # model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
#     model.add(Dense(20, activation='softmax'))   
#     model.compile(optimizer=optimizer,
#           loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False), 
#           metrics=[keras.metrics.SparseCategoricalAccuracy()])
#     return model

# model = model_Create(FS=FILTER_SIZES, NF=NUM_FILTERS, EMB=EMBEDDING_DIM,
#                      MDL=MAX_DOC_LEN, MNW=MAX_NB_WORDS+1, PWV=PWV, trainable_switch=trainable_switch)

# %%
# visual_textCNN(model)

# %%
# EMBEDDING_DIM = 200
# # W2V =  processor.w2v_pretrain(EMBEDDING_DIM, min_count=2, seed=1, cbow_mean=1,negative=5, window=20, workers=7) # pretrain w2v by gensim
# # W2V = processor.load_glove_w2v(EMBEDDING_DIM) # download glove
# trainable_switch = True
# W2V = None

# %%
# BATCH_SIZE = 64
# NUM_EPOCHES = 10  # patience=20
# patience = 30

# BestModel_Name = 'text_CNN.h5'
# BEST_MODEL_FILEPATH = BestModel_Name

# earlyStopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=patience, verbose=1, mode='max') # patience: number of epochs with no improvement on monitor : val_loss
# checkpoint = ModelCheckpoint(BEST_MODEL_FILEPATH, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
# history = model.fit(X_train, y_train, validation_split=0.2, batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
# model.load_weights(BestModel_Name)

# %%
# #### classification Report
# history_plot(history)
# y_pred = model.predict(X_test)
# # print(classification_report(y_test, np.argmax(y_pred, axis=1)))
# print(classification_report(test_label, np.argmax(y_pred, axis=1), target_names=labels))
# scores = model.evaluate(X_test, y_test, verbose=2)
# print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# print( "\n\n\n")
