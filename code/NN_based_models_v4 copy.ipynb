# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TextCNN" data-toc-modified-id="TextCNN-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TextCNN</a></span><ul class="toc-item"><li><span><a href="#notes:" data-toc-modified-id="notes:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>notes:</a></span></li></ul></li><li><span><a href="#LSTM" data-toc-modified-id="LSTM-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>LSTM</a></span></li></ul></div>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Text-Classification/code")
# !pip install pyLDAvis
# !pip install gensim
# !pip install pandas==1.3.0
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.4)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.4)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: pandas==1.3.0 in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.0) (1.15.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import numpy as np 
from sklearn import metrics
from clustering_utils import *
from eda_utils import *
from nn_utils_keras import *
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

####################################
### string normalized
####################################


from gensim.utils import tokenize
from nltk.tokenize import word_tokenize
from gensim.parsing.preprocessing import remove_stopwords

def normal_string(x):
    x = remove_stopwords(x)
#     x = " ".join(preprocess_string(x))
    x = " ".join(word_tokenize(x, preserve_line=False)).strip()
    return x
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
train, test = load_data()
train, upsampling_info = upsampling_train(train)

train_text, train_label = train_augmentation(train, select_comb=[['text'], ['reply', 'reference_one'], ['Subject', 'reference_one', 'reference_two']])
# train_text, train_label = train_augmentation(train, select_comb=None)
test_text, test_label = test['text'], test['label']

# test_text = test_text.apply(lambda x: normal_string(x))
# train_text = train_text.apply(lambda x: normal_string(x))
# Out:
# may use cols:
#  ['global_index', 'doc_path', 'label', 'reply', 'reference_one', 'reference_two', 'tag_reply', 'tag_reference_one', 'tag_reference_two', 'Subject', 'From', 'Lines', 'Organization', 'contained_emails', 'long_string', 'text', 'error_message']
# combination 1 train:  ['text']
# combination 2 train:  ['reply', 'reference_one']
# combination 3 train:  ['reference_one', 'reference_two']

# %%
####################################
### label mapper
####################################
labels = sorted(train_label.unique())
label_mapper = dict(zip(labels, range(len(labels))))
train_label = train_label.map(label_mapper)
test_label = test_label.map(label_mapper)
y_train = train_label
y_test = test_label

print(train_text.shape)
print(test_text.shape)
print(train_label.shape)
print(test_label.shape)
print(labels)
# Out:
# (35439,)
# (7761,)
# (35439,)
# (7761,)
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']

# %%
####################################
### hyper params 
####################################
filters = '"#$%&()*+,-/:;<=>@[\\]^_`{|}~\t\n0123465789!.?\''
MAX_NB_WORDS_ratio = 0.98
MAX_DOC_LEN_ratio = 0.999
MAX_NB_WORDS = eda_MAX_NB_WORDS(train_text, ratio=MAX_NB_WORDS_ratio, char_level=False, filters=filters)
MAX_DOC_LEN = eda_MAX_DOC_LEN(train_text, ratio=MAX_DOC_LEN_ratio, char_level=False, filters=filters)
# Out:
# Cut index with 98.0 % of corpus:  32073
#
#     index  word   count
# 0      44   the  318554
# 1      33    to  162317
# 2      17    of  145697
# 3      56     a  141788
# 4      75   and  125298
# 5      49     i  116295
# 6      31    in   99783
# 7      84    is   96479
# 8     137  that   88946
# 9      83    it   74681
# 10  13970    ax   62833
# 11     39   you   60779
# 12     53   for   60064
# 13    156     s   48171
# 14    163     t   44469
# 15     63  this   44362
# 16    139    on   43825
# 17     86    be   42023
# 18     76   are   41727
# 19    165   not   40279
# Cut index with 99.9 % of corpus:  8110

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Embedding, Dense, Conv1D, MaxPooling1D, Dropout, Activation, Input, Flatten, Concatenate, Lambda
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow import keras
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

# %% [markdown]
# # TextCNN

# %% [markdown]
# ## notes:

# %%
####################################
### train val test split
####################################
X_train_val, y_train_val, X_test, y_test = train_text, train_label, test_text, test_label
X_train, x_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, stratify=y_train_val)

####################################
### preprocessor for NN input
####################################
processor = text_preprocessor(MAX_DOC_LEN, MAX_NB_WORDS, train_text, filters='"#$%&()*+,-/:;<=>@[\\]^_`{|}~\t\n0123465789')
X_train = processor.generate_seq(X_train)
x_val = processor.generate_seq(x_val)
X_test = processor.generate_seq(X_test)
# y_train = to_categorical(y_train)
# y_val = to_categorical(y_val)
# y_test = to_categorical(y_test)


print('Shape of x_tr: ' + str(X_train.shape))
print('Shape of y_tr: ' + str(y_train.shape))
print('Shape of x_val: ' + str(x_val.shape))
print('Shape of y_val: ' + str(y_val.shape))
print('Shape of X_test: ' + str(X_test.shape))
print('Shape of y_test: ' + str(y_test.shape))


info = pd.concat([y_train.value_counts(), y_val.value_counts(), y_val.value_counts()/y_train.value_counts(), y_train.value_counts()/y_train.size\
                 , y_test.value_counts(), y_test.value_counts()/y_test.size], axis=1)
info.index = labels
info.columns = ['tr_size', 'val_size', 'val_ratio', 'tr_prop', 'test_size', 'test_prop']
info
# Out:
# Shape of x_tr: (28351, 8110)
# Shape of y_tr: (28351,)
# Shape of x_val: (7088, 8110)
# Shape of y_val: (7088,)
# Shape of X_test: (7761, 8110)
# Shape of y_test: (7761,)
#                           tr_size  val_size  ...  test_size  test_prop
# alt.atheism                  1330       332  ...        319   0.041103
# comp.graphics                1401       351  ...        389   0.050122
# comp.os.ms-windows.misc      1418       355  ...        394   0.050767
# comp.sys.ibm.pc.hardware     1416       354  ...        392   0.050509
# comp.sys.mac.hardware        1387       347  ...        385   0.049607
# comp.windows.x               1423       356  ...        395   0.050896
# misc.forsale                 1404       351  ...        390   0.050251
# rec.autos                    1423       356  ...        395   0.050896
# rec.motorcycles              1435       359  ...        398   0.051282
# rec.sport.baseball           1433       358  ...        397   0.051153
# rec.sport.hockey             1330       332  ...        827   0.106558
# sci.crypt                    1428       357  ...        396   0.051024
# sci.electronics              1418       355  ...        393   0.050638
# sci.med                      1901       475  ...        198   0.025512
# sci.space                    1423       356  ...        394   0.050767
# soc.religion.christian       1437       360  ...        398   0.051282
# talk.politics.guns           1330       332  ...        364   0.046901
# talk.politics.mideast        1354       338  ...        376   0.048447
# talk.politics.misc           1330       332  ...        310   0.039943
# talk.religion.misc           1330       332  ...        251   0.032341
#
# [20 rows x 6 columns]

# %%
# define Model for classification

def model_Create(FS, NF, EMB, MDL, MNW, PWV=None, optimizer='RMSprop', trainable_switch=True):
    cnn_box = cnn_model_l2(FILTER_SIZES=FS, MAX_NB_WORDS=MNW, MAX_DOC_LEN=MDL, EMBEDDING_DIM=EMB,
                        NUM_FILTERS=NF, PRETRAINED_WORD_VECTOR=PWV, trainable_switch=trainable_switch)
    # Hyperparameters: MAX_DOC_LEN
    q1_input = Input(shape=(MDL,), name='q1_input')
    encode_input1 = cnn_box(q1_input)
    # half_features = int(len(FS)*NF/2)*10
    x = Dense(384, activation='relu', name='half_features')(encode_input1)
    x = Dropout(rate=0.3, name='dropout1')(x)
#     x = Dense(256, activation='relu', name='dense1')(x)
#     x = Dropout(rate=0.3, name='dropou2')(x)
    x = Dense(128, activation='relu', name='dense2')(x)
    x = Dropout(rate=0.3, name='dropout3')(x)
    x = Dense(64, activation='relu', name='dense3')(x)
    x = Dropout(rate=0.3, name='dropout4')(x)
    pred = Dense(len(labels), activation='softmax', name='Prediction')(x)
    model = Model(inputs=q1_input, outputs=pred)
    model.compile(optimizer=optimizer,
                  loss=keras.losses.SparseCategoricalCrossentropy(),
                  metrics=[keras.metrics.SparseCategoricalAccuracy()])
    return model


EMBEDDING_DIM = 200
# W2V =  processor.w2v_pretrain(EMBEDDING_DIM, min_count=2, seed=1, cbow_mean=1,negative=5, window=20, workers=7) # pretrain w2v by gensim
# W2V = processor.load_glove_w2v(EMBEDDING_DIM) # download glove
W2V = None
trainable_switch = True

# %%
# Set hyper parameters
FILTER_SIZES = [2, 4,6,8]
# FILTER_SIZES = [2,3,4]
NUM_FILTERS = 64

# OPT = optimizers.Adam(learning_rate=0.005)
OPT = optimizers.RMSprop(learning_rate=0.0005) # 'RMSprop'
PWV = W2V
model = model_Create(FS=FILTER_SIZES, NF=NUM_FILTERS, EMB=EMBEDDING_DIM,
                     MDL=MAX_DOC_LEN, MNW=MAX_NB_WORDS+1, PWV=PWV, 
                     optimizer=OPT, trainable_switch=trainable_switch)

# %%
# visual_textCNN(model)

# %%
BATCH_SIZE = 32 # 先在小的batch上train, 容易找到全局最优部分, 然后再到 大 batch 上train, 快速收敛到局部最优
NUM_EPOCHES = 50  # 20步以上
patience = 30

file_name = 'test'
BestModel_Name = file_name + 'Best_GS_3'
BEST_MODEL_FILEPATH = BestModel_Name
# model.load_weights(BestModel_Name) # 这样就能接着上次train

earlyStopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=patience, verbose=1, mode='max') # patience: number of epochs with no improvement on monitor : val_loss
checkpoint = ModelCheckpoint(BEST_MODEL_FILEPATH, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
# history = model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
history = model.fit(X_train, y_train, validation_data=(x_val, y_val), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
model.load_weights(BestModel_Name)
# Out:
# Epoch 1/50
# 886/886 [==============================] - ETA: 0s - loss: 2.7386 - sparse_categorical_accuracy: 0.1011
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.19498, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 132s 145ms/step - loss: 2.7386 - sparse_categorical_accuracy: 0.1011 - val_loss: 2.2609 - val_sparse_categorical_accuracy: 0.1950
# Epoch 2/50
# 886/886 [==============================] - ETA: 0s - loss: 2.1327 - sparse_categorical_accuracy: 0.2177
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.19498 to 0.34834, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 128s 144ms/step - loss: 2.1327 - sparse_categorical_accuracy: 0.2177 - val_loss: 1.7831 - val_sparse_categorical_accuracy: 0.3483
# Epoch 3/50
# 886/886 [==============================] - ETA: 0s - loss: 1.6777 - sparse_categorical_accuracy: 0.3676
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.34834 to 0.52963, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 128s 145ms/step - loss: 1.6777 - sparse_categorical_accuracy: 0.3676 - val_loss: 1.3878 - val_sparse_categorical_accuracy: 0.5296
# Epoch 4/50
# 886/886 [==============================] - ETA: 0s - loss: 1.2428 - sparse_categorical_accuracy: 0.5631
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.52963 to 0.65491, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 128s 144ms/step - loss: 1.2428 - sparse_categorical_accuracy: 0.5631 - val_loss: 1.0750 - val_sparse_categorical_accuracy: 0.6549
# Epoch 5/50
# 886/886 [==============================] - ETA: 0s - loss: 0.9061 - sparse_categorical_accuracy: 0.7063
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.65491 to 0.71416, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 129s 146ms/step - loss: 0.9061 - sparse_categorical_accuracy: 0.7063 - val_loss: 0.9279 - val_sparse_categorical_accuracy: 0.7142
# Epoch 6/50
# 886/886 [==============================] - ETA: 0s - loss: 0.7092 - sparse_categorical_accuracy: 0.7799
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.71416 to 0.77032, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 128s 145ms/step - loss: 0.7092 - sparse_categorical_accuracy: 0.7799 - val_loss: 0.8043 - val_sparse_categorical_accuracy: 0.7703
# Epoch 7/50
# 886/886 [==============================] - ETA: 0s - loss: 0.6070 - sparse_categorical_accuracy: 0.8147
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.77032 to 0.78386, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 129s 145ms/step - loss: 0.6070 - sparse_categorical_accuracy: 0.8147 - val_loss: 0.7680 - val_sparse_categorical_accuracy: 0.7839
# Epoch 8/50
# 886/886 [==============================] - ETA: 0s - loss: 0.5538 - sparse_categorical_accuracy: 0.8348
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.78386
# 886/886 [==============================] - 124s 140ms/step - loss: 0.5538 - sparse_categorical_accuracy: 0.8348 - val_loss: 0.8818 - val_sparse_categorical_accuracy: 0.7779
# Epoch 9/50
# 886/886 [==============================] - ETA: 0s - loss: 0.5221 - sparse_categorical_accuracy: 0.8436
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.78386 to 0.78612, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 128s 145ms/step - loss: 0.5221 - sparse_categorical_accuracy: 0.8436 - val_loss: 0.8725 - val_sparse_categorical_accuracy: 0.7861
# Epoch 10/50
# 886/886 [==============================] - ETA: 0s - loss: 0.5016 - sparse_categorical_accuracy: 0.8502
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.78612 to 0.80008, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 129s 145ms/step - loss: 0.5016 - sparse_categorical_accuracy: 0.8502 - val_loss: 0.8317 - val_sparse_categorical_accuracy: 0.8001
# Epoch 11/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4887 - sparse_categorical_accuracy: 0.8548
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.80008
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4887 - sparse_categorical_accuracy: 0.8548 - val_loss: 0.8831 - val_sparse_categorical_accuracy: 0.7974
# Epoch 12/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4820 - sparse_categorical_accuracy: 0.8575
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.80008
# 886/886 [==============================] - 128s 144ms/step - loss: 0.4820 - sparse_categorical_accuracy: 0.8575 - val_loss: 0.8975 - val_sparse_categorical_accuracy: 0.7960
# Epoch 13/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4743 - sparse_categorical_accuracy: 0.8583
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.80008 to 0.80488, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 132s 149ms/step - loss: 0.4743 - sparse_categorical_accuracy: 0.8583 - val_loss: 0.8179 - val_sparse_categorical_accuracy: 0.8049
# Epoch 14/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4747 - sparse_categorical_accuracy: 0.8616
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.80488 to 0.80940, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 128s 144ms/step - loss: 0.4747 - sparse_categorical_accuracy: 0.8616 - val_loss: 0.7978 - val_sparse_categorical_accuracy: 0.8094
# Epoch 15/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4625 - sparse_categorical_accuracy: 0.8637
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.80940
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4625 - sparse_categorical_accuracy: 0.8637 - val_loss: 0.8906 - val_sparse_categorical_accuracy: 0.8050
# Epoch 16/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4609 - sparse_categorical_accuracy: 0.8642
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.80940
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4609 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.8553 - val_sparse_categorical_accuracy: 0.8093
# Epoch 17/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4642 - sparse_categorical_accuracy: 0.8646
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.80940
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4642 - sparse_categorical_accuracy: 0.8646 - val_loss: 0.9108 - val_sparse_categorical_accuracy: 0.8015
# Epoch 18/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4534 - sparse_categorical_accuracy: 0.8669
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.80940
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4534 - sparse_categorical_accuracy: 0.8669 - val_loss: 0.9714 - val_sparse_categorical_accuracy: 0.8052
# Epoch 19/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4561 - sparse_categorical_accuracy: 0.8671
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.80940
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4561 - sparse_categorical_accuracy: 0.8671 - val_loss: 1.0322 - val_sparse_categorical_accuracy: 0.8047
# Epoch 20/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4603 - sparse_categorical_accuracy: 0.8670
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.80940
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4603 - sparse_categorical_accuracy: 0.8670 - val_loss: 1.0289 - val_sparse_categorical_accuracy: 0.8036
# Epoch 21/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4665 - sparse_categorical_accuracy: 0.8660
# Epoch 00021: val_sparse_categorical_accuracy improved from 0.80940 to 0.81067, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 129s 145ms/step - loss: 0.4665 - sparse_categorical_accuracy: 0.8660 - val_loss: 0.8301 - val_sparse_categorical_accuracy: 0.8107
# Epoch 22/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4531 - sparse_categorical_accuracy: 0.8681
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.81067
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4531 - sparse_categorical_accuracy: 0.8681 - val_loss: 0.8828 - val_sparse_categorical_accuracy: 0.8105
# Epoch 23/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4462 - sparse_categorical_accuracy: 0.8687
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.81067
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4462 - sparse_categorical_accuracy: 0.8687 - val_loss: 0.9909 - val_sparse_categorical_accuracy: 0.8100
# Epoch 24/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4482 - sparse_categorical_accuracy: 0.8678
# Epoch 00024: val_sparse_categorical_accuracy improved from 0.81067 to 0.81363, saving model to testBest_GS_3
# INFO:tensorflow:Assets written to: testBest_GS_3/assets
# 886/886 [==============================] - 129s 146ms/step - loss: 0.4482 - sparse_categorical_accuracy: 0.8678 - val_loss: 0.8927 - val_sparse_categorical_accuracy: 0.8136
# Epoch 25/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4528 - sparse_categorical_accuracy: 0.8686
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4528 - sparse_categorical_accuracy: 0.8686 - val_loss: 0.8777 - val_sparse_categorical_accuracy: 0.8105
# Epoch 26/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4584 - sparse_categorical_accuracy: 0.8677
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4584 - sparse_categorical_accuracy: 0.8677 - val_loss: 0.9456 - val_sparse_categorical_accuracy: 0.8070
# Epoch 27/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4549 - sparse_categorical_accuracy: 0.8689
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4549 - sparse_categorical_accuracy: 0.8689 - val_loss: 0.9368 - val_sparse_categorical_accuracy: 0.8060
# Epoch 28/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4592 - sparse_categorical_accuracy: 0.8686
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4592 - sparse_categorical_accuracy: 0.8686 - val_loss: 1.1202 - val_sparse_categorical_accuracy: 0.8098
# Epoch 29/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4576 - sparse_categorical_accuracy: 0.8682
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4576 - sparse_categorical_accuracy: 0.8682 - val_loss: 0.9753 - val_sparse_categorical_accuracy: 0.8080
# Epoch 30/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4461 - sparse_categorical_accuracy: 0.8686
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4461 - sparse_categorical_accuracy: 0.8686 - val_loss: 0.9938 - val_sparse_categorical_accuracy: 0.8078
# Epoch 31/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4540 - sparse_categorical_accuracy: 0.8687
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4540 - sparse_categorical_accuracy: 0.8687 - val_loss: 1.0172 - val_sparse_categorical_accuracy: 0.8050
# Epoch 32/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4581 - sparse_categorical_accuracy: 0.8689
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4581 - sparse_categorical_accuracy: 0.8689 - val_loss: 1.0934 - val_sparse_categorical_accuracy: 0.8012
# Epoch 33/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4638 - sparse_categorical_accuracy: 0.8674
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 139ms/step - loss: 0.4638 - sparse_categorical_accuracy: 0.8674 - val_loss: 0.9535 - val_sparse_categorical_accuracy: 0.8023
# Epoch 34/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4636 - sparse_categorical_accuracy: 0.8689
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 123s 139ms/step - loss: 0.4636 - sparse_categorical_accuracy: 0.8689 - val_loss: 0.9623 - val_sparse_categorical_accuracy: 0.8088
# Epoch 35/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4782 - sparse_categorical_accuracy: 0.8679
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4782 - sparse_categorical_accuracy: 0.8679 - val_loss: 0.9308 - val_sparse_categorical_accuracy: 0.8019
# Epoch 36/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4714 - sparse_categorical_accuracy: 0.8678
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 123s 139ms/step - loss: 0.4714 - sparse_categorical_accuracy: 0.8678 - val_loss: 1.0370 - val_sparse_categorical_accuracy: 0.8032
# Epoch 37/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4708 - sparse_categorical_accuracy: 0.8680
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4708 - sparse_categorical_accuracy: 0.8680 - val_loss: 1.0986 - val_sparse_categorical_accuracy: 0.8071
# Epoch 38/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4747 - sparse_categorical_accuracy: 0.8684
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4747 - sparse_categorical_accuracy: 0.8684 - val_loss: 0.9459 - val_sparse_categorical_accuracy: 0.8083
# Epoch 39/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4815 - sparse_categorical_accuracy: 0.8688
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4815 - sparse_categorical_accuracy: 0.8688 - val_loss: 1.0245 - val_sparse_categorical_accuracy: 0.7949
# Epoch 40/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4817 - sparse_categorical_accuracy: 0.8684
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 139ms/step - loss: 0.4817 - sparse_categorical_accuracy: 0.8684 - val_loss: 0.9657 - val_sparse_categorical_accuracy: 0.8056
# Epoch 41/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4640 - sparse_categorical_accuracy: 0.8690
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4640 - sparse_categorical_accuracy: 0.8690 - val_loss: 0.9818 - val_sparse_categorical_accuracy: 0.8015
# Epoch 42/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4950 - sparse_categorical_accuracy: 0.8674
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4950 - sparse_categorical_accuracy: 0.8674 - val_loss: 1.0501 - val_sparse_categorical_accuracy: 0.7957
# Epoch 43/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4735 - sparse_categorical_accuracy: 0.8684
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4735 - sparse_categorical_accuracy: 0.8684 - val_loss: 1.2838 - val_sparse_categorical_accuracy: 0.7985
# Epoch 44/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4629 - sparse_categorical_accuracy: 0.8692
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4629 - sparse_categorical_accuracy: 0.8692 - val_loss: 1.0397 - val_sparse_categorical_accuracy: 0.8021
# Epoch 45/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4999 - sparse_categorical_accuracy: 0.8692
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 139ms/step - loss: 0.4999 - sparse_categorical_accuracy: 0.8692 - val_loss: 1.0415 - val_sparse_categorical_accuracy: 0.8063
# Epoch 46/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4848 - sparse_categorical_accuracy: 0.8695
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 128s 145ms/step - loss: 0.4848 - sparse_categorical_accuracy: 0.8695 - val_loss: 1.1176 - val_sparse_categorical_accuracy: 0.8083
# Epoch 47/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4525 - sparse_categorical_accuracy: 0.8698
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4525 - sparse_categorical_accuracy: 0.8698 - val_loss: 1.1286 - val_sparse_categorical_accuracy: 0.8064
# Epoch 48/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4629 - sparse_categorical_accuracy: 0.8692
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4629 - sparse_categorical_accuracy: 0.8692 - val_loss: 0.9835 - val_sparse_categorical_accuracy: 0.8073
# Epoch 49/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4681 - sparse_categorical_accuracy: 0.8690
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 124s 140ms/step - loss: 0.4681 - sparse_categorical_accuracy: 0.8690 - val_loss: 1.1369 - val_sparse_categorical_accuracy: 0.7990
# Epoch 50/50
# 886/886 [==============================] - ETA: 0s - loss: 0.4995 - sparse_categorical_accuracy: 0.8682
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.81363
# 886/886 [==============================] - 128s 144ms/step - loss: 0.4995 - sparse_categorical_accuracy: 0.8682 - val_loss: 1.2548 - val_sparse_categorical_accuracy: 0.7978

# %%
#### classification Report
history_plot(history)
y_pred = model.predict(X_test)
# print(classification_report(y_test, np.argmax(y_pred, axis=1)))
print(classification_report(test_label, np.argmax(y_pred, axis=1), target_names=labels))
scores = model.evaluate(X_test, y_test, verbose=2)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print( "\n\n\n")
# Out:
# ========================================================================
# loss val_loss
# ========================================================================
# sparse_categorical_accuracy val_sparse_categorical_accuracy
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.66      0.71      0.68       319
#            comp.graphics       0.58      0.55      0.56       389
#  comp.os.ms-windows.misc       0.82      0.53      0.65       394
# comp.sys.ibm.pc.hardware       0.78      0.50      0.61       392
#    comp.sys.mac.hardware       0.65      0.74      0.70       385
#           comp.windows.x       0.68      0.80      0.73       395
#             misc.forsale       0.61      0.81      0.70       390
#                rec.autos       0.75      0.73      0.74       395
#          rec.motorcycles       0.85      0.86      0.85       398
#       rec.sport.baseball       0.75      0.85      0.80       397
#         rec.sport.hockey       0.97      0.78      0.87       827
#                sci.crypt       0.91      0.84      0.88       396
#          sci.electronics       0.54      0.61      0.57       393
#                  sci.med       0.47      0.87      0.61       198
#                sci.space       0.84      0.86      0.85       394
#   soc.religion.christian       0.76      0.83      0.79       398
#       talk.politics.guns       0.70      0.82      0.76       364
#    talk.politics.mideast       0.95      0.79      0.86       376
#       talk.politics.misc       0.73      0.62      0.67       310
#       talk.religion.misc       0.63      0.48      0.54       251
#
#                 accuracy                           0.73      7761
#                macro avg       0.73      0.73      0.72      7761
#             weighted avg       0.75      0.73      0.74      7761
#
# 243/243 - 7s - loss: 3.7652 - sparse_categorical_accuracy: 0.7346 - 7s/epoch - 29ms/step
# sparse_categorical_accuracy: 73.46%

# %% [markdown]
# # LSTM

# %%
# from tensorflow.keras.layers import SpatialDropout1D, GlobalMaxPooling1D, GlobalMaxPooling2D

# def model_Create(FS, NF, EMB, MDL, MNW, PWV = None, optimizer='RMSprop', trainable_switch=True):
#     model = Sequential()
#     model.add(Embedding(input_dim=MNW, output_dim=EMB, embeddings_initializer='uniform', mask_zero=True, input_length=MDL))
#     model.add(Flatten())   
# #     model.add(GlobalMaxPooling2D()) # downsampling
# #     model.add(SpatialDropout1D(0.2))    
#     model.add(Dense(1024, activation='relu'))   
#     model.add(Dense(512, activation='relu'))   
#     model.add(Dense(128, activation='relu'))   
#     model.add(Dense(64, activation='relu'))   
#     # model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
#     model.add(Dense(20, activation='softmax'))   
#     model.compile(optimizer=optimizer,
#           loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False), 
#           metrics=[keras.metrics.SparseCategoricalAccuracy()])
#     return model

# model = model_Create(FS=FILTER_SIZES, NF=NUM_FILTERS, EMB=EMBEDDING_DIM,
#                      MDL=MAX_DOC_LEN, MNW=MAX_NB_WORDS+1, PWV=PWV, trainable_switch=trainable_switch)

# %%
# visual_textCNN(model)

# %%
# EMBEDDING_DIM = 200
# # W2V =  processor.w2v_pretrain(EMBEDDING_DIM, min_count=2, seed=1, cbow_mean=1,negative=5, window=20, workers=7) # pretrain w2v by gensim
# # W2V = processor.load_glove_w2v(EMBEDDING_DIM) # download glove
# trainable_switch = True
# W2V = None

# %%
# BATCH_SIZE = 64
# NUM_EPOCHES = 10  # patience=20
# patience = 30

# BestModel_Name = 'text_CNN.h5'
# BEST_MODEL_FILEPATH = BestModel_Name

# earlyStopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=patience, verbose=1, mode='max') # patience: number of epochs with no improvement on monitor : val_loss
# checkpoint = ModelCheckpoint(BEST_MODEL_FILEPATH, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
# history = model.fit(X_train, y_train, validation_split=0.2, batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
# model.load_weights(BestModel_Name)

# %%
# #### classification Report
# history_plot(history)
# y_pred = model.predict(X_test)
# # print(classification_report(y_test, np.argmax(y_pred, axis=1)))
# print(classification_report(test_label, np.argmax(y_pred, axis=1), target_names=labels))
# scores = model.evaluate(X_test, y_test, verbose=2)
# print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# print( "\n\n\n")
