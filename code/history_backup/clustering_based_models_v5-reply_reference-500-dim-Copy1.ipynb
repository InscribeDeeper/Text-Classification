# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Clustering-based" data-toc-modified-id="Clustering-based-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Clustering based</a></span><ul class="toc-item"><li><span><a href="#modeling" data-toc-modified-id="modeling-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>modeling</a></span></li><li><span><a href="#prediction" data-toc-modified-id="prediction-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>prediction</a></span></li><li><span><a href="#evaluation" data-toc-modified-id="evaluation-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>evaluation</a></span></li></ul></li></ul></div>

# %%
from sklearn.metrics import pairwise_distances
from sklearn import metrics
from sklearn import mixture
from sklearn.cluster import KMeans
from nltk.cluster import KMeansClusterer, cosine_distance
import pandas as pd
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from matplotlib import pyplot as plt
import numpy as np
from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from IPython.core.interactiveshell import InteractiveShell
from sklearn.model_selection import cross_validate
from sklearn.metrics import precision_recall_fscore_support, classification_report, roc_curve, auc, precision_recall_curve
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from nltk.corpus import stopwords
# nltk.download('stopwords')

# %%
seeds = 1234
np.random.seed(seeds)

# %%
train = pd.read_json('../data/structured_train.json')
test = pd.read_json('../data/structured_test.json')

# %%
# train = train.groupby('label').sample(50, random_state=seeds)
# test = test.groupby('label').sample(50, random_state=seeds)

# %%
select_cols = ["global_index", "doc_path", "label", 
               "reply", "reference_one", "reference_two","tag_reply", "tag_reference_one", "tag_reference_two", 
               "Subject", "From", "Lines", "Organization", "contained_emails", "long_string", "text", "error_message"
               ]
print("\nmay use cols: \n", select_cols)
train = train[select_cols]
test = test[select_cols]
# Out:
# may use cols:
#  ['global_index', 'doc_path', 'label', 'reply', 'reference_one', 'reference_two', 'tag_reply', 'tag_reference_one', 'tag_reference_two', 'Subject', 'From', 'Lines', 'Organization', 'contained_emails', 'long_string', 'text', 'error_message']

# %% [markdown]
# # Clustering based
# - Steps:
#     1. Transform into TF-IDF matrix
#     2. Dimension reduction into 200
#     3. Clustering in cosine similarity space (since it is word)
#     4. Assign labels with majority vote based on training set labels
#     5. Prediction
#         1. Transform test set into TF-IDF matrix
#         2. Dimension reduction into 200
#         3. Make prediction based on the clusters and mapping between clusters and labels from training set
#     6. Evaluation
#         1. Based on classification report

# %% [markdown]
# ## modeling

# %%
train_text = train['tag_reply'] 
# train_text = train['reply'] + ' ' + train['reference_one']
train_label = train['label']
test_text  = test['tag_reply']
# test_text  = test['reply'] + ' ' + test['reference_one']
test_label = test['label']

# %%
from sklearn.decomposition import TruncatedSVD

def tfidf_vectorizer(train_text, test_text, min_df=3, max_df=0.95):
    en_stopwords = stopwords.words('english')
    tfidf_vect = TfidfVectorizer(stop_words=en_stopwords, token_pattern=r'\b\w[\']?\w*\b',
                                 norm='l2', min_df=min_df, max_df=max_df)
    dtm_train = tfidf_vect.fit_transform(train_text)
    dtm_test = tfidf_vect.transform(test_text)

    word_to_idx = tfidf_vect.vocabulary_
    print("num of words:", len(word_to_idx))
    return dtm_train, dtm_test, word_to_idx, tfidf_vect


def dimension_reduction(dtm, out_dim=200, verbose=0):
    print("Dimension reduction with truncate SVD:")
    print("   input columns with ", dtm.shape[1])
    print("   output columns with ", out_dim)

    transform_mapper = TruncatedSVD(n_components=out_dim)
    dtm = transform_mapper.fit_transform(dtm)
    if verbose > 0:
        print("singular_values_: ", transform_mapper.singular_values_)
    return dtm, transform_mapper

# %%
def fit_clustering_model(dtm_train, train_label, num_clusters, metric='Cosine', model='KMeans', repeats=20):
    
    '''

    '''
    assert metric in ['Cosine']
    assert model in ['KMeans']

    # model training
    if model == 'KMeans':
        if metric == 'Cosine':
            clusterer = KMeansClusterer(num_clusters, cosine_distance, normalise=True, repeats=repeats, avoid_empty_clusters=True)
            clusters = clusterer.cluster(dtm_train, assign_clusters=True)
            train_cluster_pred = [clusterer.classify(v) for v in dtm_train]

    elif model == 'GMM':
        pass 
        # GMM model not good in such case
        # clusterer = mixture.GaussianMixture(n_components=num_clusters, n_init=repeats, covariance_type='diag')
        # clusterer.fit(dtm_train)
        # train_cluster_pred = clusterer.predict(dtm_train)
    
    # Maping clusters into labels
    df = pd.DataFrame(list(zip(train_label, train_cluster_pred)), columns=['actual_class', 'cluster'])
    confusion = pd.crosstab(index=df.cluster, columns=df.actual_class)
    clusters_to_labels = confusion.idxmax(axis=1)
    
    print("Cluster to label mapping: ")
    for idx, t in enumerate(clusters_to_labels):
        print("Cluster {} <-> label {}".format(idx, t))
    print("\n")

    return clusterer, clusters_to_labels

def pred_clustering_model(dtm_test, clusterer, clusters_to_labels):
    test_cluster_pred = [clusterer.classify(v) for v in dtm_test]
    predict = [clusters_to_labels[i] for i in test_cluster_pred]
    return predict

# %%
dtm_train, dtm_test, word_to_idx, tfidf_vect = tfidf_vectorizer(train_text, test_text, min_df=2)
dtm_train, transform_mapper = dimension_reduction(dtm_train, out_dim=500)
dtm_test = transform_mapper.transform(dtm_test)

print('dtm_train.shape', dtm_train.shape)
print('dtm_test.shape', dtm_test.shape)
print(word_to_idx)
# Out:
# num of words: 14211
# Dimension reduction with truncate SVD:
#    input columns with  14211
#    output columns with  500
# dtm_train.shape (11083, 500)
# dtm_test.shape (7761, 500)
# {'archive': 777, 'name': 8307, 'atheism': 937, 'resources': 10589, 'bumper': 1759, 'stickers': 12022, 'paraphernalia': 8993, 'freedom': 5260, 'telephone': 12561, 'fish': 5029, 'symbol': 12386, 'ones': 8699, 'christians': 2274, 'cars': 1996, 'feet': 4903, 'word': 13912, 'deluxe': 3546, 'postpaid': 9562, 'evolution': 4615, 'people': 9148, 'area': 781, 'price': 9726, 'atheist': 938, 'books': 1534, 'critiques': 3171, 'lists': 7367, 'contradictions': 2913, 'book': 1531, 'pp': 9597, 'edition': 4257, 'absurdities': 211, 'atrocities': 952, 'contradicts': 2915, 'version': 13482, 'fax': 4876, 'address': 314, 'african': 406, 'americans': 559, 'organization': 8781, 'history': 6033, 'newsletter': 8433, 'magazine': 7531, 'e': 4206, 'v': 13369, 'der': 3617, 'und': 13256, 'journal': 6895, 'write': 13971, 'story': 12068, 'proof': 9870, 'characters': 2167, 'events': 4602, 'similarity': 11471, 'living': 7388, 'gods': 5555, 'gem': 5427, 'post': 9552, 'novel': 8531, 'monks': 8106, 'lives': 7386, 'blueprints': 1482, 'sheets': 11338, 'paper': 8967, 'ink': 6547, 'lines': 7339, 'letters': 7262, 'states': 11972, 'church': 2287, 'example': 4626, 'forbids': 5163, 'anyone': 674, 'produce': 9805, 'substance': 12189, 'containing': 2879, 'atoms': 950, 'stories': 12066, 'novels': 8533, 'times': 12822, 'truth': 13143, 'religion': 10452, 'technology': 12536, 'sort': 11723, 'relevance': 10443, 'pot': 9569, 'healer': 5906, 'deity': 3527, 'summons': 12256, 'group': 5689, 'women': 13897, 'planet': 9387, 'oceans': 8633, 'faith': 4809, 'earthers': 4221, 'description': 3639, 'hero': 5976, 'searches': 11142, 'mysteries': 8291, 'reality': 10263, 'brain': 1602, 'pink': 9322, 'laser': 7135, 'beam': 1233, 'origin': 8791, 'friend': 5280, 'woman': 13895, 'star': 11950, 'system': 12422, 'man': 7598, 'music': 8267, 'premise': 9668, 'charge': 2170, 'nation': 8324, 'diary': 3750, 'life': 7299, 'theocracy': 12685, 'right': 10722, 'property': 9882, 'bank': 1142, 'accounts': 252, 'radio': 10146, 'readings': 10255, 'crimes': 3158, 'doctors': 4001, 'abortions': 192, 'world': 13934, 'writing': 13976, 'style': 12150, 'tale': 12454, 'work': 13917, 'reading': 10254, 'fuss': 5344, 'versions': 13483, 'sure': 12317, 'fallacies': 4816, 'justification': 6952, 'appendix': 721, 'terminology': 12622, 'usage': 13331, 'refutations': 10386, 'arguments': 794, 'god': 5551, 'attention': 969, 'theists': 12678, 'pages': 8931, 'critique': 3170, 'defences': 3493, 'incoherent': 6421, 'way': 13730, 'view': 13524, 'focusses': 5119, 'period': 9170, 'emphasis': 4366, 'developments': 3712, 'secularization': 11170, 'fate': 4861, 'idea': 6261, 'belief': 1299, 'thoughts': 12749, 'dictionary': 3761, 'quotations': 10111, 'kind': 7031, 'statements': 11971, 'writings': 13977, 'person': 9193, 'philosophy': 9244, 'opinions': 8735, 'observations': 8601, 'centuries': 2102, 'number': 8551, 'views': 13532, 'volume': 13602, 'series': 11262, 'existence': 4677, 'century': 2103, 'values': 13401, 'aesthetics': 385, 'attempt': 964, 'review': 10661, 'positions': 9542, 'al': 469, 'theses': 12710, 'concept': 2721, 'realm': 10265, 'replacements': 10509, 'delight': 3538, 'works': 13927, 'hand': 5799, 'waving': 13727, 'persecution': 9188, 'day': 3387, 'anthology': 652, 'listing': 7365, 'range': 10192, 'subjects': 12164, 'bibliography': 1358, 'study': 12143, 'fundamentalists': 5323, 'effect': 4272, 'server': 11269, 'co': 2461, 'uk': 13231, 'archives': 778, 'alt': 527, 'articles': 841, 'files': 4977, 'information': 6507, 'mail': 7550, 'index': 6447, 'reply': 10516, 'mathew': 7713, 'ÿ': 14210, 'introduction': 6714, 'article': 840, 'issues': 6794, 'document': 4004, 'viewpoint': 13529, 'conclusions': 2731, 'companion': 2628, 'sense': 11233, 'cohesion': 2497, 'progression': 9841, 'conversation': 2940, 'theist': 12677, 'questions': 10095, 'newsgroup': 8431, 'note': 8517, 'towards': 12928, 'religions': 10453, 'superhuman': 12283, 'divine': 3980, 'discussion': 3886, 'absence': 198, 'atheists': 939, 'position': 9540, 'latter': 7150, 'difference' ...

# %%
clusterer, clusters_to_labels = fit_clustering_model(dtm_train, train_label, num_clusters=60, repeats=2)
# Out:
# C:\Users\Administrator\Anaconda3\envs\py810\lib\site-packages\nltk\cluster\util.py:114: RuntimeWarning: invalid value encountered in true_divide
#   return vector / sqrt(numpy.dot(vector, vector))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_33684/1294377230.py in <module>
# ----> 1 clusterer, clusters_to_labels = fit_clustering_model(dtm_train, train_label, num_clusters=60, repeats=2)
#
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_33684/2436468964.py in fit_clustering_model(dtm_train, train_label, num_clusters, metric, model, repeats)
#      11         if metric == 'Cosine':
#      12             clusterer = KMeansClusterer(num_clusters, cosine_distance, normalise=True, repeats=repeats, avoid_empty_clusters=True)
# ---> 13             clusters = clusterer.cluster(dtm_train, assign_clusters=True)
#      14             train_cluster_pred = [clusterer.classify(v) for v in dtm_train]
#      15
#
# ~\Anaconda3\envs\py810\lib\site-packages\nltk\cluster\util.py in cluster(self, vectors, assign_clusters, trace)
#      58
#      59         # call abstract method to cluster the vectors
# ---> 60         self.cluster_vectorspace(vectors, trace)
#      61
#      62         # assign the vectors to clusters
#
# ~\Anaconda3\envs\py810\lib\site-packages\nltk\cluster\kmeans.py in cluster_vectorspace(self, vectors, trace)
#      89             if not self._means or trial > 1:
#      90                 self._means = self._rng.sample(list(vectors), self._num_means)
# ---> 91             self._cluster_vectorspace(vectors, trace)
#      92             meanss.append(self._means)
#      93
#
# ~\Anaconda3\envs\py810\lib\site-packages\nltk\cluster\kmeans.py in _cluster_vectorspace(self, vectors, trace)
#     120                 clusters = [[] for m in range(self._num_means)]
#     121                 for vector in vectors:
# --> 122                     index = self.classify_vectorspace(vector)
#     123                     clusters[index].append(vector)
#     124
#
# ~\Anaconda3\envs\py810\lib\site-packages\nltk\cluster\kmeans.py in classify_vectorspace(self, vector)
#     145         for index in range(len(self._means)):
#     146             mean = self._means[index]
# --> 147             dist = self._distance(vector, mean)
#     148             if best_distance is None or dist < best_distance:
#     149                 best_index, best_distance = index, dist
#
# ~\Anaconda3\envs\py810\lib\site-packages\nltk\cluster\util.py in cosine_distance(u, v)
#     129     equal to 1 - (u.v / |u||v|).
#     130     """
# --> 131     return 1 - (numpy.dot(u, v) / (sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))
#     132
#     133
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## prediction

# %%
pred = pred_clustering_model(dtm_test, clusterer, clusters_to_labels)

# %% [markdown]
# ## evaluation

# %%
from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# encoded_test_label = le.fit_transform(test_label)
# print(metrics.classification_report(y_true = encoded_test_label, y_pred=pred, target_names=le.classes_))
print(metrics.classification_report(y_true = test_label, y_pred=pred))
