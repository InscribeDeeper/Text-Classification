# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#extra-one-hot-features" data-toc-modified-id="extra-one-hot-features-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>extra one-hot features</a></span></li><li><span><a href="#extra-keywords" data-toc-modified-id="extra-keywords-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>extra keywords</a></span></li></ul></li><li><span><a href="#Dense" data-toc-modified-id="Dense-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Dense</a></span></li></ul></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TextCNN" data-toc-modified-id="TextCNN-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TextCNN</a></span><ul class="toc-item"><li><span><a href="#notes:" data-toc-modified-id="notes:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>notes:</a></span></li></ul></li><li><span><a href="#LSTM" data-toc-modified-id="LSTM-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>LSTM</a></span></li></ul></div>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Text-Classification/code")
# !pip install pyLDAvis
# !pip install gensim
# !pip install pandas==1.3.0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.4)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.4)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: pandas==1.3.0 in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (1.21.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.0) (1.15.0)

# %%
from classification_utils import *
from clustering_utils import *
from eda_utils import *
from nn_utils_keras import *
from feature_engineering_utils import *
from data_utils import *
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
train, test = load_data(only_stem_voc=True)
train, upsampling_info = upsampling_train(train)

train_text, train_label = train_augmentation(train, select_comb=None)
test_text, test_label = test['text'], test['label']

# test_text = test_text.apply(lambda x: extract_stem_voc(x))
# train_text = train_text.apply(lambda x: extract_stem_voc(x))
# train_text.to_csv("stem_voc_train.csv")
# test_text.to_csv("stem_voc_test.csv")

# train_text, test_text = load_stem_voc()
# Out:
# may use cols:
#  ['global_index', 'doc_path', 'label', 'reply', 'reference_one', 'reference_two', 'tag_reply', 'tag_reference_one', 'tag_reference_two', 'Subject', 'From', 'Lines', 'Organization', 'contained_emails', 'long_string', 'text', 'error_message']

# %%
####################################
### label mapper
####################################
labels = sorted(train_label.unique())
label_mapper = dict(zip(labels, range(len(labels))))
train_label = train_label.map(label_mapper)
test_label = test_label.map(label_mapper)
y_train = train_label
y_test = test_label

print(train_text.shape)
print(test_text.shape)
print(train_label.shape)
print(test_label.shape)
print(labels)
# Out:
# (11813,)
# (7761,)
# (11813,)
# (7761,)
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']

# %%
####################################
### hyper params 
####################################
filters = '"#$%&()*+,-/:;<=>@[\\]^_`{|}~\t\n0123465789!.?\''
MAX_NB_WORDS_ratio = 0.95
MAX_DOC_LEN_ratio = 0.95
MAX_NB_WORDS = eda_MAX_NB_WORDS(train_text, ratio=MAX_NB_WORDS_ratio, char_level=False, filters=filters)
MAX_DOC_LEN = eda_MAX_DOC_LEN(train_text, ratio=MAX_DOC_LEN_ratio, char_level=False, filters=filters)
# Out:
# Cut index with 95.0 % of corpus:  1822
#
#     index  word   count
# 0      19   the  151653
# 1      25    to   75746
# 2      10    of   71823
# 3    3916    ax   62514
# 4      45   and   60293
# 5      63    in   50710
# 6      52    is   45418
# 7      83  that   41792
# 8      51    it   37628
# 9      28   for   29575
# 10     16   you   28411
# 11      0  from   23390
# 12     54    be   22511
# 13     85    on   20901
# 14     26  have   19949
# 15     46   are   19597
# 16    101   not   19339
# 17     21  with   18059
# 18    178    as   16442
# 19    106    or   15204
# extreme frequent words:      word   count
# 10     of   71823
# 19    the  151653
# 25     to   75746
# 45    and   60293
# 63     in   50710
# 3916   ax   62514
# Cut index with 95.0 % of corpus:  542

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Embedding, Dense, Conv1D, MaxPooling1D, Dropout, Activation, Input, Flatten, Concatenate, Lambda
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow import keras
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

# %% [markdown]
# ## extra one-hot features

# %%
one_hot_X_train, one_hot_X_test, one_hot_word_to_idx, one_hot_count_vect = count_vectorizer(
    train['Subject']+" " + train['Organization'], test['Subject']+" " + test['Organization'], stop_words=True, binary=False, min_df=3, max_df=0.001)
# Out:
# num of words: 3236

# %% [markdown]
# ## extra keywords

# %%
# label_docs = train.groupby('label')['text'].apply(lambda x: " ".join(x)) # 要去除标点符号
# dtm, _, label_word_to_idx, _ = count_vectorizer(label_docs, [''], stop_words=True, min_df=1, binary=True)
# label_idx_to_word = dict([val, key] for key, val in label_word_to_idx.items())
# keywords_threshold = 1
# keywords_idx = np.where(dtm.sum(axis=0)<=keywords_threshold)[0]
# print(" keywords_idx shape: ")
# voc = [label_idx_to_word[idx] for idx in keywords_idx]

# keywords_X_train, keywords_X_test, keywords_word_to_idx, keywords_count_vect = count_vectorizer(
#     train['text'], test['text'], voc=voc, stop_words=True, min_df=1, binary=True)

# %% [markdown]
# # Dense

# %%
X_train, X_test, word_to_idx, tfidf_vect = tfidf_vectorizer(train_text, test_text, stop_words=True, binary=True, min_df=5)
# X_train, transform_mapper = dimension_reduction(X_train, out_dim=1000) # not allow negative 
# X_test = transform_mapper.transform(X_test)
# Out:
# num of words: 5691

# %%
# _X_train = np.hstack([X_train])
# _X_test = np.hstack([X_test])
_X_train = np.hstack([X_train, one_hot_X_train])
_X_test = np.hstack([X_test, one_hot_X_test])
# _X_train = np.hstack([X_train, one_hot_X_train, keywords_X_train])
# _X_test = np.hstack([X_test, one_hot_X_test, keywords_X_test])

# %%
opt = optimizers.Adam(learning_rate=0.005)

model = Sequential()
model.add(Input(shape=_X_train.shape[1],))  # input cannot connect with dropout directly
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(20, activation='softmax'))
model.compile(optimizer=opt,
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])


# model.compile(optimizer=opt,
#                 loss=keras.losses.CategoricalHinge(),
#               metrics=[keras.metrics.CategoricalAccuracy()])

# %%
BATCH_SIZE = 256 # 16 # 先在小的batch上train, 容易找到全局最优部分, 然后再到 大 batch 上train, 快速收敛到局部最优
NUM_EPOCHES = 100  # 20步以上
patience = 80

file_name = 'test'
BestModel_Name = file_name + 'Best_GS_5'
BEST_MODEL_FILEPATH = BestModel_Name
earlyStopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=patience, verbose=1, mode='max') # patience: number of epochs with no improvement on monitor : val_loss
checkpoint = ModelCheckpoint(BEST_MODEL_FILEPATH, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
# history = model.fit(_X_train, y_train, validation_data=(_X_test,y_test), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)

# for testing the capability of this model, all training set is used, and use test set to validate the model performance
history = model.fit(_X_train, y_train, validation_data=(_X_test,y_test), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=None, verbose=1)
# history = model.fit(_X_train, y_train, validation_data=(_X_val,y_val), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=None, verbose=1)
# history = model.fit(_X_train, to_categorical(y_train), validation_data=(_X_test,to_categorical(y_test)), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=None, verbose=1)
# history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 2s 21ms/step - loss: 2.5199 - sparse_categorical_accuracy: 0.2137 - val_loss: 1.3384 - val_sparse_categorical_accuracy: 0.6415
# Epoch 2/100
# 47/47 [==============================] - 0s 9ms/step - loss: 1.0442 - sparse_categorical_accuracy: 0.6655 - val_loss: 0.9468 - val_sparse_categorical_accuracy: 0.7356
# Epoch 3/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.5462 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.9724 - val_sparse_categorical_accuracy: 0.7344
# Epoch 4/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.3395 - sparse_categorical_accuracy: 0.9007 - val_loss: 1.0799 - val_sparse_categorical_accuracy: 0.7369
# Epoch 5/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2563 - sparse_categorical_accuracy: 0.9236 - val_loss: 1.1748 - val_sparse_categorical_accuracy: 0.7387
# Epoch 6/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.2062 - sparse_categorical_accuracy: 0.9383 - val_loss: 1.1748 - val_sparse_categorical_accuracy: 0.7423
# Epoch 7/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1635 - sparse_categorical_accuracy: 0.9523 - val_loss: 1.2603 - val_sparse_categorical_accuracy: 0.7469
# Epoch 8/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1319 - sparse_categorical_accuracy: 0.9640 - val_loss: 1.3615 - val_sparse_categorical_accuracy: 0.7414
# Epoch 9/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1193 - sparse_categorical_accuracy: 0.9673 - val_loss: 1.4367 - val_sparse_categorical_accuracy: 0.7393
# Epoch 10/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1005 - sparse_categorical_accuracy: 0.9710 - val_loss: 1.4921 - val_sparse_categorical_accuracy: 0.7365
# Epoch 11/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0991 - sparse_categorical_accuracy: 0.9729 - val_loss: 1.4604 - val_sparse_categorical_accuracy: 0.7432
# Epoch 12/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.1003 - sparse_categorical_accuracy: 0.9731 - val_loss: 1.4591 - val_sparse_categorical_accuracy: 0.7481
# Epoch 13/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0893 - sparse_categorical_accuracy: 0.9784 - val_loss: 1.4718 - val_sparse_categorical_accuracy: 0.7444
# Epoch 14/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9808 - val_loss: 1.5156 - val_sparse_categorical_accuracy: 0.7364
# Epoch 15/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0689 - sparse_categorical_accuracy: 0.9820 - val_loss: 1.5886 - val_sparse_categorical_accuracy: 0.7373
# Epoch 16/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0763 - sparse_categorical_accuracy: 0.9804 - val_loss: 1.5986 - val_sparse_categorical_accuracy: 0.7459
# Epoch 17/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0650 - sparse_categorical_accuracy: 0.9824 - val_loss: 1.6818 - val_sparse_categorical_accuracy: 0.7433
# Epoch 18/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0622 - sparse_categorical_accuracy: 0.9832 - val_loss: 1.7235 - val_sparse_categorical_accuracy: 0.7379
# Epoch 19/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0730 - sparse_categorical_accuracy: 0.9828 - val_loss: 1.8271 - val_sparse_categorical_accuracy: 0.7298
# Epoch 20/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0602 - sparse_categorical_accuracy: 0.9850 - val_loss: 1.7912 - val_sparse_categorical_accuracy: 0.7382
# Epoch 21/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0564 - sparse_categorical_accuracy: 0.9861 - val_loss: 1.9602 - val_sparse_categorical_accuracy: 0.7315
# Epoch 22/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0688 - sparse_categorical_accuracy: 0.9817 - val_loss: 1.8600 - val_sparse_categorical_accuracy: 0.7395
# Epoch 23/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0647 - sparse_categorical_accuracy: 0.9831 - val_loss: 1.9267 - val_sparse_categorical_accuracy: 0.7334
# Epoch 24/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0656 - sparse_categorical_accuracy: 0.9837 - val_loss: 1.8625 - val_sparse_categorical_accuracy: 0.7365
# Epoch 25/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0663 - sparse_categorical_accuracy: 0.9825 - val_loss: 1.9348 - val_sparse_categorical_accuracy: 0.7451
# Epoch 26/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9833 - val_loss: 1.9178 - val_sparse_categorical_accuracy: 0.7348
# Epoch 27/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0577 - sparse_categorical_accuracy: 0.9859 - val_loss: 1.8972 - val_sparse_categorical_accuracy: 0.7352
# Epoch 28/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0593 - sparse_categorical_accuracy: 0.9838 - val_loss: 1.9338 - val_sparse_categorical_accuracy: 0.7289
# Epoch 29/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9818 - val_loss: 1.9269 - val_sparse_categorical_accuracy: 0.7332
# Epoch 30/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0573 - sparse_categorical_accuracy: 0.9853 - val_loss: 1.8858 - val_sparse_categorical_accuracy: 0.7377
# Epoch 31/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0525 - sparse_categorical_accuracy: 0.9865 - val_loss: 1.9647 - val_sparse_categorical_accuracy: 0.7332
# Epoch 32/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0606 - sparse_categorical_accuracy: 0.9850 - val_loss: 1.9288 - val_sparse_categorical_accuracy: 0.7388
# Epoch 33/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0585 - sparse_categorical_accuracy: 0.9840 - val_loss: 2.0310 - val_sparse_categorical_accuracy: 0.7415
# Epoch 34/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9862 - val_loss: 2.0913 - val_sparse_categorical_accuracy: 0.7357
# Epoch 35/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0687 - sparse_categorical_accuracy: 0.9848 - val_loss: 2.0056 - val_sparse_categorical_accuracy: 0.7384
# Epoch 36/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0550 - sparse_categorical_accuracy: 0.9861 - val_loss: 1.9420 - val_sparse_categorical_accuracy: 0.7414
# Epoch 37/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0587 - sparse_categorical_accuracy: 0.9857 - val_loss: 2.0562 - val_sparse_categorical_accuracy: 0.7334
# Epoch 38/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9865 - val_loss: 2.0478 - val_sparse_categorical_accuracy: 0.7418
# Epoch 39/100
# 47/47 [==============================] - 1s 18ms/step - loss: 0.0487 - sparse_categorical_accuracy: 0.9865 - val_loss: 2.0983 - val_sparse_categorical_accuracy: 0.7395
# Epoch 40/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0649 - sparse_categorical_accuracy: 0.9846 - val_loss: 2.1150 - val_sparse_categorical_accuracy: 0.7294
# Epoch 41/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0542 - sparse_categorical_accuracy: 0.9870 - val_loss: 2.0788 - val_sparse_categorical_accuracy: 0.7380
# Epoch 42/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9852 - val_loss: 2.1980 - val_sparse_categorical_accuracy: 0.7357
# Epoch 43/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0520 - sparse_categorical_accuracy: 0.9861 - val_loss: 2.1229 - val_sparse_categorical_accuracy: 0.7408
# Epoch 44/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9872 - val_loss: 2.2744 - val_sparse_categorical_accuracy: 0.7374
# Epoch 45/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0456 - sparse_categorical_accuracy: 0.9890 - val_loss: 2.2092 - val_sparse_categorical_accuracy: 0.7401
# Epoch 46/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0460 - sparse_categorical_accuracy: 0.9883 - val_loss: 2.2664 - val_sparse_categorical_accuracy: 0.7371
# Epoch 47/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0520 - sparse_categorical_accuracy: 0.9880 - val_loss: 2.2004 - val_sparse_categorical_accuracy: 0.7450
# Epoch 48/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9892 - val_loss: 2.2317 - val_sparse_categorical_accuracy: 0.7360
# Epoch 49/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0574 - sparse_categorical_accuracy: 0.9869 - val_loss: 2.2434 - val_sparse_categorical_accuracy: 0.7320
# Epoch 50/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9865 - val_loss: 2.2437 - val_sparse_categorical_accuracy: 0.7377
# Epoch 51/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9885 - val_loss: 2.3034 - val_sparse_categorical_accuracy: 0.7386
# Epoch 52/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9877 - val_loss: 2.3179 - val_sparse_categorical_accuracy: 0.7344
# Epoch 53/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0517 - sparse_categorical_accuracy: 0.9888 - val_loss: 2.3081 - val_sparse_categorical_accuracy: 0.7379
# Epoch 54/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9888 - val_loss: 2.3231 - val_sparse_categorical_accuracy: 0.7391
# Epoch 55/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0494 - sparse_categorical_accuracy: 0.9869 - val_loss: 2.3389 - val_sparse_categorical_accuracy: 0.7362
# Epoch 56/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0457 - sparse_categorical_accuracy: 0.9882 - val_loss: 2.3249 - val_sparse_categorical_accuracy: 0.7424
# Epoch 57/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0448 - sparse_categorical_accuracy: 0.9883 - val_loss: 2.4456 - val_sparse_categorical_accuracy: 0.7344
# Epoch 58/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0541 - sparse_categorical_accuracy: 0.9881 - val_loss: 2.2557 - val_sparse_categorical_accuracy: 0.7401
# Epoch 59/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9892 - val_loss: 2.3129 - val_sparse_categorical_accuracy: 0.7391
# Epoch 60/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.5051 - val_sparse_categorical_accuracy: 0.7315
# Epoch 61/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9863 - val_loss: 2.2280 - val_sparse_categorical_accuracy: 0.7414
# Epoch 62/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9866 - val_loss: 2.2157 - val_sparse_categorical_accuracy: 0.7401
# Epoch 63/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9890 - val_loss: 2.3371 - val_sparse_categorical_accuracy: 0.7402
# Epoch 64/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0410 - sparse_categorical_accuracy: 0.9895 - val_loss: 2.4047 - val_sparse_categorical_accuracy: 0.7371
# Epoch 65/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0470 - sparse_categorical_accuracy: 0.9877 - val_loss: 2.4344 - val_sparse_categorical_accuracy: 0.7397
# Epoch 66/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9884 - val_loss: 2.4059 - val_sparse_categorical_accuracy: 0.7428
# Epoch 67/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9890 - val_loss: 2.5301 - val_sparse_categorical_accuracy: 0.7369
# Epoch 68/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9903 - val_loss: 2.5561 - val_sparse_categorical_accuracy: 0.7359
# Epoch 69/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0411 - sparse_categorical_accuracy: 0.9893 - val_loss: 2.5428 - val_sparse_categorical_accuracy: 0.7380
# Epoch 70/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9890 - val_loss: 2.4462 - val_sparse_categorical_accuracy: 0.7413
# Epoch 71/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0450 - sparse_categorical_accuracy: 0.9904 - val_loss: 2.4565 - val_sparse_categorical_accuracy: 0.7426
# Epoch 72/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0464 - sparse_categorical_accuracy: 0.9889 - val_loss: 2.4633 - val_sparse_categorical_accuracy: 0.7343
# Epoch 73/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9898 - val_loss: 2.4776 - val_sparse_categorical_accuracy: 0.7411
# Epoch 74/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9906 - val_loss: 2.4501 - val_sparse_categorical_accuracy: 0.7449
# Epoch 75/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9909 - val_loss: 2.5306 - val_sparse_categorical_accuracy: 0.7406
# Epoch 76/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0406 - sparse_categorical_accuracy: 0.9905 - val_loss: 2.5796 - val_sparse_categorical_accuracy: 0.7462
# Epoch 77/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9898 - val_loss: 2.5729 - val_sparse_categorical_accuracy: 0.7426
# Epoch 78/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9876 - val_loss: 2.5811 - val_sparse_categorical_accuracy: 0.7383
# Epoch 79/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9907 - val_loss: 2.6227 - val_sparse_categorical_accuracy: 0.7387
# Epoch 80/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9902 - val_loss: 2.7073 - val_sparse_categorical_accuracy: 0.7344
# Epoch 81/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9901 - val_loss: 2.6510 - val_sparse_categorical_accuracy: 0.7436
# Epoch 82/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9898 - val_loss: 2.5914 - val_sparse_categorical_accuracy: 0.7401
# Epoch 83/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9893 - val_loss: 2.5968 - val_sparse_categorical_accuracy: 0.7463
# Epoch 84/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9893 - val_loss: 2.6260 - val_sparse_categorical_accuracy: 0.7406
# Epoch 85/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0445 - sparse_categorical_accuracy: 0.9892 - val_loss: 2.7120 - val_sparse_categorical_accuracy: 0.7359
# Epoch 86/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0476 - sparse_categorical_accuracy: 0.9892 - val_loss: 2.6770 - val_sparse_categorical_accuracy: 0.7417
# Epoch 87/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0504 - sparse_categorical_accuracy: 0.9892 - val_loss: 2.6428 - val_sparse_categorical_accuracy: 0.7373
# Epoch 88/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9902 - val_loss: 2.7030 - val_sparse_categorical_accuracy: 0.7408
# Epoch 89/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9885 - val_loss: 2.7763 - val_sparse_categorical_accuracy: 0.7312
# Epoch 90/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0442 - sparse_categorical_accuracy: 0.9893 - val_loss: 2.8167 - val_sparse_categorical_accuracy: 0.7364
# Epoch 91/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9896 - val_loss: 2.8252 - val_sparse_categorical_accuracy: 0.7397
# Epoch 92/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0570 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.6300 - val_sparse_categorical_accuracy: 0.7387
# Epoch 93/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0465 - sparse_categorical_accuracy: 0.9907 - val_loss: 2.7142 - val_sparse_categorical_accuracy: 0.7338
# Epoch 94/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9894 - val_loss: 2.7469 - val_sparse_categorical_accuracy: 0.7348
# Epoch 95/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0588 - sparse_categorical_accuracy: 0.9885 - val_loss: 2.5711 - val_sparse_categorical_accuracy: 0.7347
# Epoch 96/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9898 - val_loss: 2.7237 - val_sparse_categorical_accuracy: 0.7346
# Epoch 97/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0612 - sparse_categorical_accuracy: 0.9890 - val_loss: 2.6252 - val_sparse_categorical_accuracy: 0.7379
# Epoch 98/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9901 - val_loss: 2.6906 - val_sparse_categorical_accuracy: 0.7348
# Epoch 99/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0556 - sparse_categorical_accuracy: 0.9887 - val_loss: 2.6072 - val_sparse_categorical_accuracy: 0.7335
# Epoch 100/100
# 47/47 [==============================] - 0s 9ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9906 - val_loss: 2.6702 - val_sparse_categorical_accuracy: 0.7325

# %%
#### classification Report
history_plot(history)
y_pred = model.predict(_X_test)
classification_report = evaluation_report(y_test, np.argmax(y_pred, axis=1), labels=labels)

scores = model.evaluate(_X_test, y_test, verbose=2)
roc_auc(y_test, y_pred)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print( "\n\n\n")
# Out:
# ========================================================================
# loss val_loss
# ========================================================================
# sparse_categorical_accuracy val_sparse_categorical_accuracy
# classification_report:
# f1:  {'micro avg': 0.732508697332818, 'macro avg': 0.7208243065428221}
#
#                           precision  recall  f1-score  support
# alt.atheism                   0.723   0.646     0.682    319.0
# comp.graphics                 0.575   0.676     0.622    389.0
# comp.os.ms-windows.misc       0.684   0.538     0.602    394.0
# comp.sys.ibm.pc.hardware      0.588   0.605     0.596    392.0
# comp.sys.mac.hardware         0.645   0.751     0.694    385.0
# comp.windows.x                0.652   0.673     0.663    395.0
# misc.forsale                  0.612   0.805     0.695    390.0
# rec.autos                     0.803   0.785     0.794    395.0
# rec.motorcycles               0.917   0.889     0.903    398.0
# rec.sport.baseball            0.705   0.904     0.792    397.0
# rec.sport.hockey              0.986   0.773     0.866    827.0
# sci.crypt                     0.925   0.843     0.882    396.0
# sci.electronics               0.728   0.702     0.715    393.0
# sci.med                       0.674   0.889     0.767    198.0
# sci.space                     0.854   0.789     0.821    394.0
# soc.religion.christian        0.687   0.766     0.724    398.0
# talk.politics.guns            0.727   0.725     0.726    364.0
# talk.politics.mideast         0.807   0.758     0.782    376.0
# talk.politics.misc            0.777   0.552     0.645    310.0
# talk.religion.misc            0.433   0.454     0.444    251.0
# accuracy                      0.733   0.733     0.733   7761.0
# macro avg                     0.725   0.726     0.721   7761.0
# weighted avg                  0.746   0.733     0.734   7761.0
# micro avg                     0.733   0.733     0.733   7761.0
# 243/243 - 1s - loss: 2.6702 - sparse_categorical_accuracy: 0.7325 - 553ms/epoch - 2ms/step
# roc_auc:  0.9511121527947118
# sparse_categorical_accuracy: 73.25%
