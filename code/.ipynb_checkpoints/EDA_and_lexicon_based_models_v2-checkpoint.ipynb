# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#思路" data-toc-modified-id="思路-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>思路</a></span><ul class="toc-item"><li><span><a href="#summary-statistic" data-toc-modified-id="summary-statistic-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>summary statistic</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#attribute-selection" data-toc-modified-id="attribute-selection-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>attribute selection</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Outliers</a></span><ul class="toc-item"><li><span><a href="#MNW" data-toc-modified-id="MNW-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>MNW</a></span></li></ul></li></ul></li><li><span><a href="#for-each-class-EDA" data-toc-modified-id="for-each-class-EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>for each class EDA</a></span></li></ul></div>

# %% [markdown]
# # 思路
# - 预处理 怎么找到词库?

# %%
from classification_utils import *
from clustering_utils import *
from eda_utils import *
from nn_utils_keras import *
from feature_engineering_utils import *
from data_utils import *
import warnings 
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
seeds = 1234

# %%
train = pd.read_json('../data/structured_train.json')
test = pd.read_json('../data/structured_test.json')

# l = train['long_string'].dropna().apply(len).sort_values()
# longest_idx = l[l>0].index.tolist()[-30:]
# train = train[~train.global_index.isin(longest_idx)].reset_index(drop=True)
# train['long_string'].sample(10).tolist()
# Out:
# may use cols:
#  ['global_index', 'doc_path', 'label', 'reply', 'reference_one', 'reference_two', 'tag_reply', 'tag_reference_one', 'tag_reference_two', 'Subject', 'From', 'Lines', 'Organization', 'contained_emails', 'long_string', 'text', 'error_message']

# %%
# train, test = load_data(only_stem_voc=True, sample50=False)

# %%
# train = train.groupby('label').sample(50, random_state=seeds)
# test = test.groupby('label').sample(50, random_state=seeds)

# %% [markdown]
# ## summary statistic

# %%
a = train.groupby('label').size().to_frame()
a.columns=['count']
a['percentage'] = (a['count']/a['count'].sum())
a = a.reset_index()
cols = ['label', 'count', 'percentage']
a.columns = cols
train_des = a.copy()
a = test.groupby('label').size().to_frame()
a.columns = ['count']
a['percentage'] = (a['count']/a['count'].sum())
a = a.reset_index()
cols = ['label', 'count', 'percentage']
a.columns = cols
test_des = a.copy()
des = train_des.merge(test_des, on='label', suffixes=('_train','_test'))
# des.loc['summation'] = des.sum(axis=0)
# des.loc['summation', 'label'] = 'In total'
# des
des.style.bar(color='#5fba7d', axis=0, align='zero')
# Out:
# <style type="text/css">
# #T_d6bbb_row0_col1, #T_d6bbb_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 80.3%, transparent 80.3%);
# }
# #T_d6bbb_row0_col3, #T_d6bbb_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 69.3%, transparent 69.3%);
# }
# #T_d6bbb_row1_col1, #T_d6bbb_row1_col2, #T_d6bbb_row6_col1, #T_d6bbb_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.9%, transparent 86.9%);
# }
# #T_d6bbb_row1_col3, #T_d6bbb_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.5%, transparent 73.5%);
# }
# #T_d6bbb_row2_col1, #T_d6bbb_row2_col2, #T_d6bbb_row12_col1, #T_d6bbb_row12_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.3%, transparent 87.3%);
# }
# #T_d6bbb_row2_col3, #T_d6bbb_row2_col4, #T_d6bbb_row12_col3, #T_d6bbb_row12_col4, #T_d6bbb_row14_col3, #T_d6bbb_row14_col4, #T_d6bbb_row19_col1, #T_d6bbb_row19_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.8%, transparent 73.8%);
# }
# #T_d6bbb_row3_col1, #T_d6bbb_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.2%, transparent 87.2%);
# }
# #T_d6bbb_row3_col3, #T_d6bbb_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.7%, transparent 73.7%);
# }
# #T_d6bbb_row4_col1, #T_d6bbb_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 86.5%, transparent 86.5%);
# }
# #T_d6bbb_row4_col3, #T_d6bbb_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.3%, transparent 73.3%);
# }
# #T_d6bbb_row5_col1, #T_d6bbb_row5_col2, #T_d6bbb_row7_col1, #T_d6bbb_row7_col2, #T_d6bbb_row14_col1, #T_d6bbb_row14_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.4%, transparent 87.4%);
# }
# #T_d6bbb_row5_col3, #T_d6bbb_row5_col4, #T_d6bbb_row7_col3, #T_d6bbb_row7_col4, #T_d6bbb_row11_col3, #T_d6bbb_row11_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.9%, transparent 73.9%);
# }
# #T_d6bbb_row6_col3, #T_d6bbb_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 73.6%, transparent 73.6%);
# }
# #T_d6bbb_row8_col1, #T_d6bbb_row8_col2, #T_d6bbb_row15_col1, #T_d6bbb_row15_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.8%, transparent 87.8%);
# }
# #T_d6bbb_row8_col3, #T_d6bbb_row8_col4, #T_d6bbb_row15_col3, #T_d6bbb_row15_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 74.1%, transparent 74.1%);
# }
# #T_d6bbb_row9_col1, #T_d6bbb_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.7%, transparent 87.7%);
# }
# #T_d6bbb_row9_col3, #T_d6bbb_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 74.0%, transparent 74.0%);
# }
# #T_d6bbb_row10_col1, #T_d6bbb_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 60.9%, transparent 60.9%);
# }
# #T_d6bbb_row10_col3, #T_d6bbb_row10_col4, #T_d6bbb_row13_col1, #T_d6bbb_row13_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_d6bbb_row11_col1, #T_d6bbb_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 87.6%, transparent 87.6%);
# }
# #T_d6bbb_row13_col3, #T_d6bbb_row13_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 62.0%, transparent 62.0%);
# }
# #T_d6bbb_row16_col1, #T_d6bbb_row16_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 84.5%, transparent 84.5%);
# }
# #T_d6bbb_row16_col3, #T_d6bbb_row16_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 72.0%, transparent 72.0%);
# }
# #T_d6bbb_row17_col1, #T_d6bbb_row17_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 85.6%, transparent 85.6%);
# }
# #T_d6bbb_row17_col3, #T_d6bbb_row17_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 72.7%, transparent 72.7%);
# }
# #T_d6bbb_row18_col1, #T_d6bbb_row18_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 79.4%, transparent 79.4%);
# }
# #T_d6bbb_row18_col3, #T_d6bbb_row18_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 68.7%, transparent 68.7%);
# }
# #T_d6bbb_row19_col3, #T_d6bbb_row19_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 65.2%, transparent 65.2%);
# }
# </style>
# <table id="T_d6bbb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >count_train</th>
#       <th class="col_heading level0 col2" >percentage_train</th>
#       <th class="col_heading level0 col3" >count_test</th>
#       <th class="col_heading level0 col4" >percentage_test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6bbb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6bbb_row0_col0" class="data row0 col0" >alt.atheism</td>
#       <td id="T_d6bbb_row0_col1" class="data row0 col1" >480</td>
#       <td id="T_d6bbb_row0_col2" class="data row0 col2" >0.043310</td>
#       <td id="T_d6bbb_row0_col3" class="data row0 col3" >319</td>
#       <td id="T_d6bbb_row0_col4" class="data row0 col4" >0.041103</td>
#     </tr>
#     <tr>
#       <th id="T_d6bbb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6bbb_row1_col0" class="data row1 col0" >comp.graphics</td>
#       <td id="T_d6bbb_row1_col1" class="data row1 col1" >584</td>
#       <td id="T_d6bbb_row1_col2" class="data row1 col2" >0.052693</td>
#       <td id="T_d6bbb_row1_col3" class="data row1 col3" >389</td>
#       <td id="T_d6bbb_row1_col4" class="data row1 col4" >0.050122</td>
#     </tr>
#     <tr>
#       <th id="T_d6bbb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6bbb_row2_col0" class="data row2 col0" >comp.os.ms-windows.misc</td>
#       <td id="T_d6bbb_row2_col1" class="data row2 col1" >591</td>
#       <td id="T_d6bbb_row2_col2" class="data row2 col2" >0.053325</td>
#       <td id="T_d6bbb_row2_col3" class="data row2 col3" >394</td>
#       <td id="T_d6bbb_row2_col4" class="data row2 col4" >0.050767</td>
#     </tr>
#     <tr>
#       <th id="T_d6bbb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6bbb_row3_col0" class="data row3 col0" >comp.sys.ibm.pc.hardware</td>
#       <td id="T_d6bbb_row3_col1" class="data row3 col1" >590</td>
#       <td id="T_d6bbb_row3_col2" class="data row3 col2" >0.053235</td>
#       <td id="T_d6bbb_row3_col3" class="data row3 col3" >392</td>
#       <td id="T_d6bbb_row3_col4" class="data row3 col4" >0.050509</td>
#     </tr>
#     <tr>
#       <th id="T_d6bbb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6bbb_row4_col0" class="data row4 col0" >comp.sys.mac.hardware</td>
#       <td id="T_d6bbb_row4_col1" class="data row4 co

# %% [markdown]
# # EDA

# %% [markdown]
# ## attribute selection

# %%
t = train.isnull().sum().sort_values()
not_used_cols = t[t > train.shape[0]*0.1].index.tolist()
print("not_used_cols: \n", not_used_cols)
t.to_frame().style
# Out:
# not_used_cols:
#  ['Distribution', 'Nntp-Posting-Host', 'NNTP-Posting-Host', 'Reply-To', 'Keywords', 'Article-I.D.', 'X-Newsreader', 'Summary', 'Originator', 'In-Reply-To', 'News-Software', 'Expires', 'In-reply-to', 'To', 'X-Disclaimer', 'Disclaimer', 'X-Mailer', 'X-Useragent', 'X-Xxdate', 'Supersedes', 'X-UserAgent', 'X-XXDate', 'Nf-ID', 'X-News-Reader', 'Nf-From', 'X-Added', 'Original-Sender', 'X-Posted-From', 'X-XXMessage-ID', 'Content-Type', 'X-Xxmessage-Id', 'Cc', 'X-Last-Updated', 'Mime-Version', 'Moderator', 'Content-Transfer-Encoding', 'date', 'X-Gated-By', 'X-To', 'Return-Path', 'X-Received', 'X-Sender', 'Nntp-Posting-User', 'X-Auth-User', 'X-X-From', 'X-Md4-Signature', 'X-Maildoor', 'X-Cc', 'X-NewsSoftware', 'X-AltNet-ID', 'MIME-Version', 'Return-Receipt-To', 'X-Header', 'X-Newssoftware', 'Comments', 'Bcc', 'X-Bytes', 'X-Software', 'X-Copyright', 'Posting-Front-End', 'X-Mail-Reader', 'X-News-Software', 'X-Reader', 'Organisation', 'Apparently-To', 'X-Comment-To', 'Mmdf-Warning', 'Followups-to', 'X-Newsposter', 'X-FTN-To', 'Follow-Ups', 'Nntp-Software', 'Oganization', 'X-Standard-Disclaimer', 'ReplyTo', 'OD-Comment-To', 'X-Advert', 'X-Gateway', 'Oanization', 'Nntp-Posting-Host-[nntpd-19510]', 'Posted-Date', 'Nntp-Posting-Host-[nntpd-8755]', 'Nntp-Posting-Host-[nntpd-29970]', 'X-Date', 'Nntp-Posting-Host-[nntpd-23809]', 'Original-To', 'Status', 'Nntp-Posting-Host-[nntpd-681]', 'X-Alt.reply-Address', 'Weather', 'X-Face', 'Content-Length', 'Received-Date', 'X-Address', 'X-Fax', 'X-Phone', 'IMPORTANT-INFO', 'Moon-Phase', 'Orginization', 'error_message']
# <style type="text/css">
# </style>
# <table id="T_4230c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4230c_level0_row0" class="row_heading level0 row0" >global_index</th>
#       <td id="T_4230c_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row1" class="row_heading level0 row1" >tag_reply</th>
#       <td id="T_4230c_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row2" class="row_heading level0 row2" >delivered_to</th>
#       <td id="T_4230c_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row3" class="row_heading level0 row3" >reference_two</th>
#       <td id="T_4230c_row3_col0" class="data row3 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row4" class="row_heading level0 row4" >reference_one</th>
#       <td id="T_4230c_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row5" class="row_heading level0 row5" >reply</th>
#       <td id="T_4230c_row5_col0" class="data row5 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row6" class="row_heading level0 row6" >tag_reference_one</th>
#       <td id="T_4230c_row6_col0" class="data row6 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row7" class="row_heading level0 row7" >tag_reference_two</th>
#       <td id="T_4230c_row7_col0" class="data row7 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row8" class="row_heading level0 row8" >doc_path</th>
#       <td id="T_4230c_row8_col0" class="data row8 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row9" class="row_heading level0 row9" >original_idx</th>
#       <td id="T_4230c_row9_col0" class="data row9 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row10" class="row_heading level0 row10" >label</th>
#       <td id="T_4230c_row10_col0" class="data row10 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row11" class="row_heading level0 row11" >text</th>
#       <td id="T_4230c_row11_col0" class="data row11 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row12" class="row_heading level0 row12" >From</th>
#       <td id="T_4230c_row12_col0" class="data row12 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row13" class="row_heading level0 row13" >to_domains</th>
#       <td id="T_4230c_row13_col0" class="data row13 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row14" class="row_heading level0 row14" >contained_emails</th>
#       <td id="T_4230c_row14_col0" class="data row14 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row15" class="row_heading level0 row15" >long_string</th>
#       <td id="T_4230c_row15_col0" class="data row15 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row16" class="row_heading level0 row16" >Subject</th>
#       <td id="T_4230c_row16_col0" class="data row16 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row17" class="row_heading level0 row17" >Lines</th>
#       <td id="T_4230c_row17_col0" class="data row17 col0" >48</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row18" class="row_heading level0 row18" >Organization</th>
#       <td id="T_4230c_row18_col0" class="data row18 col0" >491</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row19" class="row_heading level0 row19" >Distribution</th>
#       <td id="T_4230c_row19_col0" class="data row19 col0" >8570</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row20" class="row_heading level0 row20" >Nntp-Posting-Host</th>
#       <td id="T_4230c_row20_col0" class="data row20 col0" >8708</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row21" class="row_heading level0 row21" >NNTP-Posting-Host</th>
#       <td id="T_4230c_row21_col0" class="data row21 col0" >8793</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row22" class="row_heading level0 row22" >Reply-To</th>
#       <td id="T_4230c_row22_col0" class="data row22 col0" >9400</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row23" class="row_heading level0 row23" >Keywords</th>
#       <td id="T_4230c_row23_col0" class="data row23 col0" >10177</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row24" class="row_heading level0 row24" >Article-I.D.</th>
#       <td id="T_4230c_row24_col0" class="data row24 col0" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row25" class="row_heading level0 row25" >X-Newsreader</th>
#       <td id="T_4230c_row25_col0" class="data row25 col0" >10496</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row26" class="row_heading level0 row26" >Summary</th>
#       <td id="T_4230c_row26_col0" class="data row26 col0" >10691</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row27" class="row_heading level0 row27" >Originator</th>
#       <td id="T_4230c_row27_col0" class="data row27 col0" >10809</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row28" class="row_heading level0 row28" >In-Reply-To</th>
#       <td id="T_4230c_row28_col0" class="data row28 col0" >10870</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row29" class="row_heading level0 row29" >News-Software</th>
#       <td id="T_4230c_row29_col0" class="data row29 col0" >10919</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row30" class="row_heading level0 row30" >Expires</th>
#       <td id="T_4230c_row30_col0" class="data row30 col0" >10972</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row31" class="row_heading level0 row31" >In-reply-to</th>
#       <td id="T_4230c_row31_col0" class="data row31 col0" >10985</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row32" class="row_heading level0 row32" >To</th>
#       <td id="T_4230c_row32_col0" class="data row32 col0" >11001</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row33" class="row_heading level0 row33" >X-Disclaimer</th>
#       <td id="T_4230c_row33_col0" class="data row33 col0" >11024</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row34" class="row_heading level0 row34" >Disclaimer</th>
#       <td id="T_4230c_row34_col0" class="data row34 col0" >11026</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row35" class="row_heading level0 row35" >X-Mailer</th>
#       <td id="T_4230c_row35_col0" class="data row35 col0" >11034</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row36" class="row_heading level0 row36" >X-Useragent</th>
#       <td id="T_4230c_row36_col0" class="data row36 col0" >11042</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row37" class="row_heading level0 row37" >X-Xxdate</th>
#       <td id="T_4230c_row37_col0" class="data row37 col0" >11045</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row38" class="row_heading level0 row38" >Supersedes</th>
#       <td id="T_4230c_row38_col0" class="data row38 col0" >11048</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row39" class="row_heading level0 row39" >X-UserAgent</th>
#       <td id="T_4230c_row39_col0" class="data row39 col0" >11049</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row40" class="row_heading level0 row40" >X-XXDate</th>
#       <td id="T_4230c_row40_col0" class="data row40 col0" >11051</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row41" class="row_heading level0 row41" >Nf-ID</th>
#       <td id="T_4230c_row41_col0" class="data row41 col0" >11052</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row42" class="row_heading level0 row42" >X-News-Reader</th>
#       <td id="T_4230c_row42_col0" class="data row42 col0" >11052</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row43" class="row_heading level0 row43" >Nf-From</th>
#       <td id="T_4230c_row43_col0" class="data row43 col0" >11052</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_row44" class="row_heading level0 row44" >X-Added</th>
#       <td id="T_4230c_row44_col0" class="data row44 col0" >11057</td>
#     </tr>
#     <tr>
#       <th id="T_4230c_level0_r

# %%
select_cols = ["global_index", "doc_path", "label", "reply", "reference_one", "reference_two",
               "Subject", "From", "Lines", "Organization", "contained_emails", "long_string", "text", "error_message"]
print("\nmay use cols: \n", select_cols)
train = train[select_cols]
test = test[select_cols]
# Out:
# may use cols:
#  ['global_index', 'doc_path', 'label', 'reply', 'reference_one', 'reference_two', 'Subject', 'From', 'Lines', 'Organization', 'contained_emails', 'long_string', 'text', 'error_message']

# %%
train.isnull().sum().sort_values().to_dict()
# Out:
# {'global_index': 0,
#  'doc_path': 0,
#  'label': 0,
#  'reply': 0,
#  'reference_one': 0,
#  'reference_two': 0,
#  'text': 0,
#  'Subject': 11,
#  'From': 11,
#  'contained_emails': 11,
#  'long_string': 11,
#  'Lines': 48,
#  'Organization': 491,
#  'error_message': 11083}

# %%
# train[["label","global_index", "reply", "reference_one", "reference_two",]].sample(10).style

# %% [markdown]
# ## Outliers

# %%
train['long_string_len'] = train['long_string'].fillna(value='').apply(lambda x: len(x))
train.sort_values(by=['long_string_len']).tail(50)

# a = train['long_string'].fillna(value='').apply(lambda x: len(x))
# b = a
# c = b[b>4]
# check_list = c.index.tolist()[-50:]
# train[train['global_index'].isin(check_list)]['long_string'].tolist()
# Out:
#        global_index                                         doc_path  \
# 9195           9195        ../../data/train\talk.politics.guns\53364
# 7767           7767                   ../../data/train\sci.med\59326
# 3038           3038            ../../data/train\comp.windows.x\67012
# 8306           8306                 ../../data/train\sci.space\61022
# 2161           2161  ../../data/train\comp.sys.ibm.pc.hardware\60685
# 5858           5858          ../../data/train\rec.sport.hockey\52619
# 2065           2065  ../../data/train\comp.sys.ibm.pc.hardware\60510
# 5001           5001          ../../data/train\rec.motorcycles\104558
# 7788           7788                   ../../data/train\sci.med\59347
# 1611           1611    ../../data/train\comp.os.ms-windows.misc\9956
# 2219           2219  ../../data/train\comp.sys.ibm.pc.hardware\60758
# 2870           2870            ../../data/train\comp.windows.x\66442
# 7944           7944                 ../../data/train\sci.space\59870
# 5879           5879          ../../data/train\rec.sport.hockey\52640
# 8654           8654    ../../data/train\soc.religion.christian\20604
# 3431           3431              ../../data/train\misc.forsale\74735
# 7630           7630                   ../../data/train\sci.med\59126
# 7629           7629                   ../../data/train\sci.med\59125
# 880             880             ../../data/train\comp.graphics\38577
# 766             766             ../../data/train\comp.graphics\38460
# 10313         10313       ../../data/train\talk.politics.misc\176929
# 7627           7627                   ../../data/train\sci.med\59123
# 10744         10744        ../../data/train\talk.religion.misc\82810
# 5973           5973                 ../../data/train\sci.crypt\14991
# 4208           4208                ../../data/train\rec.autos\102812
# 686             686             ../../data/train\comp.graphics\38377
# 6397           6397                 ../../data/train\sci.crypt\15588
# 4595           4595          ../../data/train\rec.motorcycles\102616
# 5380           5380       ../../data/train\rec.sport.baseball\104343
# 685             685             ../../data/train\comp.graphics\38376
# 2861           2861            ../../data/train\comp.windows.x\66433
# 2857           2857            ../../data/train\comp.windows.x\66429
# 9186           9186        ../../data/train\talk.politics.guns\53354
# 960             960             ../../data/train\comp.graphics\38658
# 2852           2852            ../../data/train\comp.windows.x\66424
# 2858           2858            ../../data/train\comp.windows.x\66430
# 2850           2850            ../../data/train\comp.windows.x\66422
# 2826           2826            ../../data/train\comp.windows.x\66322
# 1645           1645    ../../data/train\comp.os.ms-windows.misc\9990
# 1636           1636    ../../data/train\comp.os.ms-windows.misc\9981
# 1638           1638    ../../data/train\comp.os.ms-windows.misc\9983
# 1640           1640    ../../data/train\comp.os.ms-windows.misc\9985
# 1362           1362    ../../data/train\comp.os.ms-windows.misc\9704
# 1635           1635    ../../data/train\comp.os.ms-windows.misc\9980
# 1637           1637    ../../data/train\comp.os.ms-windows.misc\9982
# 1639           1639    ../../data/train\comp.os.ms-windows.misc\9984
# 1642           1642    ../../data/train\comp.os.ms-windows.misc\9987
# 9625           9625        ../../data/train\talk.politics.guns\54684
# 1643           1643    ../../data/train\comp.os.ms-windows.misc\9988
# 1641           1641    ../../data/train\comp.os.ms-windows.misc\9986
#
#                           label  \
# 9195         talk.politics.guns
# 7767                    sci.med
# 3038             comp.windows.x
# 8306                  sci.space
# 2161   comp.sys.ibm.pc.hardware
# 5858           rec.sport.hockey
# 2065   comp.sys.ibm.pc.hardware
# 5001            rec.motorcycles
# 7788                    sci.med
# 1611    comp.os.ms-windows.misc
# 2219   comp.sys.ibm.pc.hardware
# 2870             comp.windows.x
# 7944                  sci.space
# 5879           rec.sport.hockey
# 8654     soc.religion.christian
# 3431               misc.forsale
# 7630                    sci.med
# 7629                    sci.med
# 880               comp.graphics
# 766               comp.graphics
# 10313        talk.politics.misc
# 7627                    sci.med
# 10744        talk.religion.misc
# 5973                  sci.crypt
# 4208                  rec.autos
# 686               comp.graphics
# 6397                  sci.crypt
# 4595            rec.motorcycles
# 5380         rec.sport.baseball
# 685               comp.graphics
# 2861             comp.windows.x
# 2857             comp.windows.x
# 9186         talk.politics.guns
# 960               comp.graphics
# 2852             comp.windows.x
# 2858             comp.windows.x
# 2850             comp.windows.x
# 2826             comp.windows.x
# 1645    comp.os.ms-windows.misc
# 1636    comp.os.ms-windows.misc
# 1638    comp.os.ms-windows.misc
# 1640    comp.os.ms-windows.misc
# 1362    comp.os.ms-windows.misc
# 1635    comp.os.ms-windows.misc
# 1637    comp.os.ms-windows.misc
# 1639    comp.os.ms-windows.misc
# 1642    comp.os.ms-windows.misc
# 9625         talk.politics.guns
# 1643    comp.os.ms-windows.misc
# 1641    comp.os.ms-windows.misc
#
#                                                    reply  \
# 9195   Just want to back this up with a personal anec...
# 7767   what is the likely hood of conception if sperm...
# 3038   For some reason the following code causes my X...
# 8306   Some time ago I sent the following message: Ev...
# 2161   Hi Netters, As promised, here are the summary ...
# 5858   Scoring stats for the Swedish NHL players, Apr...
# 2065   Hi! I think VGA-Copy can do what you need. If ...
# 5001   You may find it useful. -------------------cut...
# 7788   Lyme Disease Electronic Mail Network LymeNet N...
# 1611   Well, I'm amazed at how successful this exerci...
# 2219   Configuration of IDE Harddisks ===============...
# 2870   I don't know how many hours you've spent on th...
# 7944   Archive-name: space/diff DIFFS SINCE LAST FAQ ...
# 5879   ... Please. Have a care with Phil. We liked hi...
# 8654   Hi All Hope you all had a Blessed Easter. I ha...
# 3431   UPDATED LIST Hi everybody I have the following...
# 7630   ------------- cut here ----------------- Unive...
# 7629   ------------- cut here ----------------- Volum...
# 880    ------------------------------------- + .........
# 766    NYC ACM/SIGGRAPH: UNDERSTANDING IMAGES SUBJECT...
# 10313  David Matthew Deane When the words fold open, ...
# 7627   ------------- cut here ----------------- limit...
# 10744  I posted this several days ago for Dave Butler...
# 5973   I got a number of requests for code. So, here ...
# 4208   I recently posted an article asking what kind ...
# 686    Archive-name: graphics/resources-list/part1 La...
# 6397   CRYPTO '93 - Conference Announcement & Final C...
# 4595   This is a periodic posting intended to answer ...
# 5380   Some predictions need no introduction! Sometim...
# 685    Archive-name: graphics/resources-list/part3 La...
# 2861   Archive-name: x-faq/part3 Last-modified: 1993/...
# 2857   Archive-name: x-faq/part1 Last-modified: 1993/...
# 9186   THE ARMED CITIZEN Mere presence of a firearm, ...
# 960    SIGKIDS CALL FOR PARTICIPATION SIGKids Researc...
# 2852   Archive-name: x-faq/part5 Last-modified: 1993/...
# 2858   Archive-name: x-faq/part2 Last-modified: 1993/...
# 2850   Archive-name: x-faq/part4 Last-modified: 1993/...
# 2826   Archive-name: Xt-FAQ Version: $Id: FAQ-Xt,v 1....
# 1645   ------------ Part 14 of 14 ------------ M7KNZK...
# 1636   ------------ Part 7 of 14 ------------ M+8R,ER...
# 1638   ------------ Part 8 of 14 ------------ M:J"N6'...
# 1640   MFYLH`A;P#AU M9&1D9&ID1?U MFSXH$-#B"'3B8-C8V-C...
# 1362   Hi, everybody: I guess my subject has said it ...
# 1635   ------------ Part 5 of 14 ------------ M%6M%:T...
# 1637   ------------ Part 6 of 14 ------------ MAX=7HL...
# 1639   ------------ Part 10 of 14 ------------ MV=E&!...
# 1642   ------------ Part 13 of 14 ------------ MTMB8F...
# 9625   Try the firearms archive. Larry Cipriani's ins...
# 1643   ------------ Part 12 of 14 ------------ MN/3T]...
# 1641   ------------ Part 11 of 14 ------------ M9V=GQ...
#
#                                            reference_one  \
# 9195   Swatikas were also common in American Indian m...
# 7767   :When I was a school boy, my biology teacher t...
# 3038           doit = FALSE; doit = FALSE; doit = FALSE;
# 8306   How many people do you want to share the colon...
# 2161
# 5858
# 2065
# 5001
# 7788
# 1611   Does anyone know if Borland or Microsoft have ...
# 2219   When I installed a Conner CP3204F as master an...
# 2870   No. This is only relevant for OpenWindows 3.x ...
# 7944
# 5879   Bourque - the Penguin's GM must laugh his head...
# 8654
# 3431
# 7630                                            1:114/15
# 7629                                            1:114/15
# 880
# 766
# 10313  Announcing. . . Announcing. . . Announcing. . ...
# 7627                                            1:114/15
# 10744  Newsgroups: talk. religion. misc Newsgroups: t...
# 5973   0011 0011 00110000 11000000 00000011 00001100 ...
# 4208                                        $2000 / year
# 686    150 CD-ROMS directory. XYZ21. ZIP NCAD3D42. ZI...
# 6397   from dinner on Sunday to lunch on Thursday. Te...
# 4595
# 5380   What have I done? I computed the "expected win...
# 685    150 CD-ROMS with data/images. <y offset> <z of...
# 2861   <your-full-name>" is one of free-widgets-annou...
# 2857                                          F1: string
# 9186
# 960
# 2852   destroy_list; widget; destroy_countsizeof dest...
# 2858   output. xwd & /%L/%N%C:\ /%l/%N%C:\ /%N%C:\ /%...
# 2850   isn't being found. from SunOS 4.1.1. Remove th...
# 2826   sizeof) { \ size = sizeof; \ addr) = var; \ ad...
# 1645   N_?W]_?W]]'1T='I:6E 7KN_? BHJBHJN'"PMFQ#$QAX>'...
# 1636   36CV$D,='4.QL2&Q`:=G9V=G:E$ B%!2BP>"YR%<2 ` EZ...
# 1638   'AX>'AX>'AX>'AX>'AX>'AX>'`812E0<'GIYX`5Z> `0&$...
# 1640   GIZ>GIZBHJGIZ>M_?1T>EI0L+"V9F9F9FR,A_?W_0& NRH...
# 1362   P!%U]< %HUIU 'QFO0"/5DT .UV4 $$ Y SLD9&1D>SLBP...
# 1635   W&JVM<G)RK:UR<K>W<JVM<G)R<AM<GWMWRMO MK16MMZTR...
# 1637   'AX>'AX>'AX>'AX>'AX>'AX>' GHJKN/=)Q GK!Q 7EY>7...
# 1639   'AX>'AX>'AX>'AX=34U-34U-3,3$Q,3B8G) 'AX>'AX>'A...
# 1642   BHJNTM)Q&1D9L+"PL+"PL+!34U-34U-3L+"P 'AX>'AX>'...
# 9625                          prompt asking you to enter
# 1643   ' 'AX>' 'AS'$"T=ZBHJKN_?>GIZ>GK?WT=' NRIZWT>E"...
# 1641   7EZ]'1Z6EI0L+9F9F9F9F9F;$Q,3$Q,3$Q,3$9F8+"PL+ ...
#
#                                            reference_two  \
# 9195
# 7767
# 3038
# 8306
# 2161
# 5858
# 2065
# 5001
# 7788
# 1611
# 2219
# 2870   There's a bug in SunOS 4.1.3, which is alluded...
# 7944
# 5879   New York Rangers Messier Kovalev Bourque New Y...
# 8654
# 3431
# 7630
# 7629
# 880
# 766
# 10313
# 7627
# 10744  "And you maintain that you find such exegesis ...
# 5973
# 4208
# 686
# 6397
# 4595
# 5380   OPS Projected for 1992: HoJo .792 From Do you ...
# 685
# 2861
# 2857
# 9186
# 960
# 2852
# 2858
# 2850
# 2826
# 1645
# 1636
# 1638
# 1640
# 1362   G P---7+'U0/,PURM8MMVG<GX6%A85"45%147!14:U1<%%...
# 1635
# 1637
# 1639
# 1642
# 9625
# 1643
# 1641
#
#                                                  Subject  \
# 9195                                Re: Nazi memoribilia
# 7767                          Re: Pregnency without sex?
# 3038                                  Mysterious beeping
# 8306               Space Colony Size Preferences Summary
# 2161                      Summary: DoubleDisk Gold v 6.0
# 5858                          NHL Swedes: Stats, April 5
# 2065                            Re: Booting from B drive
# 5001                                     Re: Cobra Locks
# 7788                        LymeNet Newsletter vol#1 #09
# 1611     SUMMARY: Borland/Microsoft Database C Libraries
# 2219               List of IDE Harddisk specs (21/04/93)
# 2870          Re: Trouble compiling X11R5 on SunOS_4.1.3
# 7944   Diffs to sci.space/sci.astro Frequently Asked ...
# 5879      Re: This year's biggest and worst (opinion)...
# 8654                                       SSPX schism ?
# 3431          Re: computer books for sale (UPDATED LIST)
# 7630                       HICN610 Medical News Part 3/4
# 7629                 HICN610 Medical Newsletter Part 1/4
# 880    The OTIS Project (FTP sites for original art a...
# 766       SIGGRAPH -- Conference on Understanding Images
# 10313  Re: PUBLIC HEARINGS on Ballot Access, Vote Fra...
# 7627                       HICN610 Medical News Part 4/4
# 10744           BIBLICAL CONTRADICTIONS ANSWERED (Judas)
# 5973                                   LGA ncrypt source
# 4208         Insurance Rates on Performance Cars SUMMARY
# 686    (17 Apr 93) Computer Graphics Resource Listing...
# 6397                                CRYPTO 93 FINAL CALL
# 4595                              FAQ - What is the DoD?
# 5380                      Old Predictions to laugh at...
# 685    (17 Apr 93) Computer Graphics Resource Listing...
# 2861   comp.windows.x Frequently Asked Questions (FAQ...
# 2857   comp.windows.x Frequently Asked Questions (FAQ...
# 9186                           Armed Citizen - April '93
# 960                       SIGKids Research Showcase Call
# 2852   comp.windows.x Frequently Asked Questions (FAQ...
# 2858   comp.windows.x Frequently Asked Questions (FAQ...
# 2850   comp.windows.x Frequently Asked Questions (FAQ...
# 2826   comp.windows.x.intrinsics Frequently Asked Que...
# 1645                                     roman.bmp 14/14
# 1636                                     roman.bmp 07/14
# 1638                                     roman.bmp 08/14
# 1640   roman.bmp 09/14------------ Part 9 of 14 -----...
# 1362                           Re: More Cool BMP files??
# 1635                                     roman.bmp 05/14
# 1637                                     roman.bmp 06/14
# 1639                                     roman.bmp 10/14
# 1642                                     roman.bmp 13/14
# 9625   Re: Need Senate Bill numbers and House Resolut...
# 1643                                     roman.bmp 12/14
# 1641                                     roman.bmp 11/14
#
#                                                     From Lines  \
# 9195   cmay@helium.gas.uug.arizona.edu (Christopher C...    34
# 7767     scheiber@sage.cc.purdue.edu (Jennifer Scheiber)    33
# 3038                   defaria@cup.hp.com (Andy DeFaria)   121
# 8306                     globus@nas.nasa.gov (Al Globus)    92
# 2161            christyo@cae.wisc.edu (Buddy Christyono)    98
# 5858         etxonss@ufsa.ericsson.se (Staffan Axelsson)   141
# 2065   rtfuhge@immd8.informatik.uni-erlangen.de (Robe...    36
# 5001           sproulx@bmtlh204.BNR.CA (Stephane Proulx)   105
# 7788                      mcg2@Lehigh.EDU (Marc Gabriel)   344
# 1611   oecjtb@oec4.orbital.dialix.oz.au (John Bongiov...   384
# 2219      ph12hucg@sbusol.rz.uni-sb.de (Carsten Grammes)   761
# 2870                           troll@sug.org (A. Newman)   192
# 7944                        leech@cs.unc.edu (Jon Leech)   294
# 5879                   joe13+@pitt.edu (Joseph B Stiehm)    93
# 8654        simon@giaeb.cc.monash.edu.au (simon shields)    78
# 3431                           abou@dam.cee.clarkson.edu    76
# 7630                       david@stat.com (David Dodell)   708
# 7629                       david@stat.com (David Dodell)   708
# 880                     ed@cwis.unomaha.edu (Ed Stastny)   227
# 766                    arp@cooper!osd (Andrew Pinkowitz)   140
# 10313  deane@binah.cc.brandeis.edu (David Matthew Deane)   281
# 7627                       david@stat.com (David Dodell)   577
# 10744             af664@yfn.ysu.edu (Frank DeCenso, Jr.)   591
# 5973         ninassup@athena.mit.edu (Nikos I Nassuphis)  1135
# 4208               CPKJP@vm.cc.latech.edu (Kevin Parker)   244
# 686                       nfotis@ntua.gr (Nick C. Fotis)  1566
# 6397                    stevew@helios.unl.edu (Steve Wu)   258
# 4595    blgardne@javelin.sim.es.com (Dances With Bikers)   849
# 5380       tedward@cs.cornell.edu (Edward [Ted] Fischer)   404
# 685                       nfotis@ntua.gr (Nick C. Fotis)  1529
# 2861                     dbl@visual.com (David B. Lewis)   998
# 2857                     dbl@visual.com (David B. Lewis)   938
# 9186      crphilli@hound.dazixca.ingr.com (Ron Phillips)   150
# 960                schwartz@ils.nwu.edu (diane schwartz)   250
# 2852                     dbl@visual.com (David B. Lewis)   890
# 2858                     dbl@visual.com (David B. Lewis)   929
# 2850                     dbl@visual.com (David B. Lewis)   968
# 2826                ware@cis.ohio-state.edu (Peter Ware)  1609
# 1645                     pwiseman@salmon.usd.edu (Cliff)   449
# 1636                     pwiseman@salmon.usd.edu (Cliff)   958
# 1638                     pwiseman@salmon.usd.edu (Cliff)   956
# 1640                     pwiseman@salmon.usd.edu (Cliff)   958
# 1362                        james@dlss2 (James Cummings)  1021
# 1635                     pwiseman@salmon.usd.edu (Cliff)   957
# 1637                     pwiseman@salmon.usd.edu (Cliff)   958
# 1639                     pwiseman@salmon.usd.edu (Cliff)   956
# 1642                     pwiseman@salmon.usd.edu (Cliff)   956
# 9625                 mjp@watson.ibm.com (Michael Phelps)  1835
# 1643                     pwiseman@salmon.usd.edu (Cliff)   956
# 1641                     pwiseman@salmon.usd.edu (Cliff)   956
#
#                                             Organization  \
# 9195             University of Arizona - Tucson, Arizona
# 7767                  Purdue University Computing Center
# 3038                                     Hewlett-Packard
# 8306   Applied Research Office, NASA Ames Research Ce...
# 2161       U of Wisconsin-Madison College of Engineering
# 5858                 Ericsson Telecom, Stockholm, Sweden
# 2065                     University of Erlangen, csd. AI
# 5001                         Bell-Northern Research Ltd.
# 7788                                                None
# 1611                              Orbital Engine Company
# 2219           Universitaet des Saarlandes,Rechenzentrum
# 2870                                      Sun User Group
# 7944           University of North Carolina, Chapel Hill
# 5879                            University of Pittsburgh
# 8654                Monash University, Melb., Australia.
# 3431                                 Clarkson University
# 7630                        Stat Gateway Service, WB7TPY
# 7629                        Stat Gateway Service, WB7TPY
# 880                      University of Nebraska at Omaha
# 766                 Online Systems Development ( NY, NY)
# 10313                                Brandeis University
# 7627                        Stat Gateway Service, WB7TPY
# 10744               Youngstown State/Youngstown Free-Net
# 5973               Massachusetts Institute of Technology
# 4208                           Louisiana Tech University
# 686                   National Technical Univ. of Athens
# 6397                     University of Nebraska--Lincoln
# 4595             Evans & Sutherland Computer Corporation
# 5380              Cornell Univ. CS Dept, Ithaca NY 14853
# 685                   National Technical Univ. of Athens
# 2861                                        VISUAL, Inc.
# 2857                                        VISUAL, Inc.
# 9186         "Intergraph Electronics, Mountain View, CA"
# 960                  institute for the learning sciences
# 2852                                        VISUAL, Inc.
# 2858                                        VISUAL, Inc.
# 2850                                        VISUAL, Inc.
# 2826   The Ohio State University Dept. of Computer an...
# 1645                          University of South Dakota
# 1636                          University of South Dakota
# 1638                          University of South Dakota
# 1640                          University of South Dakota
# 1362                                 RedRock Development
# 1635                          University of South Dakota
# 1637                          University of South Dakota
# 1639                          University of South Dakota
# 1642                          University of South Dakota
# 9625                                     IBM Kingston NY
# 1643                          University of South Dakota
# 1641                          University of South Dakota
#
#                                         contained_emails  \
# 9195   [ <1993Apr2.232511.10711@raid.dell.com> , mike...
# 7767   [ <10030@blue.cis.pitt.edu> , kxgst1+@pitt.edu...
# 3038        [ defaria@cup.hp.com ,  defaria@cup.hp.com ]
# 8306   [ ruca@saber-si.pt ,  henry@zoo.toronto.edu , ...
# 2161   [ buddy@optics.ece.wisc.edu ,  bsteinke@dsd.es...
# 5858                                                  []
# 2065   [ rtfuhge@cip.informatik.uni-erlangen.de ,  rt...
# 5001   [ eeharvey@cybaswan.UUCP ,  <861@cybaswan.UUCP...
# 7788   [ <jml4s@uva.pcmail.virginia.edu> ,  <morset@c...
# 1611   [ osterber@husc.harvard.edu ,  cparker@centerl...
# 2219                                                  []
# 2870   [ <1993Apr6.081605.12977@fwi.uva.nl> , casper@...
# 7944   [ elements-request@telesoft.com ,  gps-request...
# 5879   [ <1993Apr6.170330.12314@is.morgan.com> , scai...
# 8654                    [ simon@giaec.cc.monash.edu.au ]
# 3431                       [ abou@sun.soe.clarkson.edu ]
# 7630   [ syd@azcc.arizona.edu ,  rick@jccc.medsch.ucl...
# 7629   [ david@stat.com ,  ATW1H@ASUACAD ,  MEDNEWS@A...
# 880        [ ed@cwis.unomaha.edu, , ed@sunsite.unc.edu ]
# 766                           [ MARCHESF@PACEVM.bitnet ]
# 10313  [ <1993Apr5.200623.15140@dsd.es.com>, , Bob.Wa...
# 7627   [ david@stat.com ,  ATW1H@ASUACAD ,  wb7tpy@wb...
# 10744  [ daveb@pogo.wv.tek.com ,  daveb@pogo.wv.tek.c...
# 5973                                                  []
# 4208   [ Callison@uokmax.ecn.uoknor.edu ,  Callison@a...
# 686    [ mail-server@pit-manager.mit.edu ,  nfotis@th...
# 6397   [ stinson@bibd.unl.edu ,  crypto93@bnr.ca ,  s...
# 4595   [ blgardne@javelin.sim.es.com. ,  Green:CA:ed....
# 5380   [ tedward@cs.cornell.edu ,  CAVGEOE@YaleVM.YCC...
# 685    [ Moore.Wbst128@Xerox.Com ,  pdbourke@ccu1.auk...
# 2861   [ xstuff@expo.lcs.mit.edu ,  foo%bar.bitnet@mi...
# 2857   [ mail-server@pit-manager.mit.edu ,  archive-s...
# 9186                 [ crphilli@hound.dazixca.ingr.com ]
# 960    [ schwartz@ils.nwu.edu ,  schwartz@ils.nwu.edu...
# 2852   [ <rvloon@cv.ruu.nl> ,  xada@ghg.hou.tx.us. , ...
# 2858   [ soft-eng@cs.uwm.edu. ,  bradley@cis.upenn.ed...
# 2850   [ dfs@bellcore.com. ,  soft-eng@cs.uwm.edu. , ...
# 2826   [ ware@cis.ohio-state.edu ,  cathyr@ora.com. ,...
# 1645   [ MW]_?>GIZKM>7@,#F3T]TM+2/3T]/3T]/3V9F0,#`UY>...
# 1636   [ MAX=75\@%2J##=4V,"F,N)P-]5%1JZ$D61DOF1D9R<F)...
# 1638   [ MAX>'AX>'AX>'AX>'AYZ>8=#0T"L!A%<-N;@+<-NPP25...
# 1640   [ MC#`P8V-55555555559-65@HWGV`7]?7U%Q>?GY?GP!@...
# 1362   [ <1993Apr17.023017.17301@gmuvax2.gmu.edu> , r...
# 1635   [ M,P$HWA=@8!SKWI_,S"B<)S<W-R>!5C<-S`HFNAIR<K)...
# 1637   [ M`0'UZY\WG@&>T)YU)3A&$+&]#+&NAX>'AX>'AS$Q,3%...
# 1639   [ M:FIJ:FIJ:FJ@KHB24E)24G9V=G9V=G9V=G9V=G9VE)3...
# 1642   [ MAX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'AS'$9F9F9@M...
# 9625   [ lvc@cbvox1.att.com ,  <1993Apr8.182924.7274@...
# 1643   [ MAX>',<3$9@L+I:5'W]_?W]_?W]_?>GIZBJ_?>M_?W]_...
# 1641   [ MAS'$Q,1F9@L+"Z6E1T??1T??WT>EI0L+"PMF"Z5'1T?...
#
#                                              long_string  \
# 9195   [+============================================...
# 7767   [>=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=--=-=-=-=-=...
# 3038   [/////////////////////////////////////////////...
# 8306   [=============================================...
# 2161   [---------------------------------------------...
# 5858   [=============================================...
# 2065   [+--------------------------------------------...
# 5001   [here-----------------------------------------...
# 7788   [---------------------------------------------...
# 1611   [+--------------------------------------------...
# 2219   [!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!...
# 2870   [---------------------------------------------...
# 7944   [=============================================...
# 5879   [>+-------------------------------------------...
# 8654   [AMBIGUITY.......................................
# 3431   [=============================================...
# 7630   [:::::::::::::::::::::::::::::::::::::::::::::...
# 7629   [:::::::::::::::::::::::::::::::::::::::::::::...
# 880    [---------------------------------------------...
# 766    [=============================================...
# 10313  [>-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+...
# 7627   [=============================================...
# 10744  [_____________________________________________...
# 5973   [;--------------------------------------------...
# 4208   [---------------------------------------------...
# 686    [=============================================...
# 6397   [................................................
# 4595   [---------------------------------------------...
# 5380   [---------------------------------------------...
# 685    [=============================================...
# 2861   [---------------------------------------------...
# 2857   [---------------------------------------------...
# 9186   [+++++++++++++++++++++++++++++++++++++++++++++...
# 960    [Name_________________________________________...
# 2852   [---------------------------------------------...
# 2858   [---------------------------------------------...
# 2850   [---------------------------------------------...
# 2826   [---------------------------------------------...
# 1645   [MI4='I:6E"PL+"V9FQ,0Q,8>'AX>'AX>'AX>'AX>'AX>'...
# 1636   [MI:6EI:6EI:6EI:6EI:6EI:6EI:6EI4='1T='1T='1T='...
# 1638   [MAPW/HFN`LC4U-34U,AK:VLV-MD'E94'V=DV-FMKS\];6...
# 1640   [MAX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'...
# 1362   [B_:S]K'EYK/W]_?W]K/W]_?W]_?W]_?VL_6JLKPO+R\_O...
# 1635   [M)B9R&KJZ)EVZ=+ITNKH>?7U=PGU]+"Q=?72_="PU'GT>...
# 1637   [MAZ)75U=7R!1KP"5A8=F>`7;UG)\&V0&>YZ>W5&$'Z]M;...
# 1639   [M:J"U$$,UM/3T]F9F9`P,#7EY>NRIZWT='I0MFQ#&'AX>...
# 1642   [M9\4TBU3&7$]F0->GK?1Z4+9C&'AX>'AX>'AX>'AX>'AX...
# 9625   [watson!yktnews.watson.ibm.com!newsgate.watson...
# 1643   [MAX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'AX>'...
# 1641   [MR1865%22DM75U=75U4)"0IV=G9V=G9V=G9V=G9V=G9V=...
#
#                                                     text  error_message  \
# 9195   Subject: Re: Nazi memoribilia\nFrom: cmay@heli...            NaN
# 7767   From: scheiber@sage.cc.purdue.edu (Jennifer Sc...            NaN
# 3038   From: defaria@cup.hp.com (Andy DeFaria)\nSubje...            NaN
# 8306   From: globus@nas.nasa.gov (Al Globus)\nSubject...            NaN
# 2161   From: christyo@cae.wisc.edu (Buddy Christyono)...            NaN
# 5858   From: etxonss@ufsa.ericsson.se (Staffan Axelss...            NaN
# 2065   From: rtfuhge@immd8.informatik.uni-erlangen.de...            NaN
# 5001   From: sproulx@bmtlh204.BNR.CA (Stephane Proulx...            NaN
# 7788   From: mcg2@Lehigh.EDU (Marc Gabriel)\nSubject:...            NaN
# 1611   From: oecjtb@oec4.orbital.dialix.oz.au (John B...            NaN
# 2219   From: ph12hucg@sbusol.rz.uni-sb.de (Carsten Gr...            NaN
# 2870   From: troll@sug.org (A. Newman)\nSubject: Re: ...            NaN
# 7944   Subject: Diffs to sci.space/sci.astro Frequent...            NaN
# 5879   From: joe13+@pitt.edu (Joseph B Stiehm)\nSubje...            NaN
# 8654   From: simon@giaeb.cc.monash.edu.au (simon shie...            NaN
# 3431   From: abou@dam.cee.clarkson.edu\nSubject: Re: ...            NaN
# 7630   From: david@stat.com (David Dodell)\nSubject: ...            NaN
# 7629   From: david@stat.com (David Dodell)\nSubject: ...            NaN
# 880    From: ed@cwis.unomaha.edu (Ed Stastny)\nSubjec...            NaN
# 766    From: arp@cooper!osd (Andrew Pinkowitz)\nSubje...            NaN
# 10313  From: deane@binah.cc.brandeis.edu (David Matth...            NaN
# 7627   From: david@stat.com (David Dodell)\nSubject: ...            NaN
# 10744  From: af664@yfn.ysu.edu (Frank DeCenso, Jr.)\n...            NaN
# 5973   From: ninassup@athena.mit.edu (Nikos I Nassuph...            NaN
# 4208   From: CPKJP@vm.cc.latech.edu (Kevin Parker)\nS...            NaN
# 686    From: nfotis@ntua.gr (Nick C. Fotis)\nSubject:...            NaN
# 6397   From: stevew@helios.unl.edu (Steve Wu)\nSubjec...            NaN
# 4595   From: blgardne@javelin.sim.es.com (Dances With...            NaN
# 5380   From: tedward@cs.cornell.edu (Edward [Ted] Fis...            NaN
# 685    From: nfotis@ntua.gr (Nick C. Fotis)\nSubject:...            NaN
# 2861   From: dbl@visual.com (David B. Lewis)\nSubject...            NaN
# 2857   From: dbl@visual.com (David B. Lewis)\nSubject...            NaN
# 9186   From: crphilli@hound.dazixca.ingr.com (Ron Phi...            NaN
# 960    From: schwartz@ils.nwu.edu (diane schwartz)\nS...            NaN
# 2852   From: dbl@visual.com (David B. Lewis)\nSubject...            NaN
# 2858   From: dbl@visual.com (David B. Lewis)\nSubject...            NaN
# 2850   From: dbl@visual.com (David B. Lewis)\nSubject...            NaN
# 2826   From: ware@cis.ohio-state.edu (Peter Ware)\nSu...            NaN
# 1645   Subject: roman.bmp 14/14\nFrom: pwiseman@salmo...            NaN
# 1636   Subject: roman.bmp 07/14\nFrom: pwiseman@salmo...            NaN
# 1638   Subject: roman.bmp 08/14\nFrom: pwiseman@salmo...            NaN
# 1640   Subject: roman.bmp 09/14------------ Part 9 of...            NaN
# 1362   From: james@dlss2 (James Cummings)\nSubject: R...            NaN
# 1635   Subject: roman.bmp 05/14\nFrom: pwiseman@salmo...            NaN
# 1637   Subject: roman.bmp 06/14\nFrom: pwiseman@salmo...            NaN
# 1639   Subject: roman.bmp 10/14\nFrom: pwiseman@salmo...            NaN
# 1642   Subject: roman.bmp 13/14\nFrom: pwiseman@salmo...            NaN
# 9625   From: mjp@watson.ibm.com (Michael Phelps)\nSub...            NaN
# 1643   Subject: roman.bmp 12/14 \nFrom: pwiseman@salm...            NaN
# 1641   Subject: roman.bmp 11/14 \nFrom: pwiseman@salm...            NaN
#
#        long_string_len
# 9195                 5
# 7767                 5
# 3038                 6
# 8306                 6
# 2161                 6
# 5858                 6
# 2065                 6
# 5001                 6
# 7788                 6
# 1611                 7
# 2219                 7
# 2870                 7
# 7944                 8
# 5879                 8
# 8654                 8
# 3431                 9
# 7630                 9
# 7629                 9
# 880                 10
# 766                 11
# 10313               11
# 7627                12
# 10744               12
# 5973                14
# 4208                14
# 686                 14
# 6397                15
# 4595                16
# 5380                17
# 685                 17
# 2861                25
# 2857                25
# 9186                28
# 960                 34
# 2852                35
# 2858                39
# 2850                42
# 2826                60
# 1645                80
# 1636                87
# 1638                95
# 1640               131
# 1362               136
# 1635               160
# 1637               213
# 1639               215
# 1642               244
# 9625               254
# 1643               266
# 1641               297

# %%
# t = train[train["reply"].apply(lambda x: "In article" in x)]
# t.groupby("label").size()

# %% [markdown]
# ### MNW

# %%
train = pd.read_json('../data/structured_train.json')
test = pd.read_json('../data/structured_test.json')

filtered_corpus=  train['text']
eda_MAX_NB_WORDS(corpus = filtered_corpus, remove_stop=True, ratio = 0.95)
eda_MAX_DOC_LEN(corpus = filtered_corpus, remove_stop=True, ratio=0.95)
eda_WORD_CLOUD(filtered_corpus, color='Blues', remove_stop=True)
# Out:
# Cut index with 95.0 % of corpus:  2899
#
#     index     word  count
# 0    3863       ax  62511
# 1     273       wa  13350
# 2      11     line  12669
# 3       0  subject  12201
# 4       9    organ  11500
# 5     122      use   9514
# 6      21    write   8625
# 7     212       ha   7538
# 8      96      ani   7020
# 9      27     like   6428
# 10    216     know   5667
# 11    267    think   4919
# 12    127       hi   4873
# 13    128     time   4847
# 14    343      doe   4146
# 15     65      new   4075
# 16    211     work   4047
# 17    495     good   3690
# 18    565     want   3582
# 19    600     year   3571
# extreme frequent words:      word  count
# 3863   ax  62511
# Cut index with 95.0 % of corpus:  210

# %%
train, test = load_data(only_stem_voc=True, sample50=False)

# %%
filtered_corpus=  train['text']
eda_MAX_NB_WORDS(corpus = filtered_corpus, remove_stop=True, ratio = 0.95)
eda_MAX_DOC_LEN(corpus = filtered_corpus, remove_stop=True, ratio=0.95)
eda_WORD_CLOUD(filtered_corpus, color='Blues', remove_stop=True)

# %% [markdown]
# # for each class EDA

# %%
# label_dict ={}
# for label, table in train.groupby("label"):
#     corpus = table['reply']
#     eda_MAX_NB_WORDS(corpus=corpus, remove_stop=True, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'+'0123456789', ratio=0.95)
#     eda_MAX_DOC_LEN(corpus=corpus, remove_stop=True,  filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'+'0123456789', ratio=0.9)
#     word_freq = eda_WORD_CLOUD(corpus)
#     label_dict[label] = word_freq
# #     break
