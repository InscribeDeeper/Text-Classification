# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#extra-one-hot-features" data-toc-modified-id="extra-one-hot-features-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>extra one-hot features</a></span></li><li><span><a href="#extra-keywords" data-toc-modified-id="extra-keywords-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>extra keywords</a></span></li></ul></li><li><span><a href="#Dense" data-toc-modified-id="Dense-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Dense</a></span></li></ul></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TextCNN" data-toc-modified-id="TextCNN-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TextCNN</a></span><ul class="toc-item"><li><span><a href="#notes:" data-toc-modified-id="notes:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>notes:</a></span></li></ul></li><li><span><a href="#LSTM" data-toc-modified-id="LSTM-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>LSTM</a></span></li></ul></div>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Text-Classification/code")
# !pip install pyLDAvis
# !pip install gensim
# !pip install pandas==1.3.0
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.0.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.4)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.2.1)
# Requirement already satisfied: pandas==1.3.0 in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.0) (1.15.0)

# %%
from classification_utils import *
from clustering_utils import *
from eda_utils import *
from nn_utils_keras import *
from feature_engineering_utils import *
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
train, test = load_data(only_stem_voc=True)
# train, upsampling_info = upsampling_train(train)

train_text, train_label = train_augmentation(train, select_comb=None)
test_text, test_label = test['text'], test['label']

# test_text = test_text.apply(lambda x: extract_stem_voc(x))
# train_text = train_text.apply(lambda x: extract_stem_voc(x))
# train_text.to_csv("stem_voc_train.csv")
# test_text.to_csv("stem_voc_test.csv")

# train_text, test_text = load_stem_voc()
# Out:
# may use cols:
#  ['global_index', 'doc_path', 'label', 'reply', 'reference_one', 'reference_two', 'tag_reply', 'tag_reference_one', 'tag_reference_two', 'Subject', 'From', 'Lines', 'Organization', 'contained_emails', 'long_string', 'text', 'error_message']

# %%
####################################
### label mapper
####################################
labels = sorted(train_label.unique())
label_mapper = dict(zip(labels, range(len(labels))))
train_label = train_label.map(label_mapper)
test_label = test_label.map(label_mapper)
y_train = train_label
y_test = test_label

print(train_text.shape)
print(test_text.shape)
print(train_label.shape)
print(test_label.shape)
print(labels)
# Out:
# (11083,)
# (7761,)
# (11083,)
# (7761,)
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']

# %%
####################################
### hyper params 
####################################
filters = '"#$%&()*+,-/:;<=>@[\\]^_`{|}~\t\n0123465789!.?\''
MAX_NB_WORDS_ratio = 0.95
MAX_DOC_LEN_ratio = 0.99
MAX_NB_WORDS = eda_MAX_NB_WORDS(train_text, ratio=MAX_NB_WORDS_ratio, char_level=False, filters=filters)
MAX_DOC_LEN = eda_MAX_DOC_LEN(train_text, ratio=MAX_DOC_LEN_ratio, char_level=False, filters=filters)
# Out:
# Cut index with 95.0 % of corpus:  1820
#
#     index  word   count
# 0      27   the  142476
# 1       6    to   71797
# 2      15    of   68191
# 3    4073    ax   62511
# 4      21   and   56944
# 5      28    in   47583
# 6      49    is   43091
# 7     129  that   38781
# 8      35    it   35601
# 9      63   for   28036
# 10    284   you   26258
# 11      0  from   22170
# 12    100    be   21418
# 13     40    on   19654
# 14    416  have   18766
# 15     25   are   18423
# 16    393   not   18290
# 17     44  with   17075
# 18    226    as   15577
# 19     85    or   14561
# Cut index with 99.0 % of corpus:  1452

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Embedding, Dense, Conv1D, MaxPooling1D, Dropout, Activation, Input, Flatten, Concatenate, Lambda
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow import keras
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

# %% [markdown]
# ## extra one-hot features

# %%
# one_hot_X_train, one_hot_X_test, one_hot_word_to_idx, one_hot_count_vect = count_vectorizer(
#     train['Subject']+" " + train['Organization'], test['Subject']+" " + test['Organization'], stop_words=True, binary=False, min_df=3, max_df=0.001)

# %% [markdown]
# ## extra keywords

# %%
label_docs = train.groupby('label')['text'].apply(lambda x: " ".join(x)) # 要去除标点符号
dtm, _, label_word_to_idx, _ = count_vectorizer(label_docs, [''], stop_words=True, min_df=1, binary=True)
label_idx_to_word = dict([val, key] for key, val in label_word_to_idx.items())
keywords_threshold = 1
keywords_idx = np.where(dtm.sum(axis=0)<=keywords_threshold)[0]
print(" keywords_idx shape: ")
voc = [label_idx_to_word[idx] for idx in keywords_idx]

keywords_X_train, keywords_X_test, keywords_word_to_idx, keywords_count_vect = count_vectorizer(
    train['text'], test['text'], voc=voc, stop_words=True, min_df=1, binary=True)
# Out:
# num of words: 10097
#  keywords_idx shape:
# num of words: 3543

# %% [markdown]
# # Dense

# %%
X_train, X_test, word_to_idx, tfidf_vect = tfidf_vectorizer(train_text, test_text, stop_words=True, binary=True, min_df=5)
# X_train, transform_mapper = dimension_reduction(X_train, out_dim=1000) # not allow negative 
# X_test = transform_mapper.transform(X_test)
# Out:
# num of words: 5678

# %%
# _X_train = np.hstack([X_train])
# _X_test = np.hstack([X_test])
_X_train = np.hstack([X_train, keywords_X_train])
_X_test = np.hstack([X_test, keywords_X_test])

# _X_train = np.hstack([X_train, one_hot_X_train, keywords_X_train])
# _X_test = np.hstack([X_test, one_hot_X_test, keywords_X_test])

# %%
opt = optimizers.Adam(learning_rate=0.005)

model = Sequential()
model.add(Input(shape=_X_train.shape[1],))  # input cannot connect with dropout directly
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(20, activation='softmax'))
model.compile(optimizer=opt,
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])


# model.compile(optimizer=opt,
#                 loss=keras.losses.CategoricalHinge(),
#               metrics=[keras.metrics.CategoricalAccuracy()])

# %%
BATCH_SIZE = 256 # 16 # 先在小的batch上train, 容易找到全局最优部分, 然后再到 大 batch 上train, 快速收敛到局部最优
NUM_EPOCHES = 100  # 20步以上
patience = 80

file_name = 'test'
BestModel_Name = file_name + 'Best_GS_5'
BEST_MODEL_FILEPATH = BestModel_Name
earlyStopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=patience, verbose=1, mode='max') # patience: number of epochs with no improvement on monitor : val_loss
checkpoint = ModelCheckpoint(BEST_MODEL_FILEPATH, monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
# history = model.fit(_X_train, y_train, validation_data=(_X_test,y_test), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)

history = model.fit(_X_train, y_train, validation_data=(_X_test,y_test), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=None, verbose=1)
# history = model.fit(_X_train, to_categorical(y_train), validation_data=(_X_test,to_categorical(y_test)), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=None, verbose=1)
# history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=BATCH_SIZE, epochs=NUM_EPOCHES, callbacks=[earlyStopping, checkpoint], verbose=1)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 1s 21ms/step - loss: 2.5633 - sparse_categorical_accuracy: 0.1953 - val_loss: 1.8059 - val_sparse_categorical_accuracy: 0.5012
# Epoch 2/100
# 44/44 [==============================] - 0s 11ms/step - loss: 1.2965 - sparse_categorical_accuracy: 0.5739 - val_loss: 1.2748 - val_sparse_categorical_accuracy: 0.6042
# Epoch 3/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.7726 - sparse_categorical_accuracy: 0.7536 - val_loss: 1.1074 - val_sparse_categorical_accuracy: 0.6878
# Epoch 4/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.5278 - sparse_categorical_accuracy: 0.8389 - val_loss: 1.1304 - val_sparse_categorical_accuracy: 0.7004
# Epoch 5/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.3723 - sparse_categorical_accuracy: 0.8896 - val_loss: 1.2315 - val_sparse_categorical_accuracy: 0.7110
# Epoch 6/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.2961 - sparse_categorical_accuracy: 0.9139 - val_loss: 1.2865 - val_sparse_categorical_accuracy: 0.7174
# Epoch 7/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.2272 - sparse_categorical_accuracy: 0.9321 - val_loss: 1.3867 - val_sparse_categorical_accuracy: 0.7154
# Epoch 8/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.2033 - sparse_categorical_accuracy: 0.9426 - val_loss: 1.4370 - val_sparse_categorical_accuracy: 0.7208
# Epoch 9/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1618 - sparse_categorical_accuracy: 0.9519 - val_loss: 1.5144 - val_sparse_categorical_accuracy: 0.7161
# Epoch 10/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.1528 - sparse_categorical_accuracy: 0.9554 - val_loss: 1.5423 - val_sparse_categorical_accuracy: 0.7191
# Epoch 11/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1254 - sparse_categorical_accuracy: 0.9627 - val_loss: 1.6375 - val_sparse_categorical_accuracy: 0.7164
# Epoch 12/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1260 - sparse_categorical_accuracy: 0.9625 - val_loss: 1.6531 - val_sparse_categorical_accuracy: 0.7165
# Epoch 13/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1197 - sparse_categorical_accuracy: 0.9658 - val_loss: 1.6272 - val_sparse_categorical_accuracy: 0.7200
# Epoch 14/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.1198 - sparse_categorical_accuracy: 0.9683 - val_loss: 1.6936 - val_sparse_categorical_accuracy: 0.7088
# Epoch 15/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.1035 - sparse_categorical_accuracy: 0.9719 - val_loss: 1.7088 - val_sparse_categorical_accuracy: 0.7207
# Epoch 16/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0951 - sparse_categorical_accuracy: 0.9752 - val_loss: 1.8008 - val_sparse_categorical_accuracy: 0.7172
# Epoch 17/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0811 - sparse_categorical_accuracy: 0.9763 - val_loss: 1.8389 - val_sparse_categorical_accuracy: 0.7155
# Epoch 18/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0883 - sparse_categorical_accuracy: 0.9753 - val_loss: 1.8357 - val_sparse_categorical_accuracy: 0.7199
# Epoch 19/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0821 - sparse_categorical_accuracy: 0.9788 - val_loss: 1.8348 - val_sparse_categorical_accuracy: 0.7159
# Epoch 20/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0757 - sparse_categorical_accuracy: 0.9776 - val_loss: 1.8879 - val_sparse_categorical_accuracy: 0.7174
# Epoch 21/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0635 - sparse_categorical_accuracy: 0.9820 - val_loss: 2.0049 - val_sparse_categorical_accuracy: 0.7183
# Epoch 22/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9791 - val_loss: 1.9921 - val_sparse_categorical_accuracy: 0.7149
# Epoch 23/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9808 - val_loss: 1.9409 - val_sparse_categorical_accuracy: 0.7178
# Epoch 24/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0766 - sparse_categorical_accuracy: 0.9815 - val_loss: 1.9858 - val_sparse_categorical_accuracy: 0.7172
# Epoch 25/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0714 - sparse_categorical_accuracy: 0.9815 - val_loss: 2.0546 - val_sparse_categorical_accuracy: 0.7145
# Epoch 26/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9829 - val_loss: 2.0325 - val_sparse_categorical_accuracy: 0.7187
# Epoch 27/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0622 - sparse_categorical_accuracy: 0.9826 - val_loss: 2.1064 - val_sparse_categorical_accuracy: 0.7200
# Epoch 28/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0670 - sparse_categorical_accuracy: 0.9811 - val_loss: 2.1171 - val_sparse_categorical_accuracy: 0.7134
# Epoch 29/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9825 - val_loss: 2.0613 - val_sparse_categorical_accuracy: 0.7142
# Epoch 30/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9845 - val_loss: 2.0912 - val_sparse_categorical_accuracy: 0.7185
# Epoch 31/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0647 - sparse_categorical_accuracy: 0.9820 - val_loss: 2.1156 - val_sparse_categorical_accuracy: 0.7169
# Epoch 32/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0726 - sparse_categorical_accuracy: 0.9809 - val_loss: 2.1202 - val_sparse_categorical_accuracy: 0.7143
# Epoch 33/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9804 - val_loss: 2.0943 - val_sparse_categorical_accuracy: 0.7049
# Epoch 34/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0665 - sparse_categorical_accuracy: 0.9825 - val_loss: 2.0573 - val_sparse_categorical_accuracy: 0.7127
# Epoch 35/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0543 - sparse_categorical_accuracy: 0.9856 - val_loss: 2.1810 - val_sparse_categorical_accuracy: 0.7143
# Epoch 36/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0623 - sparse_categorical_accuracy: 0.9843 - val_loss: 2.1967 - val_sparse_categorical_accuracy: 0.7137
# Epoch 37/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0566 - sparse_categorical_accuracy: 0.9840 - val_loss: 2.2184 - val_sparse_categorical_accuracy: 0.7094
# Epoch 38/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0700 - sparse_categorical_accuracy: 0.9832 - val_loss: 2.1658 - val_sparse_categorical_accuracy: 0.7155
# Epoch 39/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9837 - val_loss: 2.1736 - val_sparse_categorical_accuracy: 0.7154
# Epoch 40/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0717 - sparse_categorical_accuracy: 0.9805 - val_loss: 2.1874 - val_sparse_categorical_accuracy: 0.7154
# Epoch 41/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9838 - val_loss: 2.1368 - val_sparse_categorical_accuracy: 0.7127
# Epoch 42/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0591 - sparse_categorical_accuracy: 0.9851 - val_loss: 2.2287 - val_sparse_categorical_accuracy: 0.7115
# Epoch 43/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0618 - sparse_categorical_accuracy: 0.9834 - val_loss: 2.1669 - val_sparse_categorical_accuracy: 0.7141
# Epoch 44/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9820 - val_loss: 2.2687 - val_sparse_categorical_accuracy: 0.7151
# Epoch 45/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0520 - sparse_categorical_accuracy: 0.9858 - val_loss: 2.2682 - val_sparse_categorical_accuracy: 0.7176
# Epoch 46/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0569 - sparse_categorical_accuracy: 0.9838 - val_loss: 2.3485 - val_sparse_categorical_accuracy: 0.7127
# Epoch 47/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0714 - sparse_categorical_accuracy: 0.9821 - val_loss: 2.2300 - val_sparse_categorical_accuracy: 0.7136
# Epoch 48/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0763 - sparse_categorical_accuracy: 0.9841 - val_loss: 2.2599 - val_sparse_categorical_accuracy: 0.7074
# Epoch 49/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9831 - val_loss: 2.2117 - val_sparse_categorical_accuracy: 0.7122
# Epoch 50/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0545 - sparse_categorical_accuracy: 0.9854 - val_loss: 2.3771 - val_sparse_categorical_accuracy: 0.7082
# Epoch 51/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9843 - val_loss: 2.3838 - val_sparse_categorical_accuracy: 0.7089
# Epoch 52/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9833 - val_loss: 2.3618 - val_sparse_categorical_accuracy: 0.7065
# Epoch 53/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9871 - val_loss: 2.4442 - val_sparse_categorical_accuracy: 0.7094
# Epoch 54/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9855 - val_loss: 2.4241 - val_sparse_categorical_accuracy: 0.7116
# Epoch 55/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0480 - sparse_categorical_accuracy: 0.9874 - val_loss: 2.3555 - val_sparse_categorical_accuracy: 0.7143
# Epoch 56/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0532 - sparse_categorical_accuracy: 0.9853 - val_loss: 2.4841 - val_sparse_categorical_accuracy: 0.7172
# Epoch 57/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0619 - sparse_categorical_accuracy: 0.9838 - val_loss: 2.4011 - val_sparse_categorical_accuracy: 0.7141
# Epoch 58/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0609 - sparse_categorical_accuracy: 0.9845 - val_loss: 2.5203 - val_sparse_categorical_accuracy: 0.7084
# Epoch 59/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0541 - sparse_categorical_accuracy: 0.9854 - val_loss: 2.4992 - val_sparse_categorical_accuracy: 0.7100
# Epoch 60/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0462 - sparse_categorical_accuracy: 0.9872 - val_loss: 2.5579 - val_sparse_categorical_accuracy: 0.7107
# Epoch 61/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0554 - sparse_categorical_accuracy: 0.9866 - val_loss: 2.5109 - val_sparse_categorical_accuracy: 0.7107
# Epoch 62/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9856 - val_loss: 2.4703 - val_sparse_categorical_accuracy: 0.7118
# Epoch 63/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9864 - val_loss: 2.4932 - val_sparse_categorical_accuracy: 0.7114
# Epoch 64/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9874 - val_loss: 2.5444 - val_sparse_categorical_accuracy: 0.7101
# Epoch 65/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9898 - val_loss: 2.7039 - val_sparse_categorical_accuracy: 0.7119
# Epoch 66/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0612 - sparse_categorical_accuracy: 0.9859 - val_loss: 2.6174 - val_sparse_categorical_accuracy: 0.7103
# Epoch 67/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9861 - val_loss: 2.5531 - val_sparse_categorical_accuracy: 0.7119
# Epoch 68/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0546 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.5138 - val_sparse_categorical_accuracy: 0.7138
# Epoch 69/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9875 - val_loss: 2.5673 - val_sparse_categorical_accuracy: 0.7129
# Epoch 70/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0442 - sparse_categorical_accuracy: 0.9896 - val_loss: 2.7127 - val_sparse_categorical_accuracy: 0.7145
# Epoch 71/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9875 - val_loss: 2.6322 - val_sparse_categorical_accuracy: 0.7089
# Epoch 72/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0439 - sparse_categorical_accuracy: 0.9884 - val_loss: 2.6297 - val_sparse_categorical_accuracy: 0.7093
# Epoch 73/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0507 - sparse_categorical_accuracy: 0.9857 - val_loss: 2.6532 - val_sparse_categorical_accuracy: 0.7048
# Epoch 74/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0450 - sparse_categorical_accuracy: 0.9870 - val_loss: 2.6648 - val_sparse_categorical_accuracy: 0.7064
# Epoch 75/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9877 - val_loss: 2.7884 - val_sparse_categorical_accuracy: 0.7100
# Epoch 76/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9867 - val_loss: 2.8030 - val_sparse_categorical_accuracy: 0.7075
# Epoch 77/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0492 - sparse_categorical_accuracy: 0.9862 - val_loss: 2.7549 - val_sparse_categorical_accuracy: 0.7058
# Epoch 78/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0564 - sparse_categorical_accuracy: 0.9866 - val_loss: 2.7385 - val_sparse_categorical_accuracy: 0.7061
# Epoch 79/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9875 - val_loss: 2.6506 - val_sparse_categorical_accuracy: 0.7093
# Epoch 80/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9871 - val_loss: 2.6795 - val_sparse_categorical_accuracy: 0.7102
# Epoch 81/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9864 - val_loss: 2.7672 - val_sparse_categorical_accuracy: 0.7097
# Epoch 82/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9870 - val_loss: 2.7214 - val_sparse_categorical_accuracy: 0.7111
# Epoch 83/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0568 - sparse_categorical_accuracy: 0.9870 - val_loss: 2.6591 - val_sparse_categorical_accuracy: 0.7150
# Epoch 84/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9867 - val_loss: 2.6766 - val_sparse_categorical_accuracy: 0.7078
# Epoch 85/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0614 - sparse_categorical_accuracy: 0.9863 - val_loss: 2.6870 - val_sparse_categorical_accuracy: 0.7087
# Epoch 86/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9905 - val_loss: 2.7410 - val_sparse_categorical_accuracy: 0.7110
# Epoch 87/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.7783 - val_sparse_categorical_accuracy: 0.7119
# Epoch 88/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.7853 - val_sparse_categorical_accuracy: 0.7141
# Epoch 89/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0573 - sparse_categorical_accuracy: 0.9872 - val_loss: 2.5836 - val_sparse_categorical_accuracy: 0.7172
# Epoch 90/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9880 - val_loss: 2.6031 - val_sparse_categorical_accuracy: 0.7129
# Epoch 91/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9876 - val_loss: 2.6273 - val_sparse_categorical_accuracy: 0.7125
# Epoch 92/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9858 - val_loss: 2.6079 - val_sparse_categorical_accuracy: 0.7107
# Epoch 93/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9882 - val_loss: 2.7379 - val_sparse_categorical_accuracy: 0.7111
# Epoch 94/100
# 44/44 [==============================] - 1s 12ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9905 - val_loss: 2.7971 - val_sparse_categorical_accuracy: 0.7131
# Epoch 95/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0432 - sparse_categorical_accuracy: 0.9890 - val_loss: 2.7471 - val_sparse_categorical_accuracy: 0.7156
# Epoch 96/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0432 - sparse_categorical_accuracy: 0.9887 - val_loss: 2.7116 - val_sparse_categorical_accuracy: 0.7137
# Epoch 97/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0558 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.7040 - val_sparse_categorical_accuracy: 0.7146
# Epoch 98/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0520 - sparse_categorical_accuracy: 0.9867 - val_loss: 2.6538 - val_sparse_categorical_accuracy: 0.7141
# Epoch 99/100
# 44/44 [==============================] - 0s 11ms/step - loss: 0.0448 - sparse_categorical_accuracy: 0.9894 - val_loss: 2.6995 - val_sparse_categorical_accuracy: 0.7138
# Epoch 100/100
# 44/44 [==============================] - 1s 14ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.7529 - val_sparse_categorical_accuracy: 0.7110

# %%
#### classification Report
history_plot(history)
y_pred = model.predict(_X_test)
classification_report = evaluation_report(y_test, np.argmax(y_pred, axis=1), labels=labels)

scores = model.evaluate(_X_test, y_test, verbose=2)
roc_auc(y_test, y_pred)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print( "\n\n\n")
# Out:
# ========================================================================
# loss val_loss
# ========================================================================
# sparse_categorical_accuracy val_sparse_categorical_accuracy
# classification_report:
# f1:  {'micro avg': 0.7109908516943692, 'macro avg': 0.6992965697733307}
#
#                           precision  recall  f1-score  support
# alt.atheism                   0.716   0.608     0.658    319.0
# comp.graphics                 0.558   0.609     0.582    389.0
# comp.os.ms-windows.misc       0.533   0.579     0.555    394.0
# comp.sys.ibm.pc.hardware      0.526   0.620     0.569    392.0
# comp.sys.mac.hardware         0.613   0.675     0.643    385.0
# comp.windows.x                0.595   0.605     0.600    395.0
# misc.forsale                  0.695   0.754     0.723    390.0
# rec.autos                     0.757   0.775     0.766    395.0
# rec.motorcycles               0.884   0.882     0.883    398.0
# rec.sport.baseball            0.718   0.877     0.789    397.0
# rec.sport.hockey              0.986   0.779     0.870    827.0
# sci.crypt                     0.899   0.831     0.864    396.0
# sci.electronics               0.684   0.573     0.623    393.0
# sci.med                       0.729   0.813     0.768    198.0
# sci.space                     0.876   0.810     0.842    394.0
# soc.religion.christian        0.690   0.771     0.728    398.0
# talk.politics.guns            0.661   0.772     0.712    364.0
# talk.politics.mideast         0.801   0.726     0.762    376.0
# talk.politics.misc            0.623   0.523     0.568    310.0
# talk.religion.misc            0.496   0.466     0.480    251.0
# accuracy                      0.711   0.711     0.711   7761.0
# macro avg                     0.702   0.702     0.699   7761.0
# weighted avg                  0.722   0.711     0.713   7761.0
# micro avg                     0.711   0.711     0.711   7761.0
# 243/243 - 0s - loss: 2.7529 - sparse_categorical_accuracy: 0.7110 - 490ms/epoch - 2ms/step
# roc_auc:  0.9474027653848115
# sparse_categorical_accuracy: 71.10%
